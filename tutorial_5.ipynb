# %%
import nltk
from nltk.tokenize import word_tokenize
text = word_tokenize("And now for something completely different")
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %%
nltk.help.upenn_tagset('RB')
# Out:
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...

# %%
nltk.help.upenn_tagset('NN.*')
# Out:
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...

# %%
text = word_tokenize("They refuse to permit us to obtain the refuse permit")
nltk.pos_tag(text)
# Out:
# [('They', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %%
text = word_tokenize("to ship")
nltk.pos_tag(text)
# Out:
# [('to', 'TO'), ('ship', 'VB')]

# %%
text = word_tokenize("the ship")
nltk.pos_tag(text)
# Out:
# [('the', 'DT'), ('ship', 'NN')]

# %%
text = nltk.Text(word.lower() for word in nltk.corpus.brown.words())
text.similar('woman')
# Out:
# man time day year car moment world family house country child boy
# state job way war girl place word work

# %%
text.similar('bought')
# Out:
# made said put done seen had found left given heard brought got been
# was set told took in felt that

# %%
text.similar('over')
# Out:
# in on to of and for with from at by that into as up out down through
# is all about

# %%
text.similar('the')
# Out:
# a his this their its her an that our any all one these my in your no
# some other and

# %%
tagged_token = nltk.tag.str2tuple('fly/NN')
tagged_token
# Out:
# ('fly', 'NN')

# %%
tagged_token[0]
# Out:
# 'fly'

# %%
tagged_token[1]
# Out:
# 'NN'

# %%
sent = '''
... The/AT grand/JJ jury/NN commented/VBD on/IN a/AT number/NN of/IN
... other/AP topics/NNS ,/, AMONG/IN them/PPO the/AT Atlanta/NP and/CC
... Fulton/NP-tl County/NN-tl purchasing/VBG departments/NNS which/WDT it/PPS
... said/VBD ``/`` ARE/BER well/QL operated/VBN and/CC follow/VB generally/RB
... accepted/VBN practices/NNS which/WDT inure/VB to/IN the/AT best/JJT
... interest/NN of/IN both/ABX governments/NNS ''/'' ./.
... '''

# %%
[nltk.tag.str2tuple(t) for t in sent.split()]
# Out:
# [('The', 'AT'),
#  ('grand', 'JJ'),
#  ('jury', 'NN'),
#  ('commented', 'VBD'),
#  ('on', 'IN'),
#  ('a', 'AT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('other', 'AP'),
#  ('topics', 'NNS'),
#  (',', ','),
#  ('AMONG', 'IN'),
#  ('them', 'PPO'),
#  ('the', 'AT'),
#  ('Atlanta', 'NP'),
#  ('and', 'CC'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('purchasing', 'VBG'),
#  ('departments', 'NNS'),
#  ('which', 'WDT'),
#  ('it', 'PPS'),
#  ('said', 'VBD'),
#  ('``', '``'),
#  ('ARE', 'BER'),
#  ('well', 'QL'),
#  ('operated', 'VBN'),
#  ('and', 'CC'),
#  ('follow', 'VB'),
#  ('generally', 'RB'),
#  ('accepted', 'VBN'),
#  ('practices', 'NNS'),
#  ('which', 'WDT'),
#  ('inure', 'VB'),
#  ('to', 'IN'),
#  ('the', 'AT'),
#  ('best', 'JJT'),
#  ('interest', 'NN'),
#  ('of', 'IN'),
#  ('both', 'ABX'),
#  ('governments', 'NNS'),
#  ("''", "''"),
#  ('.', '.')]

# %%
nltk.corpus.brown.tagged_words()
# Out:
# [(u'The', u'AT'), (u'Fulton', u'NP-TL'), ...]

# %%
nltk.corpus.brown.tagged_words(tagset='universal')
# Out:
# [(u'The', u'DET'), (u'Fulton', u'NOUN'), ...]

# %%
print(nltk.corpus.nps_chat.tagged_words())
# Out:
# [(u'now', 'RB'), (u'im', 'PRP'), (u'left', 'VBD'), ...]

# %%
nltk.corpus.conll2000.tagged_words()
# Out:
# [(u'Confidence', u'NN'), (u'in', u'IN'), ...]

# %%
nltk.corpus.treebank.tagged_words()
# Out:
# [(u'Pierre', u'NNP'), (u'Vinken', u'NNP'), ...]

# %%
nltk.corpus.brown.tagged_words(tagset='universal')
# Out:
# [(u'The', u'DET'), (u'Fulton', u'NOUN'), ...]

# %%
nltk.corpus.treebank.tagged_words(tagset='universal')
# Out:
# [(u'Pierre', u'NOUN'), (u'Vinken', u'NOUN'), ...]

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.corpus.sinica_treebank.tagged_words()
# Out:
# [(u'\u4e00', u'Neu'), (u'\u53cb\u60c5', u'Nad'), ...]

# %%
nltk.corpus.indian.tagged_words()
# Out:
# [(u'\u09ae\u09b9\u09bf\u09b7\u09c7\u09b0', u'NN'), (u'\u09b8\u09a8\u09cd\u09a4\u09be\u09a8', u'NN'), ...]

# %%
 nltk.corpus.mac_morpho.tagged_words()
# Out:
# [(u'Jersei', u'N'), (u'atinge', u'V'), ...]

# %%
nltk.corpus.conll2002.tagged_words()
# Out:
# [(u'Sao', u'NC'), (u'Paulo', u'VMI'), (u'(', u'Fpa'), ...]

# %%
nltk.corpus.cess_cat.tagged_words()
# Out:
# [(u'El', u'da0ms0'), (u'Tribunal_Suprem', u'np0000o'), ...]

# %%
from nltk.corpus import brown
>>> brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
>>> tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
>>> tag_fd.most_common()
# Out:
# [(u'NOUN', 30654),
#  (u'VERB', 14399),
#  (u'ADP', 12355),
#  (u'.', 11928),
#  (u'DET', 11389),
#  (u'ADJ', 6706),
#  (u'ADV', 3349),
#  (u'CONJ', 2717),
#  (u'PRON', 2535),
#  (u'PRT', 2264),
#  (u'NUM', 2166),
#  (u'X', 92)]

# %%
tag_fd.plot(5, cumulative=True)

# %%
word_tag_pairs = nltk.bigrams(brown_news_tagged)
>>> noun_preceders = [a[1] for (a, b) in word_tag_pairs if b[1] == 'NOUN']
>>> fdist = nltk.FreqDist(noun_preceders)
>>> [tag for (tag, _) in fdist.most_common()]
# Out:
# [u'NOUN',
#  u'DET',
#  u'ADJ',
#  u'ADP',
#  u'.',
#  u'VERB',
#  u'CONJ',
#  u'NUM',
#  u'ADV',
#  u'PRT',
#  u'PRON',
#  u'X']

# %%
wsj = nltk.corpus.treebank.tagged_words(tagset='universal')
>>> word_tag_fd = nltk.FreqDist(wsj)
>>> [wt[0] for (wt, _) in word_tag_fd.most_common() if wt[1] == 'VERB']
# Out:
# [u'is',
#  u'said',
#  u'was',
#  u'are',
#  u'be',
#  u'has',
#  u'have',
#  u'will',
#  u'says',
#  u'would',
#  u'were',
#  u'had',
#  u'been',
#  u'could',
#  u"'s",
#  u'can',
#  u'do',
#  u'say',
#  u'make',
#  u'may',
#  u'did',
#  u'rose',
#  u'made',
#  u'does',
#  u'expected',
#  u'buy',
#  u'take',
#  u'get',
#  u'might',
#  u'sell',
#  u'added',
#  u'sold',
#  u'help',
#  u'including',
#  u'should',
#  u'reported',
#  u'according',
#  u'pay',
#  u'being',
#  u'compared',
#  u'began',
#  u'fell',
#  u'based',
#  u'closed',
#  u'used',
#  u"'re",
#  u'want',
#  u'see',
#  u'took',
#  u'yield',
#  u'priced',
#  u'offered',
#  u'set',
#  u'approved',
#  u'come',
#  u'cut',
#  u'noted',
#  u'ended',
#  u'increased',
#  u'found',
#  u'think',
#  u'become',
#  u'declined',
#  u'go',
#  u'proposed',
#  u'growing',
#  u'trying',
#  u'received',
#  u'named',
#  u'put',
#  u'give',
#  u'came',
#  u'held',
#  u'use',
#  u'paid',
#  u'going',
#  u'called',
#  u'raise',
#  u'estimated',
#  u'continue',
#  u'designed',
#  u'making',
#  u'expects',
#  u'seeking',
#  u'plans',
#  u'wo',
#  u'must',
#  u'got',
#  u'gained',
#  u'trading',
#  u'owns',
#  u'fined',
#  u'saying',
#  u'increasing',
#  u'acquired',
#  u'included',
#  u'filed',
#  u'holding',
#  u'reached',
#  u'announced',
#  u'seek',
#  u'became',
#  u'agreed',
#  u'taken',
#  u'find',
#  u'disclosed',
#  u'decided',
#  u'keep',
#  u'know',
#  u'failed',
#  u'run',
#  u'coming',
#  u'led',
#  u"'ve",
#  u'using',
#  u'traded',
#  u'lost',
#  u'built',
#  u'completed',
#  u'raised',
#  u'result',
#  u'went',
#  u'continued',
#  u'needed',
#  u'include',
#  u'told',
#  u'posted',
#  u'receive',
#  u'need',
#  u'wants',
#  u'paying',
#  u'helped',
#  u'provide',
#  u'scheduled',
#  u'believe',
#  u'indicated',
#  u'goes',
#  u'lead',
#  u'face',
#  u'caused',
#  u'ordered',
#  u'remains',
#  u"'m",
#  u'wanted',
#  u'gives',
#  u'changed',
#  u'following',
#  u'continues',
#  u'showed',
#  u'planned',
#  u'reduce',
#  u'launched',
#  u'continuing',
#  u'dropped',
#  u'includes',
#  u'issued',
#  u'believes',
#  u'like',
#  u'buying',
#  u'rise',
#  u'remain',
#  u'meet',
#  u'followed',
#  u'leading',
#  u'trade',
#  u'ca',
#  u'known',
#  u'improve',
#  u'involved',
#  u'earned',
#  u'operating',
#  u'given',
#  u'offset',
#  u'prevent',
#  u'increase',
#  u'consented',
#  u'win',
#  u'rejected',
#  u'feel',
#  u'makes',
#  u'having',
#  u'turned',
#  u'rising',
#  u'barred',
#  u'read',
#  u'seem',
#  u'asked',
#  u'build',
#  u'hurt',
#  u'sought',
#  u'aimed',
#  u'support',
#  u'begin',
#  u'introduced',
#  u'preferred',
#  u'offering',
#  u'gave',
#  u'acquire',
#  u'taking',
#  u'totaled',
#  u'carry',
#  u'required',
#  u'takes',
#  u'produced',
#  u'offer',
#  u'require',
#  u'cited',
#  u'won',
#  u'bought',
#  u'adds',
#  u'getting',
#  u'alleged',
#  u'own',
#  u'purchasing',
#  u'runs',
#  u'consider',
#  u'looking',
#  u'report',
#  u'fixed',
#  u'allowed',
#  u'advanced',
#  u'opened',
#  u'boosted',
#  u'doing',
#  u'prove',
#  u'remaining',
#  u'wrote',
#  u'giving',
#  u'considered',
#  u'left',
#  u'suspended',
#  u'hit',
#  u'close',
#  u'working',
#  u'fall',
#  u'reduced',
#  u'listed',
#  u'involving',
#  u'look',
#  u'bring',
#  u'prepared',
#  u'approve',
#  u'valued',
#  u'underlying',
#  u'boost',
#  u'losing',
#  u'mixed',
#  u'move',
#  u'extend',
#  u'selling',
#  u'appears',
#  u'described',
#  u'sells',
#  u'opposed',
#  u'seen',
#  u'let',
#  u'work',
#  u'hopes',
#  u'provided',
#  u'manufacturing',
#  u'placed',
#  u'According',
#  u'provides',
#  u'operate',
#  u'produce',
#  u'comment',
#  u'surged',
#  u'allow',
#  u'spent',
#  u'expect',
#  u'slowing',
#  u'seems',
#  u'created',
#  u'mature',
#  u'jumped',
#  u'ending',
#  u'operates',
#  u'leave',
#  u'eliminated',
#  u'violate',
#  u'seemed',
#  u'represent',
#  u'suggests',
#  u'elaborate',
#  u'settle',
#  u'avoid',
#  u'soared',
#  u"'ll",
#  u'stand',
#  u'passed',
#  u'worked',
#  u'stopped',
#  u'improved',
#  u'decline',
#  u'Says',
#  u'beginning',
#  u'force',
#  u'developed',
#  u'introduce',
#  u'shows',
#  u'asking',
#  u'becomes',
#  u'managing',
#  u'ease',
#  u'hold',
#  u'comes',
#  u'contributed',
#  u'create',
#  u'expire',
#  u'indicates',
#  u'end',
#  u'cause',
#  u'quoted',
#  u'kept',
#  u'believed',
#  u'watch',
#  u'thought',
#  u'related',
#  u'refused',
#  u'change',
#  u'raising',
#  u'threatened',
#  u'shall',
#  u'invested',
#  u'print',
#  u'eliminate',
#  u'stop',
#  u'fallen',
#  u'worried',
#  u'plunged',
#  u'appeared',
#  u'claim',
#  u'show',
#  u'fired',
#  u'met',
#  u'running',
#  u'disgorge',
#  u'file',
#  u'combined',
#  u'sent',
#  u'suggested',
#  u'suffer',
#  u'brought',
#  u'referred',
#  u'oppose',
#  u'block',
#  u'pursue',
#  u'replaced',
#  u'complete',
#  u'slow',
#  u'Take',
#  u'covered',
#  u'issue',
#  u'contain',
#  u'attributed',
#  u'managed',
#  u'argue',
#  u'occur',
#  u'succeed',
#  u'ran',
#  u'admitting',
#  u'add',
#  u'turning',
#  u'limited',
#  u'beat',
#  u'elected',
#  u'formed',
#  u'registered',
#  u'send',
#  u'requires',
#  u'shipped',
#  u'discovered',
#  u'forced',
#  u'denying',
#  u'act',
#  u'resulting',
#  u'becoming',
#  u'contained',
#  u'accused',
#  u'turn',
#  u'started',
#  u'attract',
#  u'return',
#  u'owned',
#  u'helping',
#  u'means',
#  u'matched',
#  u'done',
#  u'expanding',
#  u'happen',
#  u'developing',
#  u'playing',
#  u'finished',
#  u'focused',
#  u'thinking',
#  u'suggest',
#  u'raises',
#  u'climbed',
#  u'expressed',
#  u'confirmed',
#  u'ranged',
#  u'cutting',
#  u'attempting',
#  u'pending',
#  u"'d",
#  u'leaving',
#  u'building',
#  u'facing',
#  u'resigned',
#  u'decide',
#  u'creating',
#  u'carried',
#  u'retired',
#  u'causing',
#  u'signed',
#  u'start',
#  u'keeping',
#  u'charge',
#  u'regarding',
#  u'asks',
#  u'falling',
#  u'stay',
#  u'settled',
#  u'tried',
#  u'reporting',
#  u'voted',
#  u'discuss',
#  u'awarded',
#  u'delivered',
#  u'starting',
#  u'adjusted',
#  u'veto',
#  u'owed',
#  u'replace',
#  u'returned',
#  u'saw',
#  u'calls',
#  u'remained',
#  u'realize',
#  u'studied',
#  u'urged',
#  u'accepted',
#  u'stood',
#  u'financing',
#  u'identified',
#  u'written',
#  u'maintained',
#  u'providing',
#  u'expanded',
#  u'prompted',
#  u'moved',
#  u'follows',
#  u'offers',
#  u'expand',
#  u'bid',
#  u'adopted',
#  u'insist',
#  u'exercise',
#  u'felt',
#  u'lying',
#  u'concluded',
#  u'cover',
#  u'anticipated',
#  u'assuming',
#  u'declared',
#  u'finance',
#  u'talk',
#  u'reflect',
#  u'risk',
#  u'withdrawn',
#  u'citing',
#  u'realized',
#  u'capture',
#  u'showing',
#  u'begins',
#  u'publishing',
#  u'die',
#  u'fail',
#  u'limit',
#  u'protecting',
#  u'located',
#  u'proposing',
#  u'purchased',
#  u'profit',
#  u'spend',
#  u'learned',
#  u'worry',
#  u'marketed',
#  u'dismissed',
#  u'wait',
#  u'tied',
#  u'viewed',
#  u'care',
#  u'released',
#  u'chosen',
#  u'play',
#  u'choose',
#  u'joined',
#  u'hope',
#  u'lift',
#  u'total',
#  u'ring',
#  u'argued',
#  u'predicting',
#  u'financed',
#  u'reducing',
#  u'account',
#  u'maintaining',
#  u'exceed',
#  u'seeks',
#  u'tells',
#  u'pleased',
#  u'heard',
#  u'discussed',
#  u'considering',
#  u'treat',
#  u'reflected',
#  u'negotiate',
#  u'lowered',
#  u'declining',
#  u'sparked',
#  u'focus',
#  u'serve',
#  u'imported',
#  u'entered',
#  u'ruled',
#  u'admits',
#  u'drop',
#  u'representing',
#  u'grew',
#  u'gaining',
#  u'knows',
#  u'enters',
#  u'preventing',
#  u'live',
#  u'uses',
#  u'push',
#  u'determined',
#  u'complained',
#  u'holds',
#  u'grown',
#  u'failing',
#  u'denied',
#  u'broken',
#  u'qualified',
#  u'spread',
#  u'reflecting',
#  u'producing',
#  u'gets',
#  u'blamed',
#  u'slipped',
#  u'fueled',
#  u'encourage',
#  u'renewed',
#  u'appear',
#  u'ask',
#  u'grows',
#  u'pass',
#  u'apply',
#  u'intended',
#  u'cost',
#  u'signal',
#  u'gain',
#  u'determine',
#  u'opening',
#  u'insists',
#  u'associated',
#  u'mean',
#  u'assume',
#  u'needs',
#  u'carries',
#  u'divided',
#  u'join',
#  u'hired',
#  u'reflects',
#  u'explains',
#  u'costs',
#  u'dumped',
#  u'execute',
#  u'gotten',
#  u'caught',
#  u'heads',
#  u'receiving',
#  u'triggered',
#  u'applied',
#  u'warned',
#  u'walk',
#  u'Do',
#  u'responded',
#  u'review',
#  u'try',
#  u'speculated',
#  u'claims',
#  u'talking',
#  u'represents',
#  u'existing',
#  u'hear',
#  u'study',
#  u'obtain',
#  u'break',
#  u'mention',
#  u'targeting',
#  u'pushed',
#  u'permitted',
#  u'attend',
#  u'regarded',
#  u'dominated',
#  u'looming',
#  u'removed',
#  u'publishes',
#  u'regulated',
#  u'resolve',
#  u'shut',
#  u'Put',
#  u'protect',
#  u'withdraw',
#  u'weaken',
#  u'check',
#  u'amounted',
#  u'develop',
#  u'accommodate',
#  u'tumbled',
#  u'telling',
#  u'vote',
#  u'share',
#  u'investigating',
#  u'stands',
#  u'compete',
#  u'collected',
#  u'contends',
#  u'restructured',
#  u'accepting',
#  u'reach',
#  u'stepping',
#  u'auctioned',
#  u'subordinated',
#  u'presented',
#  u'secured',
#  u'forecast',
#  u'killed',
#  u'eliminates',
#  u'agree',
#  u'Buy',
#  u'copy',
#  u'remove',
#  u'clear',
#  u'executing',
#  u'hire',
#  u'stepped',
#  u'split',
#  u'promote',
#  u'abandoned',
#  u'occurred',
#  u'advertising',
#  u'prohibits',
#  u'curb',
#  u'turns',
#  u'changing',
#  u'spurred',
#  u'eased',
#  u'describes',
#  u'rumored',
#  u'warning',
#  u'cites',
#  u'specified',
#  u'indicate',
#  u'refund',
#  u'funded',
#  u'stem',
#  u'controlling',
#  u'extended',
#  u'supported',
#  u'conclude',
#  u'considers',
#  u'boosts',
#  u'call',
#  u'snapped',
#  u'banned',
#  u'feeling',
#  u'declaring',
#  u'predicted',
#  u'requested',
#  u'charged',
#  u'impose',
#  u'benefited',
#  u'point',
#  u'backed',
#  u'employed',
#  u'treating',
#  u'contacted',
#  u'accept',
#  u'plan',
#  u'damaged',
#  u'doubled',
#  u'offsetting',
#  u'increases',
#  u'consist',
#  u'leaves',
#  u'ought',
#  u'represented',
#  u'draw',
#  u'pointed',
#  u'employs',
#  u'drawn',
#  u'teach',
#  u'recognize',
#  u'surrendered',
#  u'deliver',
#  u'fared',
#  u'convicted',
#  u'deserve',
#  u'exercised',
#  u'improving',
#  u'covers',
#  u'retain',
#  u'edged',
#  u'notes',
#  u'executed',
#  u'yielding',
#  u'gone',
#  u'respond',
#  u'follow',
#  u'honor',
#  u'disappointed',
#  u'struggling',
#  u'expecting',
#  u'seeing',
#  u'Buying',
#  u'feared',
#  u'varying',
#  u'coupled',
#  u'marketing',
#  u'attached',
#  u'unveiled',
#  u'explained',
#  u'advertise',
#  u'breaks',
#  u'pursued',
#  u'earns',
#  u'joining',
#  u'belong',
#  u'perform',
#  u'discussing',
#  u'expelled',
#  u'booming',
#  u'restore',
#  u'died',
#  u'scrutinizing',
#  u'adding',
#  u'record',
#  u'reopen',
#  u'closing',
#  u'incurred',
#  u'printed',
#  u'committed',
#  u'insisted',
#  u'taught',
#  u'figure',
#  u'serving',
#  u'involve',
#  u'redeemed',
#  u'note',
#  u'meant',
#  u'permit',
#  u'knew',
#  u'imposed',
#  u'writing',
#  u'upheld',
#  u'revive',
#  u'trailed',
#  u'tend',
#  u'sign',
#  u'proving',
#  u'direct',
#  u'suspect',
#  u'performed',
#  u'cast',
#  u'integrated',
#  u'understand',
#  u'respected',
#  u'moving',
#  u'suspend',
#  u'revived',
#  u'grant',
#  u'stemming',
#  u'tested',
#  u'thinks',
#  u'compares',
#  u'tendered',
#  u'driving',
#  u'surviving',
#  u'played',
#  u'obtained',
#  u'jump',
#  u'ignoring',
#  u'denies',
#  u'specify',
#  u'hampered',
#  u'deny',
#  u'retained',
#  u'sink',
#  u'conduct',
#  u'drifted',
#  u'succeeded',
#  u'diluted',
#  u'strike',
#  u'transformed',
#  u'seize',
#  u'rule',
#  u'reaching',
#  u'Adds',
#  u'squeezed',
#  u'treated',
#  u'affect',
#  u'discontinued',
#  u'installed',
#  u'install',
#  u'match',
#  u'sleep',
#  u'prevents',
#  u'moderated',
#  u'stressed',
#  u'begun',
#  u'compiled',
#  u'relies',
#  u'criticized',
#  u'leveling',
#  u'claiming',
#  u'measured',
#  u'banning',
#  u'suing',
#  u'selected',
#  u'appeal',
#  u'casting',
#  u'absorbed',
#  u'plays',
#  u'balked',
#  u'belongs',
#  u'export',
#  u'lowering',
#  u'sustained',
#  u'killing',
#  u'lending',
#  u'ringing',
#  u'welcome',
#  u'link',
#  u'merge',
#  u'obligated',
#  u'contradict',
#  u'competes',
#  u'lent',
#  u'lives',
#  u'lack',
#  u'surrounding',
#  u'achieve',
#  u'vowed',
#  u'pointing',
#  u'spark',
#  u'condemned',
#  u'approach',
#  u'interviewed',
#  u'participate',
#  u'open',
#  u'occurs',
#  u'pick',
#  u'concentrated',
#  u'rushed',
#  u'diversify',
#  u'involves',
#  u'tracks',
#  u'solved',
#  u'throws',
#  u'promoting',
#  u'entitles',
#  u'place',
#  u'post',
#  u'laughing',
#  u'drove',
#  u'swap',
#  u'intend',
#  u'spur',
#  u'founded',
#  u'tune',
#  u'stored',
#  u'welcomed',
#  u'chooses',
#  u'diminished',
#  u'pegged',
#  u'violated',
#  u'doubted',
#  u'belonging',
#  u'brings',
#  u'advertised',
#  u'cope',
#  u'qualify',
#  u'signing',
#  u'regulating',
#  u'save',
#  u'limiting',
#  u'fails',
#  u'test',
#  u'engaged',
#  u'flows',
#  u'anticipates',
#  u'step',
#  u'Assuming',
#  u'risen',
#  u'blip',
#  u'weighed',
#  u'attempt',
#  u'pushing',
#  u'resulted',
#  u'fighting',
#  u'scrambling',
#  u'naming',
#  u'counts',
#  u'speaks',
#  u'pose',
#  u'concerned',
#  u'acquiring',
#  u'plunging',
#  u'concentrate',
#  u'joins',
#  u'controlled',
#  u'cautioned',
#  u'preserving',
#  u'exposed',
#  u'train',
#  u'feels',
#  u'agrees',
#  u'contracted',
#  u'kill',
#  u'commit',
#  u'fill',
#  u'calculate',
#  u'fed',
#  u'beaten',
#  u'contributing',
#  u'chastised',
#  u'modify',
#  u'sounded',
#  u'served',
#  u'gauge',
#  u'implement',
#  u'focusing',
#  u'easing',
#  u'chaired',
#  u'upset',
#  u'refuse',
#  u'ward',
#  u'defended',
#  u'drive',
#  u'transferring',
#  u'question',
#  u'competing',
#  u'range',
#  u'confined',
#  u'perceived',
#  u'targets',
#  u'attracted',
#  u'maintain',
#  u'oriented',
#  u'hitting',
#  u'operated',
#  u'tripled',
#  u'withstand',
#  u'provoke',
#  u'identify',
#  u'advised',
#  u'advancing',
#  u'write',
#  u'responding',
#  u'enables',
#  u'sweetened',
#  u'allocated',
#  u'indicating',
#  u'halted',
#  u'regard',
#  u'exchange',
#  u'letting',
#  u'assured',
#  u'loaded',
#  u'romanticized',
#  u'estimates',
#  u'putting',
#  u'feed',
#  u'spends',
#  u'adjusting',
#  u'shrinks',
#  u'terminated',
#  u'banking',
#  u'talks',
#  u'puts',
#  u'declines',
#  u'promises',
#  u'resist',
#  u'forgiven',
#  u'clarify',
#  u'withhold',
#  u'contribute',
#  ...]

# %%
cfd1 = nltk.ConditionalFreqDist(wsj)
>>> cfd1['yield'].most_common()
# Out:
# [(u'VERB', 28), (u'NOUN', 20)]

# %%
cfd1['cut'].most_common()
# Out:
# [(u'VERB', 25), (u'NOUN', 3)]

# %%
wsj = nltk.corpus.treebank.tagged_words()
>>> cfd2 = nltk.ConditionalFreqDist((tag, word) for (word, tag) in wsj)
>>> list(cfd2['VBN'])
# Out:
# [u'limited',
#  u'reorganized',
#  u'managed',
#  u'switched',
#  u'caused',
#  u'founded',
#  u'assembled',
#  u'concerned',
#  u'contained',
#  u'Rekindled',
#  u'automated',
#  u'bribed',
#  u'voted',
#  u'issued',
#  u'cluttered',
#  u'disapproved',
#  u'sent',
#  u'returned',
#  u'synchronized',
#  u'puzzled',
#  u'desired',
#  u'engineered',
#  u'headlined',
#  u'centralized',
#  u'advised',
#  u'stabbed',
#  u'continued',
#  u'perceived',
#  u'presented',
#  u'prolonged',
#  u'Related',
#  u'solved',
#  u'noted',
#  u'concluded',
#  u'Filmed',
#  u'infringed',
#  u'construed',
#  u'licensed',
#  u'knitted',
#  u'slowed',
#  u'enclosed',
#  u'replicated',
#  u'estimated',
#  u'imported',
#  u'risen',
#  u'assisted',
#  u'beaten',
#  u'contributed',
#  u'expressed',
#  u'enjoyed',
#  u'industrialized',
#  u'zoomed',
#  u'crossed',
#  u'learned',
#  u'filled',
#  u'told',
#  u'drafted',
#  u'deemed',
#  u'kicked',
#  u'led',
#  u'ranged',
#  u'slated',
#  u'reported',
#  u'focused',
#  u'auctioned',
#  u'crippled',
#  u'represented',
#  u'scrapped',
#  u'invented',
#  u'obtained',
#  u'colored',
#  u'skyrocketed',
#  u'involved',
#  u'changed',
#  u'funded',
#  u'expedited',
#  u'Founded',
#  u'diagnosed',
#  u'stressed',
#  u'postponed',
#  u'settled',
#  u'composed',
#  u'rigged',
#  u'named',
#  u'retired',
#  u'reclaimed',
#  u'distributed',
#  u'chaired',
#  u'brought',
#  u'backed',
#  u'aimed',
#  u'trained',
#  u'armed',
#  u'strapped',
#  u'fed',
#  u'handled',
#  u'answered',
#  u'coupled',
#  u'planted',
#  u'upheld',
#  u'opposed',
#  u'taken',
#  u'cited',
#  u'surveyed',
#  u'mired',
#  u'started',
#  u'clobbered',
#  u'corrected',
#  u'hurt',
#  u'tested',
#  u'known',
#  u'mounted',
#  u'Confronted',
#  u'appointed',
#  u'respected',
#  u'valued',
#  u'locked',
#  u'pushed',
#  u'plunged',
#  u'labeled',
#  u'UPHELD',
#  u'romanticized',
#  u'believed',
#  u'specialized',
#  u'performed',
#  u'meant',
#  u'indicated',
#  u'stated',
#  u'approved',
#  u'organized',
#  u'confused',
#  u'heard',
#  u'ensnarled',
#  u'dropped',
#  u'purchased',
#  u'allowed',
#  u'sought',
#  u'bolstered',
#  u'influenced',
#  u'rationed',
#  u'floated',
#  u'conducted',
#  u'dismissed',
#  u'hampered',
#  u'located',
#  u'restructured',
#  u'tried',
#  u'battered',
#  u'Funded',
#  u'derived',
#  u'confirmed',
#  u'tied',
#  u'outlawed',
#  u'halted',
#  u'fueled',
#  u'designed',
#  u'outdistanced',
#  u'chilled',
#  u'reaped',
#  u'crowded',
#  u'discontinued',
#  u'accelerated',
#  u'divided',
#  u'twinned',
#  u'executed',
#  u'finalized',
#  u'welcomed',
#  u'developed',
#  u'pointed',
#  u'installed',
#  u'produced',
#  u'held',
#  u'Absorbed',
#  u'ratified',
#  u'committed',
#  u'argued',
#  u'blocked',
#  u'revived',
#  u'hunted',
#  u'rescheduled',
#  u'chosen',
#  u'fined',
#  u'Stung',
#  u'torn',
#  u'heated',
#  u'disclosed',
#  u'covered',
#  u'hidden',
#  u'troubled',
#  u'Continued',
#  u'overcome',
#  u'stepped',
#  u'repriced',
#  u'sweetened',
#  u'anticipated',
#  u'Annualized',
#  u'qualified',
#  u'impaired',
#  u'documented',
#  u'killed',
#  u'subordinated',
#  u'matched',
#  u'mollified',
#  u'overused',
#  u'notified',
#  u'warned',
#  u'classified',
#  u'arrested',
#  u'identified',
#  u'trimmed',
#  u'deteriorated',
#  u'found',
#  u'repaired',
#  u'characterized',
#  u'referred',
#  u'lifted',
#  u'exacerbated',
#  u'fired',
#  u'populated',
#  u'cultivated',
#  u'positioned',
#  u'related',
#  u'extended',
#  u'begun',
#  u'inflated',
#  u'intended',
#  u'shown',
#  u'opened',
#  u'attracted',
#  u'laid',
#  u'dominated',
#  u'got',
#  u'integrated',
#  u'announced',
#  u'shut',
#  u'disputed',
#  u'assured',
#  u'impressed',
#  u'favored',
#  u'parched',
#  u'sparked',
#  u'threatened',
#  u'cut',
#  u'Used',
#  u'complicated',
#  u'put',
#  u'wanted',
#  u'retained',
#  u'created',
#  u'Developed',
#  u'diminished',
#  u'shipped',
#  u'competed',
#  u'incorporated',
#  u'entrusted',
#  u'fallen',
#  u'exhibited',
#  u'chopped',
#  u'secured',
#  u'Rated',
#  u'rooted',
#  u'swapped',
#  u'omitted',
#  u'reflected',
#  u'owned',
#  u'talked',
#  u'done',
#  u'suspended',
#  u'reached',
#  u'noticed',
#  u'loaded',
#  u'buoyed',
#  u'given',
#  u'rated',
#  u'renovated',
#  u'needed',
#  u'caught',
#  u'structured',
#  u'plagued',
#  u'adopted',
#  u'clarified',
#  u'listed',
#  u'passed',
#  u'averted',
#  u'consented',
#  u'completed',
#  u'diversified',
#  u'expunged',
#  u'interviewed',
#  u'rejected',
#  u'released',
#  u'rectified',
#  u'wasted',
#  u'practiced',
#  u'eliminated',
#  u'convinced',
#  u'polarized',
#  u'decided',
#  u'depressed',
#  u'gotten',
#  u'protected',
#  u'orchestrated',
#  u'treated',
#  u'Regarded',
#  u'turned',
#  u'delisted',
#  u'customized',
#  u'depleted',
#  u'cleaned',
#  u'seen',
#  u'relaunched',
#  u'linked',
#  u'viewed',
#  u'forced',
#  u'implemented',
#  u'built',
#  u'pursued',
#  u'empowered',
#  u'instructed',
#  u'oriented',
#  u'absorbed',
#  u'attempted',
#  u'provoked',
#  u'collapsed',
#  u'embroiled',
#  u'added',
#  u'altered',
#  u'paid',
#  u'serviced',
#  u'rarefied',
#  u'hired',
#  u'connected',
#  u'printed',
#  u'assessed',
#  u'alarmed',
#  u'measured',
#  u'Asked',
#  u'soared',
#  u'singled',
#  u'insured',
#  u'considered',
#  u'calculated',
#  u'upset',
#  u'cushioned',
#  u'looked',
#  u'barred',
#  u'accounted',
#  u'left',
#  u'responded',
#  u'marketed',
#  u'overpriced',
#  u'contacted',
#  u'agreed',
#  u'supported',
#  u'scattered',
#  u'flirted',
#  u'nominated',
#  u'discovered',
#  u'rusted',
#  u'superimposed',
#  u'forecast',
#  u'pleased',
#  u'based',
#  u'quoted',
#  u'earned',
#  u'surged',
#  u'inserted',
#  u'staid',
#  u'failed',
#  u'won',
#  u'judged',
#  u'equipped',
#  u'employed',
#  u'pegged',
#  u'Left',
#  u'nullified',
#  u'merged',
#  u'harvested',
#  u'borrowed',
#  u'hit',
#  u'harmed',
#  u'compiled',
#  u'banned',
#  u'designated',
#  u'preferred',
#  u'Put',
#  u'gored',
#  u'hailed',
#  u'shared',
#  u'classed',
#  u'interrogated',
#  u'justified',
#  u'ended',
#  u'tanked',
#  u'worried',
#  u'rung',
#  u'fixed',
#  u'rumored',
#  u'declared',
#  u'set',
#  u'achieved',
#  u'acquired',
#  u'instituted',
#  u'observed',
#  u'elected',
#  u'accused',
#  u'enhanced',
#  u'operated',
#  u'feared',
#  u'said',
#  u'mentioned',
#  u'served',
#  u'muted',
#  u'jumped',
#  u'diluted',
#  u'clamped',
#  u'rolled',
#  u'written',
#  u'determined',
#  u'closed',
#  u'surfaced',
#  u'drawn',
#  u'burned',
#  u'bought',
#  u'targeted',
#  u'sold',
#  u'negotiated',
#  u'tripled',
#  u'come',
#  u'faced',
#  u'received',
#  u'improved',
#  u'met',
#  u'clashed',
#  u'attributed',
#  u'milked',
#  u'coated',
#  u'planned',
#  u'publicized',
#  u'traded',
#  u'asked',
#  u'compressed',
#  u'climbed',
#  u'adjusted',
#  u'headed',
#  u'had',
#  u'maintained',
#  u'regulated',
#  u'ordered',
#  u'allocated',
#  u'withdrawn',
#  u'described',
#  u'condemned',
#  u'escalated',
#  u'been',
#  u'convicted',
#  u'defined',
#  u'combined',
#  u'expected',
#  u'entered',
#  u'chastised',
#  u'educated',
#  u'controlled',
#  u'reallocated',
#  u'painted',
#  u'offered',
#  u'formed',
#  u'priced',
#  u'finished',
#  u'tightened',
#  u'predicated',
#  u'terminated',
#  u'worked',
#  u'applied',
#  u'stacked',
#  u'abandoned',
#  u'frozen',
#  u'expanded',
#  u'expelled',
#  u'cast',
#  u'replaced',
#  u'pressed',
#  u'squeezed',
#  u'launched',
#  u'owed',
#  u'selected',
#  u'studied',
#  u'played',
#  u'dumped',
#  u'engaged',
#  u'helped',
#  u'examined',
#  u'commanded',
#  u'spooked',
#  u'amended',
#  u'grown',
#  u'overstated',
#  u'damaged',
#  u'subpoenaed',
#  u'granted',
#  u'stimulated',
#  u'split',
#  u'proved',
#  u'Posted',
#  u'used',
#  u'edged',
#  u'flooded',
#  u'boosted',
#  u'forgotten',
#  u'muffled',
#  u'nurtured',
#  u'blamed',
#  u'vowed',
#  u'midsized',
#  u'complained',
#  u'Named',
#  u'appropriated',
#  u'kept',
#  u'mortgaged',
#  u'spent',
#  u'echoed',
#  u'magnified',
#  u'thought',
#  u'relied',
#  u'Reached',
#  u'charged',
#  u'spurred',
#  u'proposed',
#  u'polled',
#  u'Given',
#  u'assigned',
#  u'recycled',
#  u'reimbursed',
#  u'advertised',
#  u'followed',
#  u'portrayed',
#  u'afflicted',
#  u'renewed',
#  u'regarded',
#  u'deprived',
#  u'guaranteed',
#  u'spread',
#  u'transformed',
#  u'born',
#  u'enacted',
#  u'excited',
#  u'surprised',
#  u'scheduled',
#  u'increased',
#  u'read',
#  u'confined',
#  u'entrenched',
#  u'accepted',
#  u'disappointed',
#  u'advanced',
#  u'imposed',
#  u'heightened',
#  u'lost',
#  u'tendered',
#  u'discarded',
#  u'become',
#  u'endorsed',
#  u'reduced',
#  u'cooled',
#  u'exposed',
#  u'scared',
#  u'financed',
#  u'Guaranteed',
#  u'understood',
#  u'experienced',
#  u'outpaced',
#  u'provided',
#  u'tracked',
#  u'recorded',
#  u'moderated',
#  u'prosecuted',
#  u'denied',
#  u'forgiven',
#  u'stopped',
#  u'beleaguered',
#  u'run',
#  u'manufactured',
#  u'refused',
#  u'broken',
#  u'murdered',
#  u'prohibited',
#  u'offset',
#  u'snapped',
#  u'exercised',
#  u'permitted',
#  u'shaken',
#  u'codified',
#  u'gained',
#  u'subdued',
#  u'carried',
#  u'obligated',
#  u'OFFERED',
#  u'discussed',
#  u'stoked',
#  u'mixed',
#  u'introduced',
#  u'wedded',
#  u'Provided',
#  u'raised',
#  u'own',
#  u'Concerned',
#  u'capped',
#  u'repaid',
#  u'speculated',
#  u'accumulated',
#  u'frightened',
#  u'prompted',
#  u'existed',
#  u'despised',
#  u'minted',
#  u'assumed',
#  u'relegated',
#  u'alleged',
#  u'liquidated',
#  u'awarded',
#  u'preapproved',
#  u'incurred',
#  u'resulted',
#  u'recruited',
#  u'touted',
#  u'revised',
#  u'triggered',
#  u'vested',
#  u'unsettled',
#  u'registered',
#  u'delayed',
#  u'collected',
#  u'lowered',
#  u'mailed',
#  u'recouped',
#  u'filed',
#  u'sustained',
#  u'removed',
#  u'posted',
#  u'directed',
#  u'made',
#  u'redeemed',
#  u'spun',
#  u'attached',
#  u'capitalized',
#  u'signed',
#  u'placed',
#  u'converted',
#  u'faded',
#  u'Estimated',
#  u'called',
#  u'detailed',
#  u'gone',
#  u'associated',
#  u'exhausted',
#  u'stripped',
#  u'specified',
#  u'moved',
#  u'fattened',
#  u'proven',
#  u'dashed',
#  u'promised',
#  u'fashioned',
#  u'watched',
#  u'compared',
#  u'initiated',
#  u'dressed',
#  u'overdone',
#  u'scrambled',
#  u'topped',
#  u'robbed',
#  u'interested',
#  u'fizzled',
#  u'requested',
#  u'obsessed',
#  u'delivered',
#  u'refunded',
#  u'felt',
#  u'prepared',
#  u'generated',
#  u'invested',
#  u'lent',
#  u'included',
#  u'decorated',
#  u'curbed',
#  u'died',
#  u'missed',
#  u'alienated',
#  u'accrued',
#  u'tailored',
#  u'required',
#  u'remarked']

# %%
 [w for w in cfd1.conditions() if 'VERB' in cfd1[w]]
# Out:
# [u'looking',
#  u'granting',
#  u'refunding',
#  u'stabbed',
#  u'bringing',
#  u'uttering',
#  u'infringed',
#  u'consists',
#  u'contributed',
#  u'designing',
#  u'increasing',
#  u'avert',
#  u'reported',
#  u'auctioned',
#  u'elaborate',
#  u'reports',
#  u'explained',
#  u'brought',
#  u'spoke',
#  u'occupying',
#  u'telegraph',
#  u'strike',
#  u'mired',
#  u'brings',
#  u'hurt',
#  u'locked',
#  u'pursue',
#  u'plunged',
#  u'organized',
#  u'reviewing',
#  u'want',
#  u'reprove',
#  u'complaining',
#  u'travel',
#  u'chase',
#  u'outlawed',
#  u'quips',
#  u'sentencing',
#  u'wins',
#  u'attracts',
#  u'scoffs',
#  u'keeps',
#  u'undo',
#  u'welcomed',
#  u'dreamed',
#  u'vary',
#  u'benefited',
#  u'secede',
#  u'hidden',
#  u'undercut',
#  u'SWITCHING',
#  u'represents',
#  u'fetching',
#  u'soaring',
#  u'precedes',
#  u'ring',
#  u'drove',
#  u'encourage',
#  u'assured',
#  u'threatened',
#  u'muscling',
#  u'estimate',
#  u'perform',
#  u'spurned',
#  u'viewing',
#  u'shipped',
#  u'competed',
#  u'shopped',
#  u'renovated',
#  u'needed',
#  u'listed',
#  u'ranging',
#  u'expunged',
#  u'rectified',
#  u'showed',
#  u'project',
#  u'feeling',
#  u'picks',
#  u'recommended',
#  u'causing',
#  u'absorbed',
#  u'committing',
#  u'retaining',
#  u'spend',
#  u'mating',
#  u'scream',
#  u'saying',
#  u'nominated',
#  u'gauge',
#  u'participate',
#  u'tempted',
#  u'copy',
#  u'clicked',
#  u'touched',
#  u'mend',
#  u'denounce',
#  u'respond',
#  u'clarified',
#  u'bled',
#  u'result',
#  u'fail',
#  u'rings',
#  u'parallels',
#  u'extend',
#  u'rolled',
#  u'authorizing',
#  u'patented',
#  u'sacrificing',
#  u'heating',
#  u'argue',
#  u'adapted',
#  u'asked',
#  u'Closes',
#  u'lift',
#  u'worked',
#  u'excited',
#  u'climbed',
#  u'anticipating',
#  u'ignoring',
#  u'damaged',
#  u'recover',
#  u'rebound',
#  u'tune',
#  u'midsized',
#  u'simulates',
#  u'echoed',
#  u'spurred',
#  u'portrayed',
#  u'succeeding',
#  u'enters',
#  u'ease',
#  u'had',
#  u'has',
#  u'lengthen',
#  u'imposed',
#  u'steps',
#  u'contributing',
#  u'continue',
#  u'summoned',
#  u'losing',
#  u'manufacturing',
#  u'Think',
#  u'shaken',
#  u'stoked',
#  u'lacked',
#  u'raised',
#  u'administer',
#  u'raises',
#  u'reducing',
#  u'authorizes',
#  u'despised',
#  u'support',
#  u'authorized',
#  u'resulted',
#  u'call',
#  u'offer',
#  u'trash',
#  u'adopt',
#  u'Sit',
#  u'disclosing',
#  u'fattened',
#  u'proven',
#  u'exist',
#  u'roll',
#  u"'s",
#  u"'d",
#  u'invested',
#  u'rolling',
#  u"'m",
#  u'time',
#  u'push',
#  u'hold',
#  u'bribed',
#  u'servicing',
#  u'stays',
#  u'trespass',
#  u'leave',
#  u'solved',
#  u'settle',
#  u'sweeten',
#  u'prevent',
#  u'sign',
#  u'lengthened',
#  u'reaffirmed',
#  u'falling',
#  u'boost',
#  u'junk',
#  u'drafted',
#  u'studied',
#  u'funded',
#  u'reclaim',
#  u'prefer',
#  u'staid',
#  u'opposes',
#  u'working',
#  u'opposed',
#  u'introducing',
#  u'specify',
#  u'rebounding',
#  u'valued',
#  u'believes',
#  u'values',
#  u'believed',
#  u'mirrors',
#  u'allowed',
#  u'divided',
#  u'contrasts',
#  u'fueled',
#  u'yielding',
#  u'pulled',
#  u'disconnect',
#  u'torn',
#  u'troubled',
#  u'reaping',
#  u'maintaining',
#  u'matched',
#  u'materialized',
#  u'pealing',
#  u'establishing',
#  u'repaired',
#  u'entering',
#  u'abide',
#  u'routes',
#  u'saving',
#  u'reopen',
#  u'vote',
#  u'open',
#  u'structured',
#  u'indicate',
#  u'cite',
#  u'proving',
#  u'surged',
#  u'depressed',
#  u'addressing',
#  u'Regarded',
#  u'turned',
#  u'say',
#  u'saw',
#  u'instructed',
#  u'note',
#  u'take',
#  u'destroy',
#  u'Observing',
#  u'altered',
#  u'Getting',
#  u'knew',
#  u'buffet',
#  u'printed',
#  u'inserted',
#  u'cushioned',
#  u'twinned',
#  u'walking',
#  u'merit',
#  u'PORTING',
#  u'slow',
#  u'going',
#  u'equipped',
#  u'directed',
#  u'condemning',
#  u'Having',
#  u'worried',
#  u'worries',
#  u'jumped',
#  u'affecting',
#  u'concentrate',
#  u'awards',
#  u'spark',
#  u'concentrated',
#  u'oust',
#  u'considers',
#  u'cleared',
#  u'combines',
#  u'stretch',
#  u'concede',
#  u'combined',
#  u'wants',
#  u'enable',
#  u'formed',
#  u'curbing',
#  u'engineering',
#  u'perpetuate',
#  u'engaged',
#  u'limping',
#  u'spooked',
#  u'threatens',
#  u'edged',
#  u'boosted',
#  u'tracking',
#  u'Says',
#  u'customized',
#  u'costs',
#  u'being',
#  u'recycled',
#  u'reimbursed',
#  u'underline',
#  u'color',
#  u'redistributing',
#  u'subordinated',
#  u'discarded',
#  u'explaining',
#  u'arrested',
#  u'thinks',
#  u'tote',
#  u'industrialized',
#  u'retraced',
#  u'act',
#  u'mean',
#  u'fundraising',
#  u'apologize',
#  u'accumulated',
#  u'complete',
#  u'buying',
#  u'pull',
#  u'naming',
#  u'agree',
#  u'detailed',
#  u'gone',
#  u'exhausted',
#  u'am',
#  u'watched',
#  u'refunded',
#  u'shipping',
#  u'waived',
#  u'waive',
#  u'consider',
#  u'caused',
#  u'causes',
#  u'illustrates',
#  u'returned',
#  u'puzzled',
#  u'floated',
#  u'hitting',
#  u'encroaching',
#  u'laying',
#  u'joined',
#  u'sank',
#  u'pass',
#  u'contrast',
#  u'experience',
#  u'followed',
#  u'reclaimed',
#  u'select',
#  u'initiated',
#  u'corrected',
#  u'competes',
#  u'tested',
#  u'keeping',
#  u'installing',
#  u'Citing',
#  u'evolved',
#  u'learn',
#  u'knocked',
#  u'stated',
#  u'states',
#  u'sense',
#  u'dismissed',
#  u'functioning',
#  u'intended',
#  u'refuse',
#  u'broadcasting',
#  u'granted',
#  u'trade',
#  u'termed',
#  u'skipped',
#  u'propose',
#  u'buys',
#  u'outlawing',
#  u'speculate',
#  u'labeling',
#  u'found',
#  u'reduce',
#  u'Related',
#  u'risen',
#  u'sparked',
#  u'stemmed',
#  u'qualify',
#  u'imagine',
#  u"C'mon",
#  u'retained',
#  u'exhibited',
#  u'rooted',
#  u'slipped',
#  u'succeeded',
#  u'recruiting',
#  u'differ',
#  u'heads',
#  u'jet',
#  u'grapple',
#  u'implements',
#  u'focusing',
#  u'stifle',
#  u'polarized',
#  u'Concerned',
#  u'defends',
#  u'determined',
#  u'guarding',
#  u'sell',
#  u'recognizing',
#  u'jostle',
#  u'play',
#  u'plan',
#  u'accepting',
#  u'singled',
#  u'understands',
#  u'seize',
#  u'cover',
#  u'barred',
#  u'attacking',
#  u'despise',
#  u'flirted',
#  u'defended',
#  u'expressed',
#  u'failed',
#  u'begins',
#  u'banned',
#  u'cry',
#  u'tanked',
#  u'banking',
#  u'rumored',
#  u'sew',
#  u'set',
#  u'bundling',
#  u'instituted',
#  u'see',
#  u'muted',
#  u'diluted',
#  u'targeted',
#  u'enables',
#  u'offending',
#  u'improves',
#  u'approve',
#  u'load',
#  u'underperforming',
#  u'acted',
#  u'publishing',
#  u'evoking',
#  u'AGREES',
#  u'convicted',
#  u'raced',
#  u'mind',
#  u'fund',
#  u'engage',
#  u'Starting',
#  u'expanded',
#  u'receive',
#  u'pressed',
#  u'evaluating',
#  u'owed',
#  u'backing',
#  u'relaunched',
#  u'prescribe',
#  u'resulting',
#  u'flooded',
#  u'recovered',
#  u'leapt',
#  u'climb',
#  u'Named',
#  u'alleging',
#  u'regulating',
#  u'befuddled',
#  u'plagued',
#  u'outstrips',
#  u'signals',
#  u'crying',
#  u'surprised',
#  u'projects',
#  u'sorting',
#  u'relied',
#  u'concedes',
#  u'bounce',
#  u'shall',
#  u'benefit',
#  u'prosecuted',
#  u'dating',
#  u'be',
#  u'performed',
#  u'looming',
#  u'relating',
#  u'cranked',
#  u'zip',
#  u'selected',
#  u'repaid',
#  u'Used',
#  u'spending',
#  u'submit',
#  u'suit',
#  u'opens',
#  u'mitigate',
#  u'inched',
#  u'link',
#  u'line',
#  u'posted',
#  u'redeemed',
#  u'mature',
#  u'faded',
#  u'defined',
#  u'chat',
#  u'defines',
#  u'scrape',
#  u'preventing',
#  u'researching',
#  u'tailored',
#  u'land',
#  u'mailing',
#  u'carrying',
#  u'came',
#  u'having',
#  u'broaden',
#  u'existing',
#  u'centers',
#  u'seemed',
#  u'impeding',
#  u'concerned',
#  u'send',
#  u'citing',
#  u'dislike',
#  u'sent',
#  u'continues',
#  u'reopened',
#  u'continued',
#  u'experiencing',
#  u'try',
#  u'licensed',
#  u'imply',
#  u'enclosed',
#  u'led',
#  u'delivering',
#  u'let',
#  u'invented',
#  u'involved',
#  u'defeat',
#  u'makes',
#  u'explain',
#  u'involves',
#  u'reserved',
#  u'recalling',
#  u'occurred',
#  u'practicing',
#  u'Can',
#  u'challenge',
#  u'insists',
#  u'pour',
#  u'prompts',
#  u'slid',
#  u'lock',
#  u'bend',
#  u'slip',
#  u'weaken',
#  u'struggling',
#  u'blocks',
#  u'tied',
#  u'halted',
#  u'demonstrating',
#  u'realized',
#  u'allow',
#  u'move',
#  u'produced',
#  u'delay',
#  u'chosen',
#  u'Excluding',
#  u'realize',
#  u'wallowing',
#  u'undertaking',
#  u'traced',
#  u'merge',
#  u'accounts',
#  u'exacerbated',
#  u'doing',
#  u'shut',
#  u'dubbed',
#  u'could',
#  u'assumed',
#  u'owned',
#  u'disposed',
#  u'buoyed',
#  u'ordering',
#  u'accompany',
#  u'split',
#  u'reacted',
#  u'appealing',
#  u'orchestrated',
#  u'collecting',
#  u'accusing',
#  u'shrinks',
#  u'denouncing',
#  u'viewed',
#  u'prohibits',
#  u'test-drive',
#  u'studying',
#  u'equaling',
#  u'embroiled',
#  u'asserts',
#  u'pitches',
#  u'Asked',
#  u'face',
#  u'hunker',
#  u'assert',
#  u'centralized',
#  u'bring',
#  u'should',
#  u'riding',
#  u'hope',
#  u'meant',
#  u'handle',
#  u'shaping',
#  u'withstand',
#  u'ends',
#  u'restricting',
#  u'negotiated',
#  u'adjusted',
#  u'conclude',
#  u'ca',
#  u'allocated',
#  u'underlying',
#  u'poured',
#  u'chastised',
#  u'rigged',
#  u'harmed',
#  u'planned',
#  u'fielded',
#  u'drink',
#  u'expand',
#  u'audit',
#  u'diversify',
#  u'drawing',
#  u'restructure',
#  u'softening',
#  u'Given',
#  u'predicts',
#  u'hauled',
#  u'afflicted',
#  u'crack',
#  u'increased',
#  u'impaired',
#  u'checking',
#  u'increases',
#  u'starting',
#  u'become',
#  u'underwent',
#  u'Guaranteed',
#  u'choosing',
#  u'flush',
#  u'avoid',
#  u'sketching',
#  u'does',
#  u'forgiven',
#  u'brokering',
#  u'pressure',
#  u'gained',
#  u'puts',
#  u'assess',
#  u'erect',
#  u'cultivated',
#  u'thwart',
#  u'terminated',
#  u'justifying',
#  u'restricts',
#  u'building',
#  u'lowered',
#  u'placed',
#  u'bearing',
#  u'recognize',
#  u'contribute',
#  u'slowing',
#  u'compared',
#  u'compares',
#  u'undercutting',
#  u'lasted',
#  u'rule',
#  u'write',
#  u'compete',
#  u'searched',
#  u'saved',
#  u'sputtered',
#  u'bludgeon',
#  u'voted',
#  u'overpaying',
#  u'shoot',
#  u'announced',
#  u'abolishing',
#  u'shedding',
#  u'established',
#  u'zoomed',
#  u'consisting',
#  u'told',
#  u'equals',
#  u'redeploy',
#  u'obtained',
#  u'stressed',
#  u'postponed',
#  u'pledged',
#  u'total',
#  u'played',
#  u'Competes',
#  u'ascribe',
#  u'work',
#  u'eclipse',
#  u'deprived',
#  u'Standing',
#  u'indicated',
#  u'cited',
#  u'belonging',
#  u'indicates',
#  u'cites',
#  u'totaled',
#  u'provide',
#  u'overstated',
#  u'transforming',
#  u'lay',
#  u'suing',
#  u'foundering',
#  u'chilled',
#  u'devote',
#  u'bans',
#  u'break',
#  u'classified',
#  u'feeds',
#  u'entitled',
#  u'lifted',
#  u'evolve',
#  u'impede',
#  u'hosted',
#  u'proscribes',
#  u'occurs',
#  u'disputed',
#  u'veto',
#  u'recovering',
#  u'created',
#  u'creates',
#  u'renew',
#  u'oppose',
#  u'incorporated',
#  u'chopped',
#  u'doling',
#  u'rated',
#  u'rates',
#  u'diversified',
#  u'rejected',
#  u'wasted',
#  u'target',
#  u'rewrite',
#  u'forced',
#  u'forces',
#  u'acquire',
#  u'sue',
#  u'exercised',
#  u'involving',
#  u'phase',
#  u'assessed',
#  u'calculated',
#  u'accounted',
#  u'disturbs',
#  u'enjoyed',
#  u'nullified',
#  u'do',
#  u'preferred',
#  u'yielded',
#  u'gored',
#  u'runs',
#  u'covering',
#  u'rung',
#  u'steal',
#  u'observed',
#  u'scrutinizing',
#  u'draws',
#  u'drawn',
#  u'wo',
#  u'received',
#  u'demobilize',
#  u'receives',
#  u'disappears',
#  u'refile',
#  u'speak',
#  u'skidded',
#  u'condemned',
#  u'applied',
#  u'inhibit',
#  u'harms',
#  u'air',
#  u'aim',
#  u'aid',
#  u'launched',
#  u'dumped',
#  u'wooing',
#  u'confirmed',
#  u'exuded',
#  u'blames',
#  u'hang',
#  u'blamed',
#  u'kept',
#  u'quoted',
#  u'ratcheting',
#  u'firmed',
#  u'clamped',
#  u'adding',
#  u'fared',
#  u'belongs',
#  u'transformed',
#  u'expelled',
#  u'injuring',
#  u'erodes',
#  u'lapses',
#  u'cooled',
#  u'sends',
#  u'eyeing',
#  u'glamorize',
#  u'denies',
#  u'born',
#  u'comments',
#  u'asking',
#  u'arrest',
#  u'denied',
#  u'marketing',
#  u'pose',
#  u'restructuring',
#  u'graduated',
#  u'post',
#  u'commanded',
#  u'rallying',
#  u'shared',
#  u'photocopy',
#  u'wield',
#  u'Make',
#  u'sparing',
#  u'extending',
#  u'capped',
#  u'Judging',
#  u'liquidated',
#  u'was',
#  u'sagging',
#  u'entrenched',
#  u'becoming',
#  u'Left',
#  u'responding',
#  u'inquiring',
#  u'promises',
#  u'promised',
#  u'stake',
#  u'profess',
#  u'presumes',
#  u'interested',
#  u'winning',
#  u'holding',
#  u'test',
#  u'mulling',
#  u'complains',
#  u'stick',
#  u'strengthened',
#  u'battle',
#  u'devoted',
#  u'compensate',
#  u'disapproved',
#  u'perceived',
#  u'presented',
#  u'altering',
#  u'turns',
#  u'perceives',
#  u'convince',
#  u'cost',
#  u'appear',
#  u'appeal',
#  u'teaches',
#  u'appears',
#  u'change',
#  u'retired',
#  u'lending',
#  u'retires',
#  u'prove',
#  u'live',
#  u'planted',
#  u'defeats',
#  u'labeled',
#  u'can',
#  u'stimulating',
#  u'rebuffed',
#  u'expanding',
#  u'heard',
#  u'posing',
#  u'occur',
#  u'fuming',
#  u'means',
#  u'entrench',
#  u'influenced',
#  u'sacrifice',
#  u'use',
#  u'averted',
#  u'produce',
#  u'flourish',
#  u'accelerated',
#  u'offend',
#  u'serving',
#  u'stayed',
#  u'tendering',
#  u'acknowledge',
#  u'halt',
#  u'sweetened',
#  u'introduce',
#  u'discuss',
#  u'enacted',
#  u'fumes',
#  u'drop',
#  u'prompted',
#  u'directing',
#  u'happen',
#  u'calling',
#  u'shown',
#  u'opened',
#  u'increase',
#  u'receiving',
#  u'shows',
#  u'rebuilding',
#  u'tightening',
#  u'care',
#  u'chose',
#  u'entrusted',
#  u'omitted',
#  u'capitalize',
#  u'caught',
#  u'eliminates',
#  u'eliminated',
#  u'recruit',
#  u'remained',
#  u'offering',
#  u'awaits',
#  u'begin',
#  u'scaring',
#  u'hamstrung',
#  u'discovered',
#  u'celebrate',
#  u'builds',
#  u'reorganized',
#  u'elected',
#  u'concern',
#  u'suspects',
#  u'import',
#  u'justified',
#  u'jeopardizing',
#  u'Estimated',
#  u'enabling',
#  u'fined',
#  u'comes',
#  u'exploit',
#  u'proved',
#  u'rebuild',
#  u'Depending',
#  u'cared',
#  u'abating',
#  u'discontinuing',
#  u'subjecting',
#  u'abridging',
#  u'developing',
#  u'accounting',
#  u'return',
#  u'ship',
#  u'worry',
#  u'develop',
#  u'angered',
#  u'predispose',
#  u'complained',
#  u'charges',
#  u'alleviate',
#  u'coordinate',
#  u'charged',
#  u'sweeping',
#  u'touch',
#  u'wrestling',
#  u'speed',
#  u'renewed',
#  u'thinking',
#  u'read',
#  u'discontinue',
#  u'using',
#  u'ruled',
#  u'heightened',
#  u'endorsed',
#  u'exposed',
#  u'intend',
#  u'recorded',
#  u'APPEARS',
#  u'balked',
#  u'assemble',
#  u'emasculate',
#  u'heated',
#  u'shrinking',
#  u'stare',
#  u'log',
#  u'prepare',
#  u'start',
#  u'DIALING',
#  u'recouped',
#  u"'S",
#  u'trying',
#  u'copied',
#  u'hire',
#  u'improved',
#  u'default',
#  u'describe',
#  u'moved',
#  u'moves',
#  u'forcing',
#  ...]

# %%
idx1 = wsj.index(('kicked', 'VBD'))
>>> wsj[idx1-4:idx1+1]
# Out:
# [(u'While', u'IN'),
#  (u'program', u'NN'),
#  (u'trades', u'NNS'),
#  (u'swiftly', u'RB'),
#  (u'kicked', u'VBD')]

# %%
idx2 = wsj.index(('kicked', 'VBN'))
>>> wsj[idx2-4:idx2+1]
# Out:
# [(u'head', u'NN'),
#  (u'of', u'IN'),
#  (u'state', u'NN'),
#  (u'has', u'VBZ'),
#  (u'kicked', u'VBN')]

# %%
list(cfd2['VBN'])
# Out:
# [u'limited',
#  u'reorganized',
#  u'managed',
#  u'switched',
#  u'caused',
#  u'founded',
#  u'assembled',
#  u'concerned',
#  u'contained',
#  u'Rekindled',
#  u'automated',
#  u'bribed',
#  u'voted',
#  u'issued',
#  u'cluttered',
#  u'disapproved',
#  u'sent',
#  u'returned',
#  u'synchronized',
#  u'puzzled',
#  u'desired',
#  u'engineered',
#  u'headlined',
#  u'centralized',
#  u'advised',
#  u'stabbed',
#  u'continued',
#  u'perceived',
#  u'presented',
#  u'prolonged',
#  u'Related',
#  u'solved',
#  u'noted',
#  u'concluded',
#  u'Filmed',
#  u'infringed',
#  u'construed',
#  u'licensed',
#  u'knitted',
#  u'slowed',
#  u'enclosed',
#  u'replicated',
#  u'estimated',
#  u'imported',
#  u'risen',
#  u'assisted',
#  u'beaten',
#  u'contributed',
#  u'expressed',
#  u'enjoyed',
#  u'industrialized',
#  u'zoomed',
#  u'crossed',
#  u'learned',
#  u'filled',
#  u'told',
#  u'drafted',
#  u'deemed',
#  u'kicked',
#  u'led',
#  u'ranged',
#  u'slated',
#  u'reported',
#  u'focused',
#  u'auctioned',
#  u'crippled',
#  u'represented',
#  u'scrapped',
#  u'invented',
#  u'obtained',
#  u'colored',
#  u'skyrocketed',
#  u'involved',
#  u'changed',
#  u'funded',
#  u'expedited',
#  u'Founded',
#  u'diagnosed',
#  u'stressed',
#  u'postponed',
#  u'settled',
#  u'composed',
#  u'rigged',
#  u'named',
#  u'retired',
#  u'reclaimed',
#  u'distributed',
#  u'chaired',
#  u'brought',
#  u'backed',
#  u'aimed',
#  u'trained',
#  u'armed',
#  u'strapped',
#  u'fed',
#  u'handled',
#  u'answered',
#  u'coupled',
#  u'planted',
#  u'upheld',
#  u'opposed',
#  u'taken',
#  u'cited',
#  u'surveyed',
#  u'mired',
#  u'started',
#  u'clobbered',
#  u'corrected',
#  u'hurt',
#  u'tested',
#  u'known',
#  u'mounted',
#  u'Confronted',
#  u'appointed',
#  u'respected',
#  u'valued',
#  u'locked',
#  u'pushed',
#  u'plunged',
#  u'labeled',
#  u'UPHELD',
#  u'romanticized',
#  u'believed',
#  u'specialized',
#  u'performed',
#  u'meant',
#  u'indicated',
#  u'stated',
#  u'approved',
#  u'organized',
#  u'confused',
#  u'heard',
#  u'ensnarled',
#  u'dropped',
#  u'purchased',
#  u'allowed',
#  u'sought',
#  u'bolstered',
#  u'influenced',
#  u'rationed',
#  u'floated',
#  u'conducted',
#  u'dismissed',
#  u'hampered',
#  u'located',
#  u'restructured',
#  u'tried',
#  u'battered',
#  u'Funded',
#  u'derived',
#  u'confirmed',
#  u'tied',
#  u'outlawed',
#  u'halted',
#  u'fueled',
#  u'designed',
#  u'outdistanced',
#  u'chilled',
#  u'reaped',
#  u'crowded',
#  u'discontinued',
#  u'accelerated',
#  u'divided',
#  u'twinned',
#  u'executed',
#  u'finalized',
#  u'welcomed',
#  u'developed',
#  u'pointed',
#  u'installed',
#  u'produced',
#  u'held',
#  u'Absorbed',
#  u'ratified',
#  u'committed',
#  u'argued',
#  u'blocked',
#  u'revived',
#  u'hunted',
#  u'rescheduled',
#  u'chosen',
#  u'fined',
#  u'Stung',
#  u'torn',
#  u'heated',
#  u'disclosed',
#  u'covered',
#  u'hidden',
#  u'troubled',
#  u'Continued',
#  u'overcome',
#  u'stepped',
#  u'repriced',
#  u'sweetened',
#  u'anticipated',
#  u'Annualized',
#  u'qualified',
#  u'impaired',
#  u'documented',
#  u'killed',
#  u'subordinated',
#  u'matched',
#  u'mollified',
#  u'overused',
#  u'notified',
#  u'warned',
#  u'classified',
#  u'arrested',
#  u'identified',
#  u'trimmed',
#  u'deteriorated',
#  u'found',
#  u'repaired',
#  u'characterized',
#  u'referred',
#  u'lifted',
#  u'exacerbated',
#  u'fired',
#  u'populated',
#  u'cultivated',
#  u'positioned',
#  u'related',
#  u'extended',
#  u'begun',
#  u'inflated',
#  u'intended',
#  u'shown',
#  u'opened',
#  u'attracted',
#  u'laid',
#  u'dominated',
#  u'got',
#  u'integrated',
#  u'announced',
#  u'shut',
#  u'disputed',
#  u'assured',
#  u'impressed',
#  u'favored',
#  u'parched',
#  u'sparked',
#  u'threatened',
#  u'cut',
#  u'Used',
#  u'complicated',
#  u'put',
#  u'wanted',
#  u'retained',
#  u'created',
#  u'Developed',
#  u'diminished',
#  u'shipped',
#  u'competed',
#  u'incorporated',
#  u'entrusted',
#  u'fallen',
#  u'exhibited',
#  u'chopped',
#  u'secured',
#  u'Rated',
#  u'rooted',
#  u'swapped',
#  u'omitted',
#  u'reflected',
#  u'owned',
#  u'talked',
#  u'done',
#  u'suspended',
#  u'reached',
#  u'noticed',
#  u'loaded',
#  u'buoyed',
#  u'given',
#  u'rated',
#  u'renovated',
#  u'needed',
#  u'caught',
#  u'structured',
#  u'plagued',
#  u'adopted',
#  u'clarified',
#  u'listed',
#  u'passed',
#  u'averted',
#  u'consented',
#  u'completed',
#  u'diversified',
#  u'expunged',
#  u'interviewed',
#  u'rejected',
#  u'released',
#  u'rectified',
#  u'wasted',
#  u'practiced',
#  u'eliminated',
#  u'convinced',
#  u'polarized',
#  u'decided',
#  u'depressed',
#  u'gotten',
#  u'protected',
#  u'orchestrated',
#  u'treated',
#  u'Regarded',
#  u'turned',
#  u'delisted',
#  u'customized',
#  u'depleted',
#  u'cleaned',
#  u'seen',
#  u'relaunched',
#  u'linked',
#  u'viewed',
#  u'forced',
#  u'implemented',
#  u'built',
#  u'pursued',
#  u'empowered',
#  u'instructed',
#  u'oriented',
#  u'absorbed',
#  u'attempted',
#  u'provoked',
#  u'collapsed',
#  u'embroiled',
#  u'added',
#  u'altered',
#  u'paid',
#  u'serviced',
#  u'rarefied',
#  u'hired',
#  u'connected',
#  u'printed',
#  u'assessed',
#  u'alarmed',
#  u'measured',
#  u'Asked',
#  u'soared',
#  u'singled',
#  u'insured',
#  u'considered',
#  u'calculated',
#  u'upset',
#  u'cushioned',
#  u'looked',
#  u'barred',
#  u'accounted',
#  u'left',
#  u'responded',
#  u'marketed',
#  u'overpriced',
#  u'contacted',
#  u'agreed',
#  u'supported',
#  u'scattered',
#  u'flirted',
#  u'nominated',
#  u'discovered',
#  u'rusted',
#  u'superimposed',
#  u'forecast',
#  u'pleased',
#  u'based',
#  u'quoted',
#  u'earned',
#  u'surged',
#  u'inserted',
#  u'staid',
#  u'failed',
#  u'won',
#  u'judged',
#  u'equipped',
#  u'employed',
#  u'pegged',
#  u'Left',
#  u'nullified',
#  u'merged',
#  u'harvested',
#  u'borrowed',
#  u'hit',
#  u'harmed',
#  u'compiled',
#  u'banned',
#  u'designated',
#  u'preferred',
#  u'Put',
#  u'gored',
#  u'hailed',
#  u'shared',
#  u'classed',
#  u'interrogated',
#  u'justified',
#  u'ended',
#  u'tanked',
#  u'worried',
#  u'rung',
#  u'fixed',
#  u'rumored',
#  u'declared',
#  u'set',
#  u'achieved',
#  u'acquired',
#  u'instituted',
#  u'observed',
#  u'elected',
#  u'accused',
#  u'enhanced',
#  u'operated',
#  u'feared',
#  u'said',
#  u'mentioned',
#  u'served',
#  u'muted',
#  u'jumped',
#  u'diluted',
#  u'clamped',
#  u'rolled',
#  u'written',
#  u'determined',
#  u'closed',
#  u'surfaced',
#  u'drawn',
#  u'burned',
#  u'bought',
#  u'targeted',
#  u'sold',
#  u'negotiated',
#  u'tripled',
#  u'come',
#  u'faced',
#  u'received',
#  u'improved',
#  u'met',
#  u'clashed',
#  u'attributed',
#  u'milked',
#  u'coated',
#  u'planned',
#  u'publicized',
#  u'traded',
#  u'asked',
#  u'compressed',
#  u'climbed',
#  u'adjusted',
#  u'headed',
#  u'had',
#  u'maintained',
#  u'regulated',
#  u'ordered',
#  u'allocated',
#  u'withdrawn',
#  u'described',
#  u'condemned',
#  u'escalated',
#  u'been',
#  u'convicted',
#  u'defined',
#  u'combined',
#  u'expected',
#  u'entered',
#  u'chastised',
#  u'educated',
#  u'controlled',
#  u'reallocated',
#  u'painted',
#  u'offered',
#  u'formed',
#  u'priced',
#  u'finished',
#  u'tightened',
#  u'predicated',
#  u'terminated',
#  u'worked',
#  u'applied',
#  u'stacked',
#  u'abandoned',
#  u'frozen',
#  u'expanded',
#  u'expelled',
#  u'cast',
#  u'replaced',
#  u'pressed',
#  u'squeezed',
#  u'launched',
#  u'owed',
#  u'selected',
#  u'studied',
#  u'played',
#  u'dumped',
#  u'engaged',
#  u'helped',
#  u'examined',
#  u'commanded',
#  u'spooked',
#  u'amended',
#  u'grown',
#  u'overstated',
#  u'damaged',
#  u'subpoenaed',
#  u'granted',
#  u'stimulated',
#  u'split',
#  u'proved',
#  u'Posted',
#  u'used',
#  u'edged',
#  u'flooded',
#  u'boosted',
#  u'forgotten',
#  u'muffled',
#  u'nurtured',
#  u'blamed',
#  u'vowed',
#  u'midsized',
#  u'complained',
#  u'Named',
#  u'appropriated',
#  u'kept',
#  u'mortgaged',
#  u'spent',
#  u'echoed',
#  u'magnified',
#  u'thought',
#  u'relied',
#  u'Reached',
#  u'charged',
#  u'spurred',
#  u'proposed',
#  u'polled',
#  u'Given',
#  u'assigned',
#  u'recycled',
#  u'reimbursed',
#  u'advertised',
#  u'followed',
#  u'portrayed',
#  u'afflicted',
#  u'renewed',
#  u'regarded',
#  u'deprived',
#  u'guaranteed',
#  u'spread',
#  u'transformed',
#  u'born',
#  u'enacted',
#  u'excited',
#  u'surprised',
#  u'scheduled',
#  u'increased',
#  u'read',
#  u'confined',
#  u'entrenched',
#  u'accepted',
#  u'disappointed',
#  u'advanced',
#  u'imposed',
#  u'heightened',
#  u'lost',
#  u'tendered',
#  u'discarded',
#  u'become',
#  u'endorsed',
#  u'reduced',
#  u'cooled',
#  u'exposed',
#  u'scared',
#  u'financed',
#  u'Guaranteed',
#  u'understood',
#  u'experienced',
#  u'outpaced',
#  u'provided',
#  u'tracked',
#  u'recorded',
#  u'moderated',
#  u'prosecuted',
#  u'denied',
#  u'forgiven',
#  u'stopped',
#  u'beleaguered',
#  u'run',
#  u'manufactured',
#  u'refused',
#  u'broken',
#  u'murdered',
#  u'prohibited',
#  u'offset',
#  u'snapped',
#  u'exercised',
#  u'permitted',
#  u'shaken',
#  u'codified',
#  u'gained',
#  u'subdued',
#  u'carried',
#  u'obligated',
#  u'OFFERED',
#  u'discussed',
#  u'stoked',
#  u'mixed',
#  u'introduced',
#  u'wedded',
#  u'Provided',
#  u'raised',
#  u'own',
#  u'Concerned',
#  u'capped',
#  u'repaid',
#  u'speculated',
#  u'accumulated',
#  u'frightened',
#  u'prompted',
#  u'existed',
#  u'despised',
#  u'minted',
#  u'assumed',
#  u'relegated',
#  u'alleged',
#  u'liquidated',
#  u'awarded',
#  u'preapproved',
#  u'incurred',
#  u'resulted',
#  u'recruited',
#  u'touted',
#  u'revised',
#  u'triggered',
#  u'vested',
#  u'unsettled',
#  u'registered',
#  u'delayed',
#  u'collected',
#  u'lowered',
#  u'mailed',
#  u'recouped',
#  u'filed',
#  u'sustained',
#  u'removed',
#  u'posted',
#  u'directed',
#  u'made',
#  u'redeemed',
#  u'spun',
#  u'attached',
#  u'capitalized',
#  u'signed',
#  u'placed',
#  u'converted',
#  u'faded',
#  u'Estimated',
#  u'called',
#  u'detailed',
#  u'gone',
#  u'associated',
#  u'exhausted',
#  u'stripped',
#  u'specified',
#  u'moved',
#  u'fattened',
#  u'proven',
#  u'dashed',
#  u'promised',
#  u'fashioned',
#  u'watched',
#  u'compared',
#  u'initiated',
#  u'dressed',
#  u'overdone',
#  u'scrambled',
#  u'topped',
#  u'robbed',
#  u'interested',
#  u'fizzled',
#  u'requested',
#  u'obsessed',
#  u'delivered',
#  u'refunded',
#  u'felt',
#  u'prepared',
#  u'generated',
#  u'invested',
#  u'lent',
#  u'included',
#  u'decorated',
#  u'curbed',
#  u'died',
#  u'missed',
#  u'alienated',
#  u'accrued',
#  u'tailored',
#  u'required',
#  u'remarked']

# %%
def findtags(tag_prefix, tagged_text):
    cfd = nltk.ConditionalFreqDist((tag, word) for (word, tag) in tagged_text
                                  if tag.startswith(tag_prefix))
    return dict((tag, cfd[tag].most_common(5)) for tag in cfd.conditions())

# %%
tagdict = findtags('NN', nltk.corpus.brown.tagged_words(categories='news'))
>>> for tag in sorted(tagdict):
...     print(tag, tagdict[tag])
# Out:
# (u'NN', [(u'year', 137), (u'time', 97), (u'state', 88), (u'week', 85), (u'man', 72)])
# (u'NN$', [(u"year's", 13), (u"world's", 8), (u"state's", 7), (u"nation's", 6), (u"company's", 6)])
# (u'NN$-HL', [(u"Golf's", 1), (u"Navy's", 1)])
# (u'NN$-TL', [(u"President's", 11), (u"University's", 3), (u"League's", 3), (u"Gallery's", 3), (u"Army's", 3)])
# (u'NN-HL', [(u'cut', 2), (u'Salary', 2), (u'condition', 2), (u'Question', 2), (u'business', 2)])
# (u'NN-NC', [(u'eva', 1), (u'ova', 1), (u'aya', 1)])
# (u'NN-TL', [(u'President', 88), (u'House', 68), (u'State', 59), (u'University', 42), (u'City', 41)])
# (u'NN-TL-HL', [(u'Fort', 2), (u'City', 1), (u'Commissioner', 1), (u'Grove', 1), (u'House', 1)])
# (u'NNS', [(u'years', 101), (u'members', 69), (u'people', 52), (u'sales', 51), (u'men', 46)])
# (u'NNS$', [(u"children's", 7), (u"women's", 5), (u"men's", 3), (u"janitors'", 3), (u"taxpayers'", 2)])
# (u'NNS$-HL', [(u"Dealers'", 1), (u"Idols'", 1)])
# (u'NNS$-TL', [(u"Women's", 4), (u"States'", 3), (u"Giants'", 2), (u"Officers'", 1), (u"Bombers'", 1)])
# (u'NNS-HL', [(u'years', 1), (u'idols', 1), (u'Creations', 1), (u'thanks', 1), (u'centers', 1)])
# (u'NNS-TL', [(u'States', 38), (u'Nations', 11), (u'Masters', 10), (u'Rules', 9), (u'Communists', 9)])
# (u'NNS-TL-HL', [(u'Nations', 1)])

# %%
brown_learned_text = brown.words(categories='learned')
>>> sorted(set(b for (a, b) in nltk.bigrams(brown_learned_text) if a == 'often'))
# Out:
# [u',',
#  u'.',
#  u'accomplished',
#  u'analytically',
#  u'appear',
#  u'apt',
#  u'associated',
#  u'assuming',
#  u'became',
#  u'become',
#  u'been',
#  u'began',
#  u'call',
#  u'called',
#  u'carefully',
#  u'chose',
#  u'classified',
#  u'colorful',
#  u'composed',
#  u'contain',
#  u'differed',
#  u'difficult',
#  u'encountered',
#  u'enough',
#  u'equate',
#  u'extremely',
#  u'found',
#  u'happens',
#  u'have',
#  u'ignored',
#  u'in',
#  u'involved',
#  u'more',
#  u'needed',
#  u'nightly',
#  u'observed',
#  u'of',
#  u'on',
#  u'out',
#  u'quite',
#  u'represent',
#  u'responsible',
#  u'revamped',
#  u'seclude',
#  u'set',
#  u'shortened',
#  u'sing',
#  u'sounded',
#  u'stated',
#  u'still',
#  u'sung',
#  u'supported',
#  u'than',
#  u'to',
#  u'when',
#  u'work']

# %%
brown_lrnd_tagged = brown.tagged_words(categories='learned', tagset='universal')
>>> tags = [b[1] for (a, b) in nltk.bigrams(brown_lrnd_tagged) if a[0] == 'often']
>>> fd = nltk.FreqDist(tags)
>>> fd.tabulate()
# Out:
# VERB  ADV  ADP  ADJ    .  PRT
#   37    8    7    6    4    2

# %%
from nltk.corpus import brown
def process(sentence):
    for (w1,t1), (w2,t2), (w3,t3) in nltk.trigrams(sentence):
        if (t1.startswith('V') and t2 == 'TO' and t3.startswith('V')):
            print(w1, w2, w3)

# %%
for tagged_sent in brown.tagged_sents():
...     process(tagged_sent)
# Out:
# (u'combined', u'to', u'achieve')
# (u'continue', u'to', u'place')
# (u'serve', u'to', u'protect')
# (u'wanted', u'to', u'wait')
# (u'allowed', u'to', u'place')
# (u'expected', u'to', u'become')
# (u'expected', u'to', u'approve')
# (u'expected', u'to', u'make')
# (u'intends', u'to', u'make')
# (u'seek', u'to', u'set')
# (u'like', u'to', u'see')
# (u'designed', u'to', u'provide')
# (u'get', u'to', u'hear')
# (u'expects', u'to', u'tell')
# (u'expected', u'to', u'give')
# (u'prefer', u'to', u'pay')
# (u'required', u'to', u'obtain')
# (u'permitted', u'to', u'teach')
# (u'designed', u'to', u'reduce')
# (u'Asked', u'to', u'elaborate')
# (u'got', u'to', u'go')
# (u'raised', u'to', u'pay')
# (u'scheduled', u'to', u'go')
# (u'cut', u'to', u'meet')
# (u'needed', u'to', u'meet')
# (u'hastened', u'to', u'add')
# (u'found', u'to', u'prevent')
# (u'continue', u'to', u'insist')
# (u'compelled', u'to', u'make')
# (u'made', u'to', u'remove')
# (u'revamped', u'to', u'give')
# (u'want', u'to', u'risk')
# (u'appear', u'to', u'spark')
# (u'fails', u'to', u'consider')
# (u'plans', u'to', u'call')
# (u'going', u'to', u'examine')
# (u'plans', u'to', u'name')
# (u'come', u'to', u'pass')
# (u'voted', u'to', u'accept')
# (u'happens', u'to', u'hold')
# (u'authorized', u'to', u'adopt')
# (u'hesitated', u'to', u'prosecute')
# (u'try', u'to', u'make')
# (u'decided', u'to', u'spend')
# (u'taken', u'to', u'preserve')
# (u'left', u'to', u'preserve')
# (u'stand', u'to', u'bring')
# (u'decided', u'to', u'seek')
# (u'trying', u'to', u'induce')
# (u'proposing', u'to', u'make')
# (u'decided', u'to', u'run')
# (u'directed', u'to', u'investigate')
# (u'expected', u'to', u'pass')
# (u'expected', u'to', u'make')
# (u'expected', u'to', u'encounter')
# (u'hopes', u'to', u'pass')
# (u'came', u'to', u'pay')
# (u'expected', u'to', u'receive')
# (u'understood', u'to', u'follow')
# (u'wanted', u'to', u'vote')
# (u'decide', u'to', u'call')
# (u'begin', u'to', u'flow')
# (u'appears', u'to', u'face')
# (u'fails', u'to', u'pass')
# (u'care', u'to', u'acknowledge')
# (u'like', u'to', u'convey')
# (u'continued', u'to', u'wage')
# (u'try', u'to', u'avoid')
# (u'done', u'to', u'arouse')
# (u'tried', u'to', u'economize')
# (u'agreed', u'to', u'cooperate')
# (u'want', u'to', u'find')
# (u'expected', u'to', u'raise')
# (u'agreed', u'to', u'form')
# (u'threatened', u'to', u'form')
# (u'failed', u'to', u'sign')
# (u'trying', u'to', u'build')
# (u'plan', u'to', u'absorb')
# (u'working', u'to', u'establish')
# (u'expects', u'to', u'evacuate')
# (u'need', u'to', u'hear')
# (u'scheduled', u'to', u'hold')
# (u'decided', u'to', u'ask')
# (u'scheduled', u'to', u'fill')
# (u'going', u'to', u'determine')
# (u'urged', u'to', u'move')
# (u'conpired', u'to', u'use')
# (u'used', u'to', u'carry')
# (u'needed', u'to', u'face')
# (u'failed', u'to', u'tally')
# (u'failed', u'to', u'produce')
# (u'tried', u'to', u'stretch')
# (u'hopes', u'to', u'melt')
# (u'slated', u'to', u'oppose')
# (u'scheduled', u'to', u'share')
# (u'plans', u'to', u'bring')
# (u'seek', u'to', u'trim')
# (u'seems', u'to', u'improve')
# (u'appeared', u'to', u'win')
# (u'gets', u'to', u'play')
# (u'hopes', u'to', u'start')
# (u'tried', u'to', u'teach')
# (u'seem', u'to', u'get')
# (u'started', u'to', u'form')
# (u'like', u'to', u'keep')
# (u'want', u'to', u'talk')
# (u'continue', u'to', u'abide')
# (u'refused', u'to', u'reconsider')
# (u'expected', u'to', u'put')
# (u'resigned', u'to', u'take')
# (u'sought', u'to', u'convince')
# (u'tried', u'to', u'blast')
# (u'tried', u'to', u'keep')
# (u'happened', u'to', u'think')
# (u'expected', u'to', u'continue')
# (u'plans', u'to', u'open')
# (u'recovering', u'to', u'make')
# (u'supposed', u'to', u'deliver')
# (u'get', u'to', u'like')
# (u'want', u'to', u'thank')
# (u'set', u'to', u'play')
# (u'going', u'to', u'pass')
# (u'paid', u'to', u'play')
# (u'wanted', u'to', u'pop')
# (u'expect', u'to', u'establish')
# (u'going', u'to', u'try')
# (u'try', u'to', u'get')
# (u'signed', u'to', u'play')
# (u'fly', u'to', u'collect')
# (u'helps', u'to', u'bridge')
# (u'wants', u'to', u'pick')
# (u'relearns', u'to', u'mingle')
# (u'watching', u'to', u'see')
# (u'learn', u'to', u'readjust')
# (u'promises', u'to', u'follow')
# (u'expect', u'to', u'offer')
# (u'like', u'to', u'come')
# (u'like', u'to', u'bring')
# (u'combined', u'to', u'form')
# (u'chosen', u'to', u'rule')
# (u'attempted', u'to', u'stop')
# (u'required', u'to', u'use')
# (u'prepared', u'to', u'grant')
# (u'refused', u'to', u'return')
# (u'demanded', u'to', u'know')
# (u'decided', u'to', u'end')
# (u'offered', u'to', u'supply')
# (u'designed', u'to', u'seek')
# (u'get', u'to', u'know')
# (u'get', u'to', u'know')
# (u'going', u'to', u'call')
# (u'attempted', u'to', u'end')
# (u'forbidden', u'to', u'drive')
# (u'failed', u'to', u'reach')
# (u'wish', u'to', u'appear')
# (u'hopes', u'to', u'rebuild')
# (u'used', u'to', u'provide')
# (u'wanted', u'to', u'make')
# (u'trying', u'to', u'land')
# (u'prepared', u'to', u'accept')
# (u'continue', u'to', u'operate')
# (u'taken', u'to', u'overcome')
# (u'intend', u'to', u'make')
# (u'desiring', u'to', u'study')
# (u'designed', u'to', u'assure')
# (u'intend', u'to', u'attend')
# (u'failed', u'to', u'cooperate')
# (u'agree', u'to', u'attend')
# (u'decided', u'to', u'attend')
# (u'scheduled', u'to', u'begin')
# (u'agreed', u'to', u'meet')
# (u'failed', u'to', u'show')
# (u'declined', u'to', u'name')
# (u'tried', u'to', u'subdue')
# (u'planning', u'to', u'expand')
# (u'thought', u'to', u'infest')
# (u'voted', u'to', u'decertify')
# (u'designed', u'to', u'give')
# (u'continued', u'to', u'run')
# (u'failed', u'to', u'place')
# (u'started', u'to', u'turn')
# (u'bought', u'to', u'provide')
# (u'asked', u'to', u'set')
# (u'vote', u'to', u'appeal')
# (u'failed', u'to', u'reach')
# (u'failed', u'to', u'destroy')
# (u'encouraged', u'to', u'try')
# (u'try', u'to', u'get')
# (u'managed', u'to', u'maneuver')
# (u'obligated', u'to', u'make')
# (u'promised', u'to', u'get')
# (u'attempting', u'to', u'connect')
# (u'prepared', u'to', u'answer')
# (u'failed', u'to', u'report')
# (u'attempted', u'to', u'cash')
# (u'wanting', u'to', u'get')
# (u'combined', u'to', u'make')
# (u'continue', u'to', u'grab')
# (u'designed', u'to', u'provide')
# (u'appear', u'to', u'favor')
# (u'declined', u'to', u'suggest')
# (u'expected', u'to', u'advance')
# (u'required', u'to', u'reach')
# (u'fail', u'to', u'give')
# (u'began', u'to', u'come')
# (u'undertake', u'to', u'reply')
# (u'found', u'to', u'deal')
# (u'forced', u'to', u'buy')
# (u'starting', u'to', u'get')
# (u'inclined', u'to', u'explain')
# (u'supposed', u'to', u'look')
# (u'chose', u'to', u'take')
# (u'used', u'to', u'emphasize')
# (u'seem', u'to', u'realize')
# (u'happen', u'to', u'grow')
# (u'tried', u'to', u'compromise')
# (u'scheduled', u'to', u'arrive')
# (u'prefer', u'to', u'see')
# (u'set', u'to', u'open')
# (u'expected', u'to', u'prove')
# (u'try', u'to', u'influence')
# (u'strive', u'to', u'set')
# (u'decided', u'to', u'try')
# (u'try', u'to', u'let')
# (u'asked', u'to', u'read')
# (u'prepared', u'to', u'demonstrate')
# (u'led', u'to', u'believe')
# (u'went', u'to', u'see')
# (u'begun', u'to', u'pall')
# (u'going', u'to', u'get')
# (u'painted', u'to', u'match')
# (u'appointed', u'to', u'serve')
# (u'expected', u'to', u'register')
# (u'failed', u'to', u'materialize')
# (u'wanted', u'to', u'buy')
# (u'begin', u'to', u'implement')
# (u'tended', u'to', u'confirm')
# (u'want', u'to', u'appear')
# (u'try', u'to', u'probe')
# (u'determined', u'to', u'apply')
# (u'come', u'to', u'warn')
# (u'known', u'to', u'rely')
# (u'try', u'to', u'exploit')
# (u'tended', u'to', u'cancel')
# (u'cease', u'to', u'marvel')
# (u'seem', u'to', u'represent')
# (u'seems', u'to', u'show')
# (u'declines', u'to', u'gamble')
# (u'needs', u'to', u'feel')
# (u'advanced', u'to', u'argue')
# (u'undertakes', u'to', u'fight')
# (u'decided', u'to', u'keep')
# (u'advertising', u'to', u'attract')
# (u'wants', u'to', u'operate')
# (u'varied', u'to', u'provide')
# (u'designed', u'to', u'reduce')
# (u'use', u'to', u'deny')
# (u'combining', u'to', u'lower')
# (u'combining', u'to', u'raise')
# (u'intended', u'to', u'effect')
# (u'tend', u'to', u'convert')
# (u'exist', u'to', u'raise')
# (u'wish', u'to', u'prevent')
# (u'wish', u'to', u'preserve')
# (u'attempting', u'to', u'extend')
# (u'made', u'to', u'take')
# (u'continue', u'to', u'set')
# (u'trying', u'to', u'persuade')
# (u'attempted', u'to', u'take')
# (u'decided', u'to', u'break')
# (u'braced', u'to', u'move')
# (u'needed', u'to', u'keep')
# (u'used', u'to', u'carry')
# (u'decided', u'to', u'go')
# (u'happens', u'to', u'benefit')
# (u'attempted', u'to', u'work')
# (u'decided', u'to', u'join')
# (u'said', u'to', u'regard')
# (u'sought', u'to', u'bring')
# (u'want', u'to', u'give')
# (u'voting', u'to', u'cut')
# (u'prepared', u'to', u'choke')
# (u'used', u'to', u'approach')
# (u'trying', u'to', u'hit')
# (u'refused', u'to', u'let')
# (u'began', u'to', u'acquire')
# (u'proceeded', u'to', u'sink')
# (u'proceeded', u'to', u'follow')
# (u'hoping', u'to', u'slice')
# (u'chose', u'to', u'hit')
# (u'like', u'to', u'hit')
# (u'tries', u'to', u'answer')
# (u'want', u'to', u'talk')
# (u'got', u'to', u'get')
# (u'used', u'to', u'follow')
# (u'try', u'to', u'play')
# (u'conspired', u'to', u'lose')
# (u'needed', u'to', u'revive')
# (u'chosen', u'to', u'run')
# (u'hopes', u'to', u'visit')
# (u'got', u'to', u'see')
# (u'arranged', u'to', u'sell')
# (u'delighted', u'to', u'get')
# (u'want', u'to', u'enjoy')
# (u'tried', u'to', u'get')
# (u'try', u'to', u'close')
# (u'required', u'to', u'furnish')
# (u'obliged', u'to', u'dole')
# (u'wished', u'to', u'wait')
# (u'decided', u'to', u'act')
# (u'hoped', u'to', u'attend')
# (u'like', u'to', u'woo')
# (u'prepared', u'to', u'discuss')
# (u'wanted', u'to', u'go')
# (u'allowed', u'to', u'file')
# (u'tried', u'to', u'persuade')
# (u'began', u'to', u'tell')
# (u'hoped', u'to', u'peddle')
# (u'intended', u'to', u'insure')
# (u'decided', u'to', u'provide')
# (u'expected', u'to', u'go')
# (u'expected', u'to', u'sign')
# (u'like', u'to', u'eat')
# (u'like', u'to', u'talk')
# (u'ceased', u'to', u'grumble')
# (u'tending', u'to', u'bid')
# (u'start', u'to', u'pay')
# (u'failed', u'to', u'measure')
# (u'going', u'to', u'take')
# (u'needed', u'to', u'push')
# (u'trying', u'to', u'get')
# (u'try', u'to', u'get')
# (u'want', u'to', u'increase')
# (u'wants', u'to', u'bring')
# (u'threaten', u'to', u'strike')
# (u'begun', u'to', u'grow')
# (u'combine', u'to', u'serve')
# (u'helping', u'to', u'strengthen')
# (u'designed', u'to', u'promote')
# (u'threatening', u'to', u'expand')
# (u'seeks', u'to', u'get')
# (u'begin', u'to', u'see')
# (u'continue', u'to', u'expand')
# (u'failing', u'to', u'render')
# (u'decided', u'to', u'tackle')
# (u'expects', u'to', u'sign')
# (u'tends', u'to', u'become')
# (u'came', u'to', u'understand')
# (u'deserve', u'to', u'breathe')
# (u'advised', u'to', u'seek')
# (u'attempting', u'to', u'make')
# (u'try', u'to', u'gun')
# (u'began', u'to', u'fill')
# (u'proposes', u'to', u'preserve')
# (u'asked', u'to', u'approve')
# (u'seeking', u'to', u'break')
# (u'tends', u'to', u'spread')
# (u'want', u'to', u'amend')
# (u'rejected', u'to', u'seek')
# (u'continued', u'to', u'speak')
# (u'trying', u'to', u'make')
# (u'expected', u'to', u'head')
# (u'tempted', u'to', u'let')
# (u'appear', u'to', u'cost')
# (u'attempt', u'to', u'shore')
# (u'seeking', u'to', u'achieve')
# (u'expected', u'to', u'report')
# (u'born', u'to', u'play')
# (u'promising', u'to', u'build')
# (u'minded', u'to', u'read')
# (u'hope', u'to', u'win')
# (u'threatened', u'to', u'ignite')
# (u'beginning', u'to', u'take')
# (u'flew', u'to', u'exert')
# (u'proceed', u'to', u'validate')
# (u'continues', u'to', u'feel')
# (u'want', u'to', u'make')
# (u'going', u'to', u'get')
# (u'attempt', u'to', u'rewrite')
# (u'purport', u'to', u'advocate')
# (u'seeking', u'to', u'capitalize')
# (u'exist', u'to', u'aid')
# (u'learn', u'to', u'put')
# (u'tends', u'to', u'create')
# (u'promised', u'to', u'eat')
# (u'hopes', u'to', u'include')
# (u'moving', u'to', u'create')
# (u'prepared', u'to', u'undertake')
# (u'conspired', u'to', u'overthrow')
# (u'seem', u'to', u'feel')
# (u'decided', u'to', u'keep')
# (u'applied', u'to', u'serve')
# (u'try', u'to', u'seize')
# (u'lead', u'to', u'involving')
# (u'cut', u'to', u'allow')
# (u'hope', u'to', u'enjoy')
# (u'likes', u'to', u'receive')
# (u'delighted', u'to', u'learn')
# (u'going', u'to', u'expand')
# (u'authorized', u'to', u'deliver')
# (u'going', u'to', u'can')
# (u'going', u'to', u'close')
# (u'supposed', u'to', u'make')
# (u'try', u'to', u'raise')
# (u'tried', u'to', u'settle')
# (u'pass', u'to', u'enter')
# (u'came', u'to', u'tell')
# (u'wanted', u'to', u'grab')
# (u'stops', u'to', u'think')
# (u'expect', u'to', u'get')
# (u'chosen', u'to', u'answer')
# (u'motivated', u'to', u'seek')
# (u'disposed', u'to', u'covet')
# (u'like', u'to', u'lie')
# (u'going', u'to', u'tell')
# (u'prepared', u'to', u'accept')
# (u'try', u'to', u'stop')
# (u'try', u'to', u'stop')
# (u'sought', u'to', u'break')
# (u'inclined', u'to', u'look')
# (u'begun', u'to', u'act')
# (u'elect', u'to', u'slow')
# (u'like', u'to', u'challenge')
# (u'going', u'to', u'move')
# (u'asked', u'to', u'carry')
# (u'expect', u'to', u'stop')
# (u'expect', u'to', u'reduce')
# (u'expected', u'to', u'supply')
# (u'supposed', u'to', u'win')
# (u'seems', u'to', u'lack')
# (u'tends', u'to', u'treat')
# (u'like', u'to', u'share')
# (u'try', u'to', u'treat')
# (u'try', u'to', u'bring')
# (u'try', u'to', u'give')
# (u'continue', u'to', u'lack')
# (u'learn', u'to', u'color')
# (u'slated', u'to', u'replace')
# (u'strive', u'to', u'put')
# (u'intends', u'to', u'provide')
# (u'try', u'to', u'solve')
# (u'decided', u'to', u'use')
# (u'try', u'to', u'end')
# (u'going', u'to', u'take')
# (u'trying', u'to', u'organize')
# (u'permitted', u'to', u'repair')
# (u'trying', u'to', u'find')
# (u'planned', u'to', u'rival')
# (u'seems', u'to', u'speak')
# (u'tried', u'to', u'dissuade')
# (u'tends', u'to', u'shimmy')
# (u'designed', u'to', u'teach')
# (u'prepared', u'to', u'teach')
# (u'wanted', u'to', u'sign')
# (u'made', u'to', u'act')
# (u'continue', u'to', u'influence')
# (u'begins', u'to', u'notice')
# (u'expected', u'to', u'win')
# (u'seek', u'to', u'find')
# (u'join', u'to', u'defeat')
# (u'meant', u'to', u'repeat')
# (u'trying', u'to', u'downgrade')
# (u'tried', u'to', u'guard')
# (u'want', u'to', u'separate')
# (u'seem', u'to', u'indicate')
# (u'afford', u'to', u'buy')
# (u'try', u'to', u'develop')
# (u'attempting', u'to', u'attract')
# (u'compelled', u'to', u'write')
# (u'failed', u'to', u'set')
# (u'continue', u'to', u'shape')
# (u'wants', u'to', u'study')
# (u'wants', u'to', u'study')
# (u'equipped', u'to', u'care')
# (u'expected', u'to', u'survive')
# (u'shocked', u'to', u'see')
# (u'going', u'to', u'play')
# (u'voted', u'to', u'aid')
# (u'died', u'to', u'uphold')
# (u'urged', u'to', u'reduce')
# (u'wish', u'to', u'state')
# (u'expected', u'to', u'give')
# (u'trying', u'to', u'maintain')
# (u'attempt', u'to', u'seek')
# (u'wishes', u'to', u'commend')
# (u'qualified', u'to', u'teach')
# (u'want', u'to', u'let')
# (u'informed', u'to', u'report')
# (u'planning', u'to', u'shelter')
# (u'plans', u'to', u'sit')
# (u'continue', u'to', u'inquire')
# (u'began', u'to', u'realize')
# (u'refuse', u'to', u'acknowledge')
# (u'required', u'to', u'certify')
# (u'desire', u'to', u'participate')
# (u'hasten', u'to', u'join')
# (u'like', u'to', u'question')
# (u'needed', u'to', u'help')
# (u'prepared', u'to', u'care')
# (u'like', u'to', u'suggest')
# (u'fear', u'to', u'negotiate')
# (u'tried', u'to', u'prevent')
# (u'refusing', u'to', u'pay')
# (u'like', u'to', u'quote')
# (u'transfer', u'to', u'ride')
# (u'managed', u'to', u'automate')
# (u'expected', u'to', u'pay')
# (u'collected', u'to', u'buy')
# (u'continue', u'to', u'provide')
# (u'wish', u'to', u'congratulate')
# (u'help', u'to', u'turn')
# (u'try', u'to', u'keep')
# (u'try', u'to', u'frighten')
# (u'wish', u'to', u'advocate')
# (u'expect', u'to', u'see')
# (u'refuse', u'to', u'aid')
# (u'needs', u'to', u'stand')
# (u'strives', u'to', u'emulate')
# (u'refusing', u'to', u'show')
# (u'seems', u'to', u'match')
# (u'decided', u'to', u'rake')
# (u'entitled', u'to', u'stay')
# (u'bringing', u'to', u'bear')
# (u'beginning', u'to', u'get')
# (u'threaten', u'to', u'use')
# (u'begin', u'to', u'play')
# (u'begin', u'to', u'hunt')
# (u'induced', u'to', u'see')
# (u'going', u'to', u'hang')
# (u'continue', u'to', u'test')
# (u'choose', u'to', u'agree')
# (u'chosen', u'to', u'find')
# (u'compelled', u'to', u'conduct')
# (u'need', u'to', u'realize')
# (u'used', u'to', u'justify')
# (u'fail', u'to', u'respond')
# (u'intends', u'to', u'economize')
# (u'bound', u'to', u'say')
# (u'trying', u'to', u'mollify')
# (u'used', u'to', u'say')
# (u'came', u'to', u'reassert')
# (u'choose', u'to', u'call')
# (u'intend', u'to', u're-enter')
# (u'conscripted', u'to', u'enact')
# (u'continues', u'to', u'feed')
# (u'tried', u'to', u'integrate')
# (u'poised', u'to', u'strike')
# (u'try', u'to', u'force')
# (u'attempting', u'to', u'reach')
# (u'afford', u'to', u'take')
# (u'forbidden', u'to', u'sit')
# (u'plans', u'to', u'import')
# (u'likes', u'to', u'imagine')
# (u'used', u'to', u'get')
# (u'trying', u'to', u'make')
# (u'ceased', u'to', u'suggest')
# (u'going', u'to', u'work')
# (u'wanting', u'to', u'cut')
# (u'choose', u'to', u'persuade')
# (u'trying', u'to', u'keep')
# (u'like', u'to', u'embark')
# (u'suited', u'to', u'defeat')
# (u'hastened', u'to', u'put')
# (u'like', u'to', u'add')
# (u'want', u'to', u'preserve')
# (u'required', u'to', u'participate')
# (u'happened', u'to', u'save')
# (u'doing', u'to', u'promote')
# (u'tempted', u'to', u'quote')
# (u'continuing', u'to', u'capture')
# (u'need', u'to', u'communicate')
# (u'like', u'to', u'see')
# (u'interested', u'to', u'know')
# (u'allowed', u'to', u'rust')
# (u'chose', u'to', u'devote')
# (u'left', u'to', u'choose')
# (u'want', u'to', u'own')
# (u'plan', u'to', u'become')
# (u'persuaded', u'to', u'restock')
# (u'seems', u'to', u'improve')
# (u'arranged', u'to', u'permit')
# (u'seem', u'to', u'lend')
# (u'allowed', u'to', u'mix')
# (u'starts', u'to', u'swing')
# (u'seems', u'to', u'stop')
# (u'ordered', u'to', u'hold')
# (u'fitted', u'to', u'endure')
# (u'trying', u'to', u'follow')
# (u'threatening', u'to', u'explode')
# (u'rides', u'to', u'break')
# (u'managed', u'to', u'make')
# (u'dancing', u'to', u'display')
# (u'hasten', u'to', u'report')
# (u'seems', u'to', u'come')
# (u'reassuring', u'to', u'see')
# (u'profess', u'to', u'know')
# (u'help', u'to', u'explain')
# (u'forced', u'to', u'rely')
# (u'attempt', u'to', u'homogenize')
# (u'like', u'to', u'put')
# (u'continue', u'to', u'try')
# (u'try', u'to', u'come')
# (u'seem', u'to', u'deal')
# (u'decide', u'to', u'let')
# (u'tries', u'to', u'take')
# (u'trying', u'to', u'forget')
# (u'trying', u'to', u'acquire')
# (u'threatens', u'to', u'linger')
# (u'decided', u'to', u'forego')
# (u'managed', u'to', u'hold')
# (u'intended', u'to', u'illustrate')
# (u'tried', u'to', u'get')
# (u'learn', u'to', u'live')
# (u'helping', u'to', u'move')
# (u'striving', u'to', u'hold')
# (u'choose', u'to', u'work')
# (u'tried', u'to', u'see')
# (u'trying', u'to', u'create')
# (u'made', u'to', u'appear')
# (u'failed', u'to', u'make')
# (u'seemed', u'to', u'deserve')
# (u'managed', u'to', u'mix')
# (u'want', u'to', u'hurt')
# (u'liked', u'to', u'nip')
# (u'manages', u'to', u'acquire')
# (u'widened', u'to', u'enchant')
# (u'serve', u'to', u'contradict')
# (u'dare', u'to', u'experiment')
# (u'tried', u'to', u'humanize')
# (u'tries', u'to', u'preserve')
# (u'helps', u'to', u'rebut')
# (u'seems', u'to', u'make')
# (u'began', u'to', u'play')
# (u'cares', u'to', u'remember')
# (u'serve', u'to', u'show')
# (u'want', u'to', u'collect')
# (u'designed', u'to', u'invite')
# (u'attempt', u'to', u'make')
# (u'designed', u'to', u'belong')
# (u'seem', u'to', u'come')
# (u'wanted', u'to', u'identify')
# (u'neglect', u'to', u'cultivate')
# (u'chooses', u'to', u'lead')
# (u'chosen', u'to', u'sing')
# (u'expected', u'to', u'follow')
# (u'formed', u'to', u'spur')
# (u'tends', u'to', u'shy')
# (u'seeking', u'to', u'become')
# (u'tries', u'to', u'make')
# (u'began', u'to', u'change')
# (u'try', u'to', u'solve')
# (u'formed', u'to', u'fill')
# (u'determined', u'to', u'avoid')
# (u'seems', u'to', u'work')
# (u'began', u'to', u'fall')
# (u'began', u'to', u'depart')
# (u'refused', u'to', u'give')
# (u'like', u'to', u'sniff')
# (u'continue', u'to', u'demonstrate')
# (u'begins', u'to', u'wilt')
# (u'going', u'to', u'murder')
# (u'trying', u'to', u'puzzle')
# (u'expects', u'to', u'profit')
# (u'chooses', u'to', u'die')
# (u'wishes', u'to', u'pay')
# (u'conditioned', u'to', u'expect')
# (u'hoped', u'to', u'tell')
# (u'refusing', u'to', u'make')
# (u'intended', u'to', u'stop')
# (u'failed', u'to', u'lead')
# (u'need', u'to', u'discipline')
# (u'attempts', u'to', u'trace')
# (u'conspire', u'to', u'defy')
# (u'learning', u'to', u'think')
# (u'wants', u'to', u'know')
# (u'wants', u'to', u'supply')
# (u'begin', u'to', u'look')
# (u'start', u'to', u'think')
# (u'attempt', u'to', u'say')
# (u'come', u'to', u'feel')
# (u'supposed', u'to', u'put')
# (u'called', u'to', u'work')
# (u'continue', u'to', u'exist')
# (u'observed', u'to', u'characterize')
# (u'continue', u'to', u'alienate')
# (u'continue', u'to', u'preach')
# (u'means', u'to', u'say')
# (u'fit', u'to', u'place')
# (u'concerned', u'to', u'stand')
# (u'strive', u'to', u'formulate')
# (u'proceeded', u'to', u'give')
# (u'offer', u'to', u'remind')
# (u'offered', u'to', u'allow')
# (u'requested', u'to', u'teach')
# (u'said', u'to', u'repeat')
# (u'mean', u'to', u'say')
# (u'inclined', u'to', u'extenuate')
# (u'came', u'to', u'rescue')
# (u'venture', u'to', u'assert')
# (u'come', u'to', u'destroy')
# (u'compelled', u'to', u'ask')
# (u'begins', u'to', u'look')
# (u'refuse', u'to', u'accept')
# (u'entitled', u'to', u'excoriate')
# (u'come', u'to', u'occupy')
# (u'prepared', u'to', u'resort')
# (u'obliged', u'to', u'become')
# (u'disposed', u'to', u'allow')
# (u'prepared', u'to', u'give')
# (u'trying', u'to', u'continue')
# (u'continue', u'to', u'use')
# (u'attempting', u'to', u'bridge')
# (u'destined', u'to', u'live')
# (u'daring', u'to', u'trust')
# (u'called', u'to', u'stand')
# (u'die', u'to', u'save')
# (u'told', u'to', u'express')
# (u'supposed', u'to', u'perform')
# (u'designed', u'to', u'give')
# (u'fear', u'to', u'negotiate')
# (u'threatening', u'to', u'devour')
# (u'try', u'to', u'escape')
# (u'tried', u'to', u'swim')
# (u'learn', u'to', u'say')
# (u'threatening', u'to', u'eat')
# (u'remains', u'to', u'show')
# (u'attempted', u'to', u'analyze')
# (u'tried', u'to', u'consider')
# (u'begin', u'to', u'talk')
# (u'tended', u'to', u'stifle')
# (u'begin', u'to', u'understand')
# (u'fail', u'to', u'achieve')
# (u'made', u'to', u'keep')
# (u'desiring', u'to', u'unite')
# (u'invited', u'to', u'speak')
# (u'hesitate', u'to', u'ask')
# (u'trying', u'to', u'make')
# (u'help', u'to', u'determine')
# (u'combine', u'to', u'provide')
# (u'attempt', u'to', u'compensate')
# (u'learn', u'to', u'recognize')
# (u'serve', u'to', u'promote')
# (u'claim', u'to', u'incarnate')
# (u'led', u'to', u'emphasize')
# (u'tend', u'to', u'consider')
# (u'expected', u'to', u'seek')
# (u'disposed', u'to', u'compromise')
# (u'served', u'to', u'provide')
# (u'mean', u'to', u'imply')
# (u'mean', u'to', u'imply')
# (u'attempts', u'to', u'face')
# (u'need', u'to', u'submit')
# (u'prepared', u'to', u'run')
# (u'asked', u'to', u'choose')
# (u'continuing', u'to', u'incur')
# (u'seems', u'to', u'think')
# (u'begin', u'to', u'amass')
# (u'sought', u'to', u'limit')
# (u'bring', u'to', u'bear')
# (u'invited', u'to', u'participate')
# (u'sought', u'to', u'bring')
# (u'attempting', u'to', u'explore')
# (u'seen', u'to', u'consist')
# (u'committed', u'to', u'avoid')
# (u'claim', u'to', u'serve')
# (u'determined', u'to', u'avoid')
# (u'trying', u'to', u'converse')
# (u'started', u'to', u'adjust')
# (u'trying', u'to', u'make')
# (u'decided', u'to', u'take')
# (u'forced', u'to', u'conclude')
# (u'beginning', u'to', u'make')
# (u'helped', u'to', u'make')
# (u'made', u'to', u'give')
# (u'determined', u'to', u'exclude')
# (u'sought', u'to', u'win')
# (u'sought', u'to', u'avoid')
# (u'meant', u'to', u'incur')
# (u'supposed', u'to', u'result')
# (u'cited', u'to', u'show')
# (u'supposed', u'to', u'possess')
# (u'burned', u'to', u'make')
# (u'wanted', u'to', u'find')
# (u'helps', u'to', u'meet')
# (u'rejoiced', u'to', u'see')
# (u'began', u'to', u'suspect')
# (u'began', u'to', u'review')
# (u'called', u'to', u'sit')
# (u'began', u'to', u'write')
# (u'decided', u'to', u'try')
# (u'takes', u'to', u'tell')
# (u'seemed', u'to', u'widen')
# (u'proceeded', u'to', u'teach')
# (u'helps', u'to', u'make')
# (u'remember', u'to', u'make')
# (u'supposed', u'to', u'like')
# (u'working', u'to', u'improve')
# (u'like', u'to', u'make')
# (u'added', u'to', u'encourage')
# (u'like', u'to', u'shear')
# (u'needs', u'to', u'tell')
# (u'like', u'to', u'grow')
# (u'allowed', u'to', u'mature')
# (u'used', u'to', u'attack')
# (u'continued', u'to', u'threaten')
# (u'decide', u'to', u'build')
# (u'used', u'to', u'destroy')
# (u'going', u'to', u'develop')
# (u'put', u'to', u'see')
# (u'fail', u'to', u'develop')
# (u'seem', u'to', u'fall')
# (u'serve', u'to', u'emphasize')
# (u'tend', u'to', u'stamp')
# (u'fail', u'to', u'enter')
# (u'rehearing', u'to', u'acquire')
# (u'fail', u'to', u'convey')
# (u'needed', u'to', u'attain')
# (u'seem', u'to', u'reduce')
# (u'continue', u'to', u'show')
# (u'sponsored', u'to', u'win')
# (u'invited', u'to', u'judge')
# (u'asked', u'to', u'pick')
# (u'qualified', u'to', u'judge')
# (u'helping', u'to', u'create')
# (u'qualified', u'to', u'win')
# (u'continuing', u'to', u'donate')
# (u'found', u'to', u'take')
# (u'built', u'to', u'accommodate')
# (u'bothered', u'to', u'make')
# (u'wanted', u'to', u'purchase')
# (u'managing', u'to', u'get')
# (u'formed', u'to', u'develop')
# (u'used', u'to', u'indicate')
# (u'meant', u'to', u'pertain')
# (u'designed', u'to', u'cater')
# (u'equipped', u'to', u'handle')
# (u'pulled', u'to', u'clear')
# (u'Tend', u'to', u'make')
# (u'progresses', u'to', u'insure')
# (u'Endeavor', u'to', u'get')
# (u'used', u'to', u'separate')
# (u'used', u'to', u'separate')
# (u'seems', u'to', u'know')
# (u'wanted', u'to', u'trot')
# (u'likes', u'to', u'trot')
# (u'wants', u'to', u'trot')
# (u'started', u'to', u'pace')
# (u'starting', u'to', u'go')
# (u'expected', u'to', u'race')
# (u'designed', u'to', u'push')
# (u'looks', u'to', u'run')
# (u'began', u'to', u'motor')
# (u'trained', u'to', u'drag')
# (u'fled', u'to', u'make')
# (u'seemed', u'to', u'know')
# (u'used', u'to', u'say')
# (u'preferred', u'to', u'get')
# (u'hope', u'to', u'cover')
# (u'want', u'to', u'miss')
# (u'scheduled', u'to', u'vanish')
# (u'vanish', u'to', u'make')
# (u'continued', u'to', u'live')
# (u'seem', u'to', u'cascade')
# (u'forget', u'to', u'buy')
# (u'fail', u'to', u'shorten')
# (u'intend', u'to', u'cook')
# (u'sized', u'to', u'fit')
# (u'continue', u'to', u'release')
# (u'wish', u'to', u'create')
# (u'trim', u'to', u'fit')
# (u'cut', u'to', u'fit')
# (u'help', u'to', u'prevent')
# (u'designed', u'to', u'take')
# (u'used', u'to', u'transport')
# (u'want', u'to', u'buy')
# (u'used', u'to', u'fasten')
# (u'help', u'to', u'keep')
# (u'needed', u'to', u'build')
# (u'designed', u'to', u'accommodate')
# (u'adjusted', u'to', u'suit')
# (u'used', u'to', u'cut')
# (u'want', u'to', u'avoid')
# (u'agreed', u'to', u'take')
# (u'planned', u'to', u'destroy')
# (u'allowed', u'to', u'issue')
# (u'managed', u'to', u'coerce')
# (u'want', u'to', u'know')
# (u'planning', u'to', u'bring')
# (u'urged', u'to', u'keep')
# (u'come', u'to', u'swim')
# (u'enjoined', u'to', u'look')
# (u'prepared', u'to', u'cope')
# (u'want', u'to', u'make')
# (u'allowed', u'to', u'dry')
# (u'pays', u'to', u'buy')
# (u'want', u'to', u'play')
# (u'expected', u'to', u'last')
# (u'plan', u'to', u'add')
# (u'want', u'to', u'start')
# (u'plan', u'to', u'buy')
# (u'going', u'to', u'need')
# (u'continue', u'to', u'reduce')
# (u'needed', u'to', u'arrive')
# (u'done', u'to', u'correct')
# (u'cost', u'to', u'make')
# (u'settled', u'to', u'find')
# (u'grew', u'to', u'fulfill')
# (u'attempted', u'to', u'restrict')
# (u'conceived', u'to', u'affirm')
# (u'prefer', u'to', u'believe')
# (u'tried', u'to', u'refashion')
# (u'begin', u'to', u'fear')
# (u'linger', u'to', u'haunt')
# (u'disciplined', u'to', u'serve')
# (u'trained', u'to', u'fulfill')
# (u'organized', u'to', u'furnish')
# (u'continued', u'to', u'paint')
# (u'made', u'to', u'weave')
# (u'try', u'to', u'place')
# (u'hesitate', u'to', u'add')
# (u'seemed', u'to', u'emphasize')
# (u'mean', u'to', u'project')
# (u'wishes', u'to', u'convey')
# (u'beginning', u'to', u'learn')
# (u'start', u'to', u'study')
# (u'said', u'to', u'start')
# (u'wished', u'to', u'get')
# (u'Try', u'to', u'push')
# (u'taken', u'to', u'see')
# (u'promises', u'to', u'open')
# (u'selected', u'to', u'operate')
# (u'used', u'to', u'measure')
# (u'employed', u'to', u'measure')
# (u'used', u'to', u'detect')
# (u'tend', u'to', u'reflect')
# (u'used', u'to', u'scan')
# (u'decided', u'to', u'enter')
# (u'preparing', u'to', u'matriculate')
# (u'continued', u'to', u'help')
# (u'intend', u'to', u'carry')
# (u'lived', u'to', u'see')
# (u'manage', u'to', u'experiment')
# (u'tempted', u'to', u'compare')
# (u'made', u'to', u'see')
# (u'caused', u'to', u'glow')
# (u'made', u'to', u'flow')
# (u'happened', u'to', u'place')
# (u'used', u'to', u'construct')
# (u'used', u'to', u'fill')
# (u'examine', u'to', u'make')
# (u'designed', u'to', u'counter')
# (u'tend', u'to', u'become')
# (u'try', u'to', u'share')
# (u'continue', u'to', u'make')
# (u'come', u'to', u'expect')
# (u'used', u'to', u'keep')
# (u'bound', u'to', u'increase')
# (u'trying', u'to', u'match')
# (u'going', u'to', u'take')
# (u'continue', u'to', u'exceed')
# (u'extended', u'to', u'compare')
# (u'continue', u'to', u'divorce')
# (u'fail', u'to', u'lower')
# (u'supposed', u'to', u'stand')
# (u'prepared', u'to', u'teach')
# (u'school', u'to', u'cover')
# (u'make', u'to', u'assess')
# (u'try', u'to', u'set')
# (u'encouraged', u'to', u'take')
# (u'try', u'to', u'maintain')
# (u'plan', u'to', u'limit')
# (u'make', u'to', u'assure')
# (u'afford', u'to', u'spend')
# (u'Aim', u'to', u'balance')
# (u'Check', u'to', u'see')
# (u'called', u'to', u'determine')
# (u'cooperate', u'to', u'launch')
# (u'designed', u'to', u'expose')
# (u'existing', u'to', u'acquaint')
# (u'like', u'to', u'organize')
# (u'begin', u'to', u'appreciate')
# (u'inclined', u'to', u'think')
# (u'needed', u'to', u'protect')
# (u'struggling', u'to', u'meet')
# (u'helping', u'to', u'account')
# (u'want', u'to', u'learn')
# (u'used', u'to', u'think')
# (u'fights', u'to', u'change')
# (u'tends', u'to', u'rise')
# (u'expects', u'to', u'extend')
# (u'learn', u'to', u'wear')
# (u'tried', u'to', u'make')
# (u'appears', u'to', u'lie')
# (u'attempted', u'to', u'provide')
# (u'found', u'to', u'allow')
# (u'planned', u'to', u'duplicate')
# (u'wants', u'to', u'interest')
# (u'want', u'to', u'risk')
# (u'want', u'to', u'use')
# (u'continue', u'to', u'learn')
# (u'meant', u'to', u'convey')
# (u'used', u'to', u'minimize')
# (u'try', u'to', u'wrestle')
# (u'trying', u'to', u'install')
# (u'plan', u'to', u'build')
# (u'equipped', u'to', u'handle')
# (u'equipped', u'to', u'package')
# (u'equipped', u'to', u'receive')
# (u'equipped', u'to', u'save')
# (u'plan', u'to', u'increase')
# (u'hopes', u'to', u'cut')
# (u'bound', u'to', u'swell')
# (u'begin', u'to', u'feel')
# (u'want', u'to', u'change')
# (u'arrange', u'to', u'rent')
# (u'plan', u'to', u'travel')
# (u'plan', u'to', u'visit')
# (u'like', u'to', u'start')
# (u'wish', u'to', u'budget')
# (u'wanting', u'to', u'rent')
# (u'want', u'to', u'see')
# (u'want', u'to', u'throw')
# (u'designed', u'to', u'work')
# (u'trying', u'to', u'prepare')
# (u'began', u'to', u'develop')
# (u'used', u'to', u'suggest')
# (u'wanted', u'to', u'polish')
# (u'pays', u'to', u'consider')
# (u'compelled', u'to', u'use')
# (u'began', u'to', u'fall')
# (u'begun', u'to', u'write')
# (u'made', u'to', u'seem')
# (u'attempting', u'to', u'direct')
# (u'pleased', u'to', u'call')
# (u'scheduled', u'to', u'nominate')
# (u'come', u'to', u'spend')
# (u'managed', u'to', u'irrigate')
# (u'stooped', u'to', u'scoop')
# (u'fall', u'to', u'show')
# (u'try', u'to', u'push')
# (u'begins', u'to', u'deteriorate')
# (u'used', u'to', u'like')
# (u'offered', u'to', u'ship')
# (u'hopes', u'to', u'find')
# (u'invented', u'to', u'hold')
# (u'learn', u'to', u'like')
# (u'labored', u'to', u'set')
# (u'set', u'to', u'receive')
# (u'entered', u'to', u'compete')
# (u'seem', u'to', u'make')
# (u'seemed', u'to', u'answer')
# (u'decided', u'to', u'use')
# (u'began', u'to', u'show')
# (u'Wishing', u'to', u'show')
# (u'learned', u'to', u'set')
# (u'forced', u'to', u'fly')
# (u'hope', u'to', u'break')
# (u'came', u'to', u'recognize')
# (u'turning', u'to', u'cup')
# (u'seems', u'to', u'creep')
# (u'going', u'to', u'live')
# (u'got', u'to', u'learn')
# (u'learn', u'to', u'live')
# (u'going', u'to', u'live')
# (u'like', u'to', u'sew')
# (u'love', u'to', u'run')
# (u'love', u'to', u'crack')
# (u'yearn', u'to', u'make')
# (u'tried', u'to', u'see')
# (u'love', u'to', u'dust')
# (u'like', u'to', u'become')
# (u'decide', u'to', u'write')
# (u'cause', u'to', u'exist')
# (u'learn', u'to', u'portray')
# (u'learn', u'to', u'portray')
# (u'began', u'to', u'advise')
# (u'taught', u'to', u'yield')
# (u'prefer', u'to', u'cope')
# (u'helps', u'to', u'explain')
# (u'surprised', u'to', u'bump')
# (u'seemed', u'to', u'brave')
# (u'begins', u'to', u'regard')
# (u'began', u'to', u'embezzle')
# (u'appears', u'to', u'endorse')
# (u'expected', u'to', u'like')
# (u'begin', u'to', u'assert')
# (u'began', u'to', u'challenge')
# (u'going', u'to', u'become')
# (u'helping', u'to', u'make')
# (u'began', u'to', u'stress')
# (u'began', u'to', u'describe')
# (u'fails', u'to', u'gain')
# (u'liked', u'to', u'play')
# (u'love', u'to', u'audition')
# (u'wanted', u'to', u'show')
# (u'like', u'to', u'see')
# (u'loved', u'to', u'dance')
# (u'try', u'to', u'bid')
# (u'wanted', u'to', u'go')
# (u'asked', u'to', u'leave')
# (u'continued', u'to', u'promote')
# (u'wished', u'to', u'meet')
# (u'hoping', u'to', u'see')
# (u'got', u'to', u'know')
# (u'paused', u'to', u'comfort')
# (u'hesitate', u'to', u'quote')
# (u'decided', u'to', u'see')
# (u'wanted', u'to', u'take')
# (u'need', u'to', u'know')
# (u'need', u'to', u'look')
# (u'beginning', u'to', u'protrude')
# (u'try', u'to', u'speak')
# (u'decides', u'to', u'proceed')
# (u'interested', u'to', u'hear')
# (u'seems', u'to', u'probe')
# (u'preferring', u'to', u'consider')
# (u'known', u'to', u'go')
# (u'amazed', u'to', u'realize')
# (u'seeking', u'to', u'help')
# (u'interpreted', u'to', u'conform')
# (u'explored', u'to', u'find')
# (u'trying', u'to', u'throw')
# (u'designed', u'to', u'find')
# (u'required', u'to', u'mark')
# (u'asked', u'to', u'consider')
# (u'seem', u'to', u'involve')
# (u'seems', u'to', u'smell')
# (u'seems', u'to', u'see')
# (u'learned', u'to', u'develop')
# (u'arranged', u'to', u'meet')
# (u'need', u'to', u'work')
# (u'want', u'to', u'raise')
# (u'need', u'to', u'bring')
# (u'expect', u'to', u'grow')
# (u'expected', u'to', u'work')
# (u'want', u'to', u'include')
# (u'going', u'to', u'produce')
# (u'want', u'to', u'hire')
# (u'want', u'to', u'buy')
# (u'want', u'to', u'hire')
# (u'going', u'to', u'farm')
# (u'need', u'to', u'know')
# (u'want', u'to', u'undertake')
# (u'want', u'to', u'buy')
# (u'wish', u'to', u'locate')
# (u'plan', u'to', u'sell')
# (u'want', u'to', u'go')
# (u'intend', u'to', u'raise')
# (u'cost', u'to', u'live')
# (u'expected', u'to', u'produce')
# (u'expect', u'to', u'get')
# (u'forced', u'to', u'lay')
# (u'trying', u'to', u'explain')
# (u'happened', u'to', u'light')
# (u'began', u'to', u'turn')
# (u'intended', u'to', u'warn')
# (u'used', u'to', u'transform')
# (u'forced', u'to', u'overcome')
# (u'begins', u'to', u'give')
# (u'failed', u'to', u'post')
# (u'refused', u'to', u'permit')
# (u'encouraged', u'to', u'beget')
# (u'obliged', u'to', u'obey')
# (u'united', u'to', u'push')
# (u'try', u'to', u'oppose')
# (u'made', u'to', u'impose')
# (u'wanted', u'to', u'clarify')
# (u'proposed', u'to', u'sail')
# (u'determined', u'to', u'catch')
# (u'forced', u'to', u'turn')
# (u'seemed', u'to', u'sense')
# (u'seemed', u'to', u'know')
# (u'tried', u'to', u'brush')
# (u'turning', u'to', u'repeat')
# (u'tried', u'to', u'persuade')
# (u'wanted', u'to', u'turn')
# (u'preparing', u'to', u'pacify')
# (u'forced', u'to', u'retreat')
# (u'contracted', u'to', u'supply')
# (u'forced', u'to', u'leave')
# (u'offering', u'to', u'bring')
# (u'attempt', u'to', u'bring')
# (u'decided', u'to', u'cast')
# (u'liked', u'to', u'tease')
# (u'going', u'to', u'buy')
# (u'com', u'to', u'sea')
# (u'drilled', u'to', u'follow')
# (u'born', u'to', u'command')
# (u'come', u'to', u'recognize')
# (u'allowed', u'to', u'account')
# (u'created', u'to', u'fan')
# (u'come', u'to', u'mean')
# (u'trying', u'to', u'make')
# (u'refusing', u'to', u'keep')
# (u'wishes', u'to', u'discuss')
# (u'want', u'to', u'ask')
# (u'want', u'to', u'tap')
# (u'said', u'to', u'use')
# (u'employed', u'to', u'see')
# (u'shoot', u'to', u'kill')
# (u'refused', u'to', u'touch')
# (u'threatened', u'to', u'shoot')
# (u'said', u'to', u'let')
# (u'begin', u'to', u'roll')
# (u'held', u'to', u'assure')
# (u'going', u'to', u'make')
# (u'managed', u'to', u'get')
# (u'wanted', u'to', u'play')
# (u'prepared', u'to', u'counterattack')
# (u'failed', u'to', u'rally')
# (u'tried', u'to', u'rape')
# (u'refused', u'to', u'speak')
# (u'called', u'to', u'look')
# (u'refused', u'to', u'say')
# (u'mean', u'to', u'suggest')
# (u'prepared', u'to', u'carry')
# (u'designed', u'to', u'overthrow')
# (u'trying', u'to', u'put')
# (u'needed', u'to', u'work')
# (u'disposed', u'to', u'exploit')
# (u'fail', u'to', u'see')
# (u'bound', u'to', u'fall')
# (u'tempted', u'to', u'place')
# (u'need', u'to', u'ask')
# (u'seek', u'to', u'undermine')
# (u'hand', u'to', u'show')
# (u'begun', u'to', u'spit')
# (u'threatened', u'to', u'ignite')
# (u'invited', u'to', u'take')
# (u'rushing', u'to', u'keep')
# (u'like', u'to', u'wander')
# (u'like', u'to', u'follow')
# (u'professing', u'to', u'believe')
# (u'want', u'to', u'show')
# (u'enabled', u'to', u'attend')
# (u'determined', u'to', u'exercise')
# (u'inclined', u'to', u'exaggerate')
# (u'like', u'to', u'go')
# (u'determined', u'to', u'marry')
# (u'said', u'to', u'sprinkle')
# (u'used', u'to', u'stop')
# (u'bought', u'to', u'apply')
# (u'supposed', u'to', u'cause')
# (u'said', u'to', u'give')
# (u'allowed', u'to', u'rest')
# (u'enters', u'to', u'spoil')
# (u'wish', u'to', u'deny')
# (u'allowed', u'to', u'warm')
# (u'wishes', u'to', u'entertain')
# (u'allowed', u'to', u'stand')
# (u'refused', u'to', u'accept')
# (u'wished', u'to', u'continue')
# (u'persuaded', u'to', u'accept')
# (u'decided', u'to', u'charge')
# (u'decided', u'to', u'go')
# (u'allowed', u'to', u'see')
# (u'agreed', u'to', u'take')
# (u'decide', u'to', u'send')
# (u'allowed', u'to', u'delay')
# (u'request', u'to', u'leave')
# (u'promised', u'to', u'treat')
# (u'declined', u'to', u'enter')
# (u'added', u'to', u'reinforce')
# (u'obliged', u'to', u'publish')
# (u'continue', u'to', u'serve')
# (u'plans', u'to', u'serve')
# (u'Hoping', u'to', u'cut')
# (u'obliged', u'to', u'announce')
# (u'wish', u'to', u'preserve')
# (u'heard', u'to', u'remark')
# (u'hopes', u'to', u'redress')
# (u'desires', u'to', u'walk')
# (u'prefer', u'to', u'take')
# (u'likes', u'to', u'measure')
# (u'proposed', u'to', u'corral')
# (u'intended', u'to', u'stay')
# (u'ceased', u'to', u'look')
# (u'manages', u'to', u'overlook')
# (u'troubled', u'to', u'read')
# (u'destined', u'to', u'go')
# (u'expected', u'to', u'go')
# (u'used', u'to', u'characterize')
# (u'helping', u'to', u'raise')
# (u'decided', u'to', u'stay')
# (u'used', u'to', u'refer')
# (u'needs', u'to', u'educate')
# (u'tended', u'to', u'tamp')
# (u'like', u'to', u'underline')
# (u'begun', u'to', u'falter')
# (u'intend', u'to', u'include')
# (u'wish', u'to', u'improve')
# (u'try', u'to', u'take')
# (u'prefers', u'to', u'designate')
# (u'want', u'to', u'join')
# (u'seeking', u'to', u'increase')
# (u'used', u'to', u'make')
# (u'used', u'to', u'make')
# (u'inclined', u'to', u'remain')
# (u'heard', u'to', u'say')
# (u'stopped', u'to', u'receive')
# (u'used', u'to', u'describe')
# (u'claimed', u'to', u'own')
# (u'tried', u'to', u'find')
# (u'meant', u'to', u'pay')
# (u'given', u'to', u'go')
# (u'wanted', u'to', u'make')
# (u'began', u'to', u'gallop')
# (u'attempting', u'to', u'lasso')
# (u'failing', u'to', u'encircle')
# (u'got', u'to', u'get')
# (u'trying', u'to', u'maneuver')
# (u'beginning', u'to', u'go')
# (u'began', u'to', u'pull')
# (u'began', u'to', u'draw')
# (u'like', u'to', u'go')
# (u'tend', u'to', u'compete')
# (u'doing', u'to', u'help')
# (u'begins', u'to', u'see')
# (u'Desiring', u'to', u'fill')
# (u'tends', u'to', u'look')
# (u'try', u'to', u'match')
# (u'played', u'to', u'win')
# (u'failed', u'to', u'make')
# (u'began', u'to', u'involve')
# (u'learning', u'to', u'bunt')
# (u'dared', u'to', u'dream')
# (u'dared', u'to', u'taunt')
# (u'refused', u'to', u'come')
# (u'undertook', u'to', u'set')
# (u'essayed', u'to', u'down')
# (u'began', u'to', u'prosper')
# (u'liked', u'to', u'wring')
# (u'happened', u'to', u'sit')
# (u'hastened', u'to', u'place')
# (u'began', u'to', u'offer')
# (u'seemed', u'to', u'indicate')
# (u'liked', u'to', u'imagine')
# (u'expected', u'to', u'know')
# (u'began', u'to', u'appear')
# (u'begin', u'to', u'store')
# (u'continue', u'to', u'sanction')
# (u'intended', u'to', u'demonstrate')
# (u'permitted', u'to', u'exercise')
# (u'encouraged', u'to', u'develop')
# (u'failing', u'to', u'behave')
# (u'appeared', u'to', u'regard')
# (u'seek', u'to', u'disprove')
# (u'tends', u'to', u'fuse')
# (u'prefers', u'to', u'adduce')
# (u'empowered', u'to', u'compel')
# (u'designed', u'to', u'prevent')
# (u'disposed', u'to', u'heed')
# (u'agree', u'to', u'let')
# (u'seeking', u'to', u'reform')
# (u'used', u'to', u'crowd')
# (u'Ask', u'to', u'see')
# (u'interested', u'to', u'learn')
# (u'pass', u'to', u'add')
# (u'demanding', u'to', u'know')
# (u'seems', u'to', u'threaten')
# (u'tried', u'to', u'describe')
# (u'tried', u'to', u'explain')
# (u'seem', u'to', u'feel')
# (u'got', u'to', u'play')
# (u'ceased', u'to', u'need')
# (u'like', u'to', u'live')
# (u'came', u'to', u'see')
# (u'threatens', u'to', u'break')
# (u'begins', u'to', u'fade')
# (u'begins', u'to', u'appear')
# (u'equipped', u'to', u'tell')
# (u'used', u'to', u'increase')
# (u'hired', u'to', u'repeat')
# (u'wished', u'to', u'make')
# (u'seems', u'to', u'exist')
# (u'means', u'to', u'choose')
# (u'struggle', u'to', u'insulate')
# (u'serves', u'to', u'crystallize')
# (u'doomed', u'to', u'become')
# (u'serves', u'to', u'illuminate')
# (u'failed', u'to', u'furnish')
# (u'encouraged', u'to', u'trade')
# (u'continued', u'to', u'come')
# (u'promised', u'to', u'send')
# (u'attempted', u'to', u'understand')
# (u'decided', u'to', u'send')
# (u'assigned', u'to', u'arrest')
# (u'planned', u'to', u'build')
# (u'offered', u'to', u'surrender')
# (u'gone', u'to', u'live')
# (u'returned', u'to', u'succeed')
# (u'expected', u'to', u'arrange')
# (u'expected', u'to', u'supply')
# (u'expected', u'to', u'entertain')
# (u'tried', u'to', u'bring')
# (u'provoked', u'to', u'use')
# (u'refused', u'to', u'let')
# (u'needed', u'to', u'outwit')
# (u'purporting', u'to', u'inform')
# (u'inspired', u'to', u'remind')
# (u'mean', u'to', u'tell')
# (u'trying', u'to', u'demonstrate')
# (u'went', u'to', u'visit')
# (u'continued', u'to', u'teach')
# (u'beginning', u'to', u'devise')
# (u'learn', u'to', u'like')
# (u'stood', u'to', u'watch')
# (u'planned', u'to', u'go')
# (u'trying', u'to', u'plan')
# (u'continues', u'to', u'grow')
# (u'learn', u'to', u'keep')
# (u'learned', u'to', u'polish')
# (u'left', u'to', u'meet')
# (u'fails', u'to', u'make')
# (u'resolved', u'to', u'maintain')
# (u'register', u'to', u'vote')
# (u'needs', u'to', u'make')
# (u'going', u'to', u'march')
# (u'proposed', u'to', u'defeat')
# (u'proposed', u'to', u'enter')
# (u'seems', u'to', u'require')
# (u'seem', u'to', u'violate')
# (u'tended', u'to', u'obscure')
# (u'continue', u'to', u'view')
# (u'try', u'to', u'coerce')
# (u'likes', u'to', u'believe')
# (u'continue', u'to', u'affect')
# (u'served', u'to', u'overcome')
# (u'tends', u'to', u'further')
# (u'help', u'to', u'reveal')
# (u'struggle', u'to', u'assert')
# (u'said', u'to', u'exist')
# (u'taken', u'to', u'guard')
# (u'done', u'to', u'increase')
# (u'ready', u'to', u'tick')
# (u'forced', u'to', u'hypothesize')
# (u'used', u'to', u'challenge')
# (u'permitted', u'to', u'authorize')
# (u'decides', u'to', u'break')
# (u'required', u'to', u'pass')
# (u'decide', u'to', u'clobber')
# (u'decided', u'to', u'reverse')
# (u'tried', u'to', u'start')
# (u'forbidden', u'to', u'fly')
# (u'required', u'to', u'copy')
# (u'began', u'to', u'move')
# (u'run', u'to', u'live')
# (u'started', u'to', u'glance')
# (u'try', u'to', u'memorize')
# (u'turned', u'to', u'look')
# (u'trying', u'to', u'talk')
# (u'started', u'to', u'decline')
# (u'continues', u'to', u'take')
# (u'continues', u'to', u'center')
# (u'come', u'to', u'see')
# (u'come', u'to', u'walk')
# (u'beginning', u'to', u'complain')
# (u'gather', u'to', u'sing')
# (u'began', u'to', u'converse')
# (u'began', u'to', u'relax')
# (u'hoped', u'to', u'become')
# (u'forced', u'to', u'restrict')
# (u'began', u'to', u'give')
# (u'asked', u'to', u'become')
# (u'trying', u'to', u'sell')
# (u'serves', u'to', u'stimulate')
# (u'seemed', u'to', u'lack')
# (u'offered', u'to', u'make')
# (u'assembled', u'to', u'warrant')
# (u'returned', u'to', u'preside')
# (u'sought', u'to', u'prevent')
# (u'expect', u'to', u'stand')
# (u'compelled', u'to', u'face')
# (u'continue', u'to', u'live')
# (u'refused', u'to', u'move')
# (u'refused', u'to', u'obey')
# (u'doomed', u'to', u'become')
# (u'tended', u'to', u'romanticize')
# (u'supposed', u'to', u'keep')
# (u'left', u'to', u'rest')
# (u'wants', u'to', u'see')
# (u'tended', u'to', u'dress')
# (u'designed', u'to', u'become')
# (u'begins', u'to', u'feel')
# (u'tends', u'to', u'depict')
# (u'transferred', u'to', u'become')
# (u'impelled', u'to', u'make')
# (u'seeks', u'to', u'make')
# (u'made', u'to', u'look')
# (u'happen', u'to', u'meet')
# (u'told', u'to', u'lie')
# (u'wanted', u'to', u'write')
# (u'tempted', u'to', u'say')
# (u'omitting', u'to', u'assert')
# (u'continue', u'to', u'live')
# (u'refused', u'to', u'permit')
# (u'served', u'to', u'maintain')
# (u'seem', u'to', u'make')
# (u'help', u'to', u'dispel')
# (u'trained', u'to', u'describe')
# (u'daring', u'to', u'abandon')
# (u'seem', u'to', u'resemble')
# (u'appears', u'to', u'lie')
# (u'tend', u'to', u'persist')
# (u'tried', u'to', u'describe')
# (u'like', u'to', u'call')
# (u'began', u'to', u'speak')
# (u'try', u'to', u'say')
# (u'attempting', u'to', u'make')
# (u'attempt', u'to', u'answer')
# (u'wanted', u'to', u'know')
# (u'designed', u'to', u'enhance')
# (u'intended', u'to', u'provide')
# (u'continue', u'to', u'suffer')
# (u'serves', u'to', u'make')
# (u'fails', u'to', u'reach')
# (u'beginning', u'to', u'crack')
# (u'drawn', u'to', u'join')
# (u'made', u'to', u'bite')
# (u'forbidden', u'to', u'swing')
# (u'seemed', u'to', u'hear')
# (u'hired', u'to', u'drive')
# (u'try', u'to', u'work')
# (u'forbidden', u'to', u'love')
# (u'made', u'to', u'represent')
# (u'starts', u'to', u'ride')
# (u'tries', u'to', u'stop')
# (u'begins', u'to', u'gather')
# (u'brought', u'to', u'pass')
# (u'tends', u'to', u'reflect')
# (u'tended', u'to', u'stratify')
# (u'chosen', u'to', u'use')
# (u'used', u'to', u'mean')
# (u'forced', u'to', u'respond')
# (u'tends', u'to', u'lose')
# (u'tends', u'to', u'express')
# (u'made', u'to', u'integrate')
# (u'try', u'to', u'get')
# (u'attempted', u'to', u'restrain')
# (u'wished', u'to', u'continue')
# (u'failed', u'to', u'flourish')
# (u'propose', u'to', u'go')
# (u'wished', u'to', u'segregate')
# (u'liked', u'to', u'fancy')
# (u'Deciding', u'to', u'become')
# (u'strove', u'to', u'see')
# (u'used', u'to', u'play')
# (u'returned', u'to', u'live')
# (u'proceeded', u'to', u'find')
# (u'likes', u'to', u'catch')
# (u'seems', u'to', u'care')
# (u'intends', u'to', u'save')
# (u'compelled', u'to', u'find')
# (u'wishes', u'to', u'continue')
# (u'ceasing', u'to', u'write')
# (u'stops', u'to', u'ask')
# (u'expected', u'to', u'fulfill')
# (u'tailored', u'to', u'meet')
# (u'want', u'to', u'say')
# (u'want', u'to', u'quote')
# (u'seems', u'to', u'realize')
# (u'primed', u'to', u'catch')
# (u'try', u'to', u'diagnose')
# (u'want', u'to', u'point')
# (u'used', u'to', u'regard')
# (u'seems', u'to', u'represent')
# (u'trying', u'to', u'draw')
# (u'wish', u'to', u'see')
# (u'used', u'to', u'include')
# (u'allowed', u'to', u'operate')
# (u'urged', u'to', u'produce')
# (u'afford', u'to', u'present')
# (u'decides', u'to', u'drop')
# (u'expect', u'to', u'abolish')
# (u'needed', u'to', u'pit')
# (u'tempted', u'to', u'blame')
# (u'hope', u'to', u'serve')
# (u'tried', u'to', u'remedy')
# (u'tends', u'to', u'express')
# (u'seem', u'to', u'believe')
# (u'permitted', u'to', u'return')
# (u'attempted', u'to', u'make')
# (u'prepared', u'to', u'demonstrate')
# (u'calculated', u'to', u'suggest')
# (u'seemed', u'to', u'disconcert')
# (u'known', u'to', u'make')
# (u'going', u'to', u'talk')
# (u'learns', u'to', u'focus')
# (u'chooses', u'to', u'subordinate')
# (u'wish', u'to', u'preserve')
# (u'cease', u'to', u'exist')
# (u'seem', u'to', u'constitute')
# (u'destined', u'to', u'fail')
# (u'wants', u'to', u'get')
# (u'began', u'to', u'understand')
# (u'wanted', u'to', u'capture')
# (u'liked', u'to', u'tell')
# (u'decided', u'to', u'migrate')
# (u'continued', u'to', u'trouble')
# (u'labored', u'to', u'finish')
# (u'decided', u'to', u'return')
# (u'waiting', u'to', u'go')
# (u'chosen', u'to', u'serve')
# (u'came', u'to', u'know')
# (u'helped', u'to', u'escape')
# (u'opened', u'to', u'admit')
# (u'happened', u'to', u'see')
# (u'brought', u'to', u'bear')
# (u'inclined', u'to', u'argue')
# (u'seeming', u'to', u'say')
# (u'prompted', u'to', u'write')
# (u'come', u'to', u'dominate')
# (u'used', u'to', u'illustrate')
# (u'prepared', u'to', u'find')
# (u'wish', u'to', u'argue')
# (u'begin', u'to', u'read')
# (u'plan', u'to', u'discuss')
# (u'come', u'to', u'call')
# (u'expect', u'to', u'find')
# (u'come', u'to', u'believe')
# (u'continue', u'to', u'pay')
# (u'tend', u'to', u'thump')
# (u'determined', u'to', u'prove')
# (u'learn', u'to', u'control')
# (u'used', u'to', u'frustrate')
# (u'trying', u'to', u'assert')
# (u'trying', u'to', u'expose')
# (u'comes', u'to', u'regard')
# (u'felt', u'to', u'indicate')
# (u'came', u'to', u'speak')
# (u'needed', u'to', u'explain')
# (u'required', u'to', u'make')
# (u'sought', u'to', u'make')
# (u'accustomed', u'to', u'think')
# ...
# (u'try', u'to', u'thank')
# (u'like', u'to', u'starve')
# (u'hoped', u'to', u'succeed')
# (u'hated', u'to', u'answer')
# (u'got', u'to', u'get')
# (u'swung', u'to', u'see')
# (u'offered', u'to', u'walk')
# (u'wanted', u'to', u'avoid')
# (u'dared', u'to', u'enter')
# (u'failing', u'to', u'understand')
# (u'pause', u'to', u'consider')
# (u'chose', u'to', u'ignore')
# (u'dare', u'to', u'face')
# (u'continued', u'to', u'move')
# (u'started', u'to', u'brush')
# (u'trying', u'to', u'focus')
# (u'tried', u'to', u'fling')
# (u'want', u'to', u'tell')
# (u'attempted', u'to', u'kiss')
# (u'going', u'to', u'listen')
# (u'going', u'to', u'listen')
# (u'want', u'to', u'miss')
# (u"goin'", u'to', u'say')
# (u'going', u'to', u'take')
# (u'supposed', u'to', u'walk')
# (u'waiting', u'to', u'catch')
# (u'like', u'to', u'bother')
# (u'attempted', u'to', u'push')
# (u'going', u'to', u'kill')
# (u'going', u'to', u'kill')
# (u'trying', u'to', u'keep')
# (u'seeming', u'to', u'like')
# (u'got', u'to', u'take')
# (u'going', u'to', u'need')
# (u'want', u'to', u'put')
# (u'hoped', u'to', u'catch')
# (u'went', u'to', u'look')
# (u'wanting', u'to', u'unlock')
# (u'amazed', u'to', u'see')
# (u'refused', u'to', u'give')
# (u'tried', u'to', u'lift')
# (u'forced', u'to', u'agree')
# (u'fails', u'to', u'substantiate')
# (u'wants', u'to', u'see')
# (u'beginning', u'to', u'get')
# (u'continued', u'to', u'smile')
# (u'turned', u'to', u'add')
# (u'wanted', u'to', u'get')
# (u'continued', u'to', u'snort')
# (u'started', u'to', u'reach')
# (u'beginning', u'to', u'recover')
# (u'going', u'to', u'talk')
# (u'like', u'to', u'kill')
# (u'going', u'to', u'hear')
# (u'wanted', u'to', u'hear')
# (u'came', u'to', u'investigate')
# (u'managed', u'to', u'duck')
# (u'began', u'to', u'focus')
# (u'trying', u'to', u'yank')
# (u'began', u'to', u'snort')
# (u'wanted', u'to', u'show')
# (u'tried', u'to', u'start')
# (u'going', u'to', u'let')
# (u'going', u'to', u'fight')
# (u'attempting', u'to', u'speak')
# (u'longing', u'to', u'catch')
# (u'rejoicing', u'to', u'think')
# (u'like', u'to', u'get')
# (u'tried', u'to', u'go')
# (u'seemed', u'to', u'make')
# (u'aim', u'to', u'give')
# (u'want', u'to', u'trade')
# (u'beginning', u'to', u'turn')
# (u'forced', u'to', u'maintain')
# (u'hope', u'to', u'locate')
# (u'paused', u'to', u'gather')
# (u'bothering', u'to', u'note')
# (u'turned', u'to', u'survey')
# (u'started', u'to', u'struggle')
# (u'started', u'to', u'return')
# (u'pretended', u'to', u'give')
# (u'served', u'to', u'increase')
# (u'determined', u'to', u'drive')
# (u'try', u'to', u'go')
# (u'began', u'to', u'run')
# (u'continued', u'to', u'come')
# (u'continued', u'to', u'camouflage')
# (u'Forced', u'to', u'realize')
# (u'trying', u'to', u'grab')
# (u'trying', u'to', u'read')
# (u'began', u'to', u'drink')
# (u'started', u'to', u'slide')
# (u'mean', u'to', u'pry')
# (u'going', u'to', u'sell')
# (u'pleased', u'to', u'hear')
# (u'starting', u'to', u'itch')
# (u'like', u'to', u'think')
# (u'supposed', u'to', u'meet')
# (u'wait', u'to', u'get')
# (u'seem', u'to', u'dwell')
# (u'feared', u'to', u'dwell')
# (u'tried', u'to', u'date')
# (u'trying', u'to', u'cut')
# (u'beginning', u'to', u'collect')
# (u'determined', u'to', u'find')
# (u'put', u'to', u'use')
# (u'determined', u'to', u'spend')
# (u'hoping', u'to', u'escape')
# (u'pleased', u'to', u'note')
# (u'calculated', u'to', u'glamorize')
# (u'began', u'to', u'explain')
# (u'want', u'to', u'see')
# (u'wanted', u'to', u'turn')
# (u'began', u'to', u'whip')
# (u'failed', u'to', u'find')
# (u'meant', u'to', u'save')
# (u'wanted', u'to', u'waste')
# (u'want', u'to', u'get')
# (u'going', u'to', u'explode')
# (u'seemed', u'to', u'disintegrate')
# (u'intended', u'to', u'propitiate')
# (u'embarrassing', u'to', u'see')
# (u'going', u'to', u'keel')
# (u'seemed', u'to', u'enjoy')
# (u'like', u'to', u'know')
# (u'deserve', u'to', u'lie')
# (u'want', u'to', u'see')
# (u'pretending', u'to', u'joke')
# (u'used', u'to', u'try')
# (u'trying', u'to', u'look')
# (u'began', u'to', u'watch')
# (u'want', u'to', u'go')
# (u'seemed', u'to', u'sink')
# (u'began', u'to', u'ooze')
# (u'began', u'to', u'move')
# (u'seemed', u'to', u'know')
# (u'trying', u'to', u'talk')
# (u'continued', u'to', u'lash')
# (u'turned', u'to', u'look')
# (u'struggled', u'to', u'control')
# (u'deserved', u'to', u'live')
# (u'like', u'to', u'hunt')
# (u'left', u'to', u'say')
# (u'like', u'to', u'recognize')
# (u'wanting', u'to', u'fly')
# (u'dispatched', u'to', u'harry')
# (u'started', u'to', u'buckle')
# (u'began', u'to', u'crawl')
# (u'wanted', u'to', u'lose')
# (u'going', u'to', u'show')
# (u'going', u'to', u'give')
# (u'trying', u'to', u'size')
# (u'seemed', u'to', u'promise')
# (u'hate', u'to', u'run')
# (u'turned', u'to', u'face')
# (u'wish', u'to', u'enter')
# (u'intend', u'to', u'speak')
# (u'determined', u'to', u'make')
# (u'want', u'to', u'upset')
# (u'resolved', u'to', u'make')
# (u'left', u'to', u'distract')
# (u'vied', u'to', u'knock')
# (u'equipped', u'to', u'die')
# (u'tried', u'to', u'roll')
# (u'commenced', u'to', u'weep')
# (u'began', u'to', u'uncap')
# (u'going', u'to', u'get')
# (u'expected', u'to', u'risk')
# (u'decided', u'to', u'set')
# (u'seem', u'to', u'locate')
# (u'allowed', u'to', u'come')
# (u'allowed', u'to', u'leave')
# (u'sent', u'to', u'clean')
# (u'proceeded', u'to', u'disturb')
# (u'came', u'to', u'teach')
# (u'wait', u'to', u'get')
# (u'get', u'to', u'school')
# (u'beginning', u'to', u'stir')
# (u'got', u'to', u'get')
# (u'seemed', u'to', u'think')
# (u'trying', u'to', u'get')
# (u'struggling', u'to', u'get')
# (u'mean', u'to', u'pull')
# (u'got', u'to', u'take')
# (u'trying', u'to', u'think')
# (u'seeming', u'to', u'scream')
# (u'sought', u'to', u'make')
# (u'proceeded', u'to', u'give')
# (u'advised', u'to', u'flee')
# (u'like', u'to', u'hurt')
# (u'hurt', u'to', u'beat')
# (u'want', u'to', u'go')
# (u'chanced', u'to', u'glance')
# (u'vowed', u'to', u'take')
# (u'started', u'to', u'move')
# (u'began', u'to', u'sizzle')
# (u'cared', u'to', u'see')
# (u'time', u'to', u'pay')
# (u'determined', u'to', u'hold')
# (u'beginning', u'to', u'fold')
# (u'wanted', u'to', u'smoke')
# (u'seem', u'to', u'get')
# (u'trying', u'to', u'find')
# (u'like', u'to', u'keep')
# (u'seem', u'to', u'snap')
# (u'like', u'to', u'think')
# (u'beginning', u'to', u'find')
# (u'beginning', u'to', u'look')
# (u'going', u'to', u'last')
# (u'going', u'to', u'prove')
# (u'hoped', u'to', u'die')
# (u'gone', u'to', u'live')
# (u'stayed', u'to', u'get')
# (u'turned', u'to', u'go')
# (u'going', u'to', u'see')
# (u'going', u'to', u'laugh')
# (u'tried', u'to', u'bite')
# (u'seem', u'to', u'rise')
# (u'come', u'to', u'see')
# (u'got', u'to', u'know')
# (u'seem', u'to', u'take')
# (u'beginning', u'to', u'creep')
# (u'seemed', u'to', u'rain')
# (u'like', u'to', u'hear')
# (u'come', u'to', u'make')
# (u'started', u'to', u'move')
# (u'bent', u'to', u'pick')
# (u'permitted', u'to', u'operate')
# (u'beginning', u'to', u'get')
# (u'seemed', u'to', u'think')
# (u'tried', u'to', u'make')
# (u'wanted', u'to', u'present')
# (u'expected', u'to', u'stay')
# (u'wish', u'to', u'start')
# (u'got', u'to', u'run')
# (u'like', u'to', u'talk')
# (u'disappointed', u'to', u'find')
# (u'tried', u'to', u'reason')
# (u'trying', u'to', u'close')
# (u'want', u'to', u'help')
# (u'surprised', u'to', u'see')
# (u'trying', u'to', u'find')
# (u'neglected', u'to', u'play')
# (u'wanted', u'to', u'call')
# (u'like', u'to', u'offer')
# (u'want', u'to', u'say')
# (u'wished', u'to', u'see')
# (u'overheard', u'to', u'say')
# (u'like', u'to', u'get')
# (u'expected', u'to', u'perform')
# (u'going', u'to', u'bring')
# (u'seek', u'to', u'storm')
# (u'used', u'to', u'defend')
# (u'shocked', u'to', u'find')
# (u'hesitate', u'to', u'speak')
# (u'beginning', u'to', u'study')
# (u'grow', u'to', u'devote')
# (u'wish', u'to', u'turn')
# (u'going', u'to', u'fail')
# (u'wished', u'to', u'change')
# (u'wanted', u'to', u'take')
# (u'wanted', u'to', u'bring')
# (u'like', u'to', u'know')
# (u'intend', u'to', u'marry')
# (u'began', u'to', u'talk')
# (u'used', u'to', u'play')
# (u'trying', u'to', u'get')
# (u'happen', u'to', u'drive')
# (u'hating', u'to', u'get')
# (u'try', u'to', u'walk')
# (u'left', u'to', u'believe')
# (u'tried', u'to', u'rest')
# (u'dying', u'to', u'defend')
# (u'used', u'to', u'kid')
# (u'wanted', u'to', u'paint')
# (u'going', u'to', u'organize')
# (u'try', u'to', u'paint')
# (u'used', u'to', u'hang')
# (u'prepared', u'to', u'worship')
# (u'want', u'to', u'stir')
# (u'beginning', u'to', u'gather')
# (u'tried', u'to', u'believe')
# (u'used', u'to', u'say')
# (u'began', u'to', u'shudder')
# (u'come', u'to', u'understand')
# (u'come', u'to', u'see')
# (u'called', u'to', u'say')
# (u'decided', u'to', u'cremate')
# (u'want', u'to', u'meet')
# (u'impelled', u'to', u'kneel')
# (u'trying', u'to', u'touch')
# (u'trying', u'to', u'flatter')
# (u'trying', u'to', u'worry')
# (u'trying', u'to', u'worry')
# (u'want', u'to', u'go')
# (u'like', u'to', u'take')
# (u'wanted', u'to', u'know')
# (u'trying', u'to', u'get')
# (u'gone', u'to', u'purify')
# (u'waiting', u'to', u'see')
# (u'come', u'to', u'skirt')
# (u'trying', u'to', u'make')
# (u'go', u'to', u'sleep')
# (u'tried', u'to', u'emulate')
# (u'began', u'to', u'pulse')
# (u'amazed', u'to', u'find')
# (u'kneeling', u'to', u'tie')
# (u'trying', u'to', u'get')
# (u'trying', u'to', u'smile')
# (u'seemed', u'to', u'float')
# (u'tried', u'to', u'see')
# (u'stop', u'to', u'analyze')
# (u'supposed', u'to', u'joke')
# (u'supposed', u'to', u'handle')
# (u'want', u'to', u'ask')
# (u'got', u'to', u'admit')
# (u'tried', u'to', u'leave')
# (u'began', u'to', u'walk')
# (u'supposed', u'to', u'stay')
# (u'going', u'to', u'tell')
# (u'going', u'to', u'get')
# (u'intended', u'to', u'make')
# (u'began', u'to', u'zip')
# (u'obliged', u'to', u'roll')
# (u'want', u'to', u'stop')
# (u'going', u'to', u'marry')
# (u'liked', u'to', u'hear')
# (u'tempted', u'to', u'tell')
# (u'seemed', u'to', u'mark')
# (u'tried', u'to', u'explain')
# (u'managed', u'to', u'look')
# (u'needed', u'to', u'get')
# (u'answered', u'to', u'find')
# (u'afford', u'to', u'get')
# (u'started', u'to', u'look')
# (u'takes', u'to', u'get')
# (u'going', u'to', u'get')
# (u'tried', u'to', u'quiet')
# (u'trying', u'to', u'sound')
# (u'came', u'to', u'meet')
# (u'seemed', u'to', u'focus')
# (u'want', u'to', u'talk')
# (u'want', u'to', u'see')
# (u'wants', u'to', u'get')
# (u'went', u'to', u'turn')
# (u'surprised', u'to', u'find')
# (u'want', u'to', u'stay')
# (u'going', u'to', u'make')
# (u'hoped', u'to', u'dig')
# (u'trying', u'to', u'make')
# (u'going', u'to', u'lug')
# (u'surprised', u'to', u'see')
# (u'stop', u'to', u'read')
# (u'intended', u'to', u'move')
# (u'rising', u'to', u'sting')
# (u'arranged', u'to', u'live')
# (u'managed', u'to', u'find')
# (u'inclined', u'to', u'wobble')
# (u'supposed', u'to', u'care')
# (u'shuddered', u'to', u'think')
# (u'seemed', u'to', u'understand')
# (u'aroused', u'to', u'go')
# (u'hate', u'to', u'call')
# (u'wish', u'to', u'leave')
# (u'seemed', u'to', u'follow')
# (u'supposed', u'to', u'matter')
# (u'bothered', u'to', u'tell')
# (u'hesitate', u'to', u'use')
# (u'used', u'to', u'say')
# (u'try', u'to', u'persuade')
# (u'wanted', u'to', u'keep')
# (u'trying', u'to', u'keep')
# (u'blushed', u'to', u'admit')
# (u'want', u'to', u'continue')
# (u'chosen', u'to', u'represent')
# (u'want', u'to', u'leave')
# (u'wanted', u'to', u'work')
# (u'seemed', u'to', u'regard')
# (u'forbore', u'to', u'mention')
# (u'managed', u'to', u'open')
# (u'want', u'to', u'encourage')
# (u'want', u'to', u'watch')
# (u'remember', u'to', u'warn')
# (u'used', u'to', u'take')
# (u'want', u'to', u'use')
# (u'started', u'to', u'throw')
# (u'began', u'to', u'swing')
# (u'started', u'to', u'carry')
# (u'began', u'to', u'look')
# (u'going', u'to', u'happen')
# (u'began', u'to', u'walk')
# (u'trying', u'to', u'say')
# (u'trying', u'to', u'say')
# (u'started', u'to', u'say')
# (u'wants', u'to', u'take')
# (u'started', u'to', u'take')
# (u'began', u'to', u'fascinate')
# (u'left', u'to', u'spend')
# (u'seemed', u'to', u'work')
# (u'work', u'to', u'grow')
# (u'trying', u'to', u'talk')
# (u'lied', u'to', u'shorten')
# (u'trying', u'to', u'make')
# (u'wanted', u'to', u'force')
# (u'refused', u'to', u'take')
# (u'seemed', u'to', u'please')
# (u'grew', u'to', u'depend')
# (u'meant', u'to', u'tell')
# (u'trying', u'to', u'pull')
# (u'seemed', u'to', u'shiver')
# (u'trying', u'to', u'remember')
# (u'worked', u'to', u'recall')
# (u'wished', u'to', u'call')
# (u'seemed', u'to', u'stare')
# (u'began', u'to', u'tremble')
# (u'refusing', u'to', u'think')
# (u'refusing', u'to', u'think')
# (u'hoping', u'to', u'frighten')
# (u'wanted', u'to', u'run')
# (u'began', u'to', u'ache')
# (u'began', u'to', u'bother')
# (u'tried', u'to', u'take')
# (u'wanted', u'to', u'kill')
# (u'stopped', u'to', u'see')
# (u'going', u'to', u'tell')
# (u'going', u'to', u'push')
# (u'wanted', u'to', u'slap')
# (u'started', u'to', u'type')
# (u'helped', u'to', u'build')
# (u'refused', u'to', u'drive')
# (u'wanted', u'to', u'go')
# (u'likes', u'to', u'play')
# (u'like', u'to', u'rise')
# (u'tried', u'to', u'push')
# (u'trying', u'to', u'run')
# (u'tried', u'to', u'make')
# (u'used', u'to', u'say')
# (u'come', u'to', u'exist')
# (u'fit', u'to', u'put')
# (u'stoop', u'to', u'lift')
# (u'wanted', u'to', u'draw')
# (u'going', u'to', u'pick')
# (u'intended', u'to', u'wait')
# (u'determined', u'to', u'foil')
# (u'strode', u'to', u'answer')
# (u'trusted', u'to', u'carry')
# (u'seemed', u'to', u'help')
# (u'chose', u'to', u'come')
# (u'tried', u'to', u'ignore')
# (u'liked', u'to', u'break')
# (u'began', u'to', u'aid')
# (u'going', u'to', u'tear')
# (u'like', u'to', u'exhibit')
# (u'forced', u'to', u'make')
# (u'hate', u'to', u'admit')
# (u'got', u'to', u'decide')
# (u'tried', u'to', u'sell')
# (u'try', u'to', u'swing')
# (u'expect', u'to', u'call')
# (u'paused', u'to', u'get')
# (u'proceeded', u'to', u'search')
# (u'began', u'to', u'suspect')
# (u'endeavoring', u'to', u'cut')
# (u'wanted', u'to', u'know')
# (u'daring', u'to', u'commit')
# (u'given', u'to', u'dig')
# (u'urged', u'to', u'attend')
# (u'refused', u'to', u'receive')
# (u'beckoned', u'to', u'cross')
# (u'taken', u'to', u'keep')
# (u'trying', u'to', u'hold')
# (u'managing', u'to', u'get')
# (u'promised', u'to', u'illustrate')
# (u'pretending', u'to', u'black')
# (u'wanted', u'to', u'remind')
# (u'Resolving', u'to', u'get')
# (u'started', u'to', u'start')
# (u'starting', u'to', u'woolgather')
# (u'bound', u'to', u'get')
# (u'wanted', u'to', u'keep')
# (u'looked', u'to', u'see')
# (u'chosen', u'to', u'complement')
# (u'live', u'to', u'hear')
# (u'leaping', u'to', u'light')
# (u'trying', u'to', u'prove')
# (u'trying', u'to', u'determine')
# (u'supposed', u'to', u'put')
# (u'proceeded', u'to', u'neglect')
# (u'care', u'to', u'count')
# (u'shuddered', u'to', u'think')
# (u'telephoned', u'to', u'announce')
# (u'neglected', u'to', u'consider')
# (u'trouble', u'to', u'memorize')
# (u'deigned', u'to', u'appear')
# (u'seemed', u'to', u'understand')
# (u'try', u'to', u'revive')
# (u'seemed', u'to', u'produce')
# (u'returning', u'to', u'jump')
# (u'tried', u'to', u'farm')
# (u'going', u'to', u'set')
# (u'turned', u'to', u'stare')
# (u'seem', u'to', u'think')
# (u'liked', u'to', u'hire')
# (u'remember', u'to', u'telephone')
# (u'like', u'to', u'work')
# (u'like', u'to', u'disclose')
# (u'got', u'to', u'put')
# (u'got', u'to', u'run')
# (u'waiting', u'to', u'get')
# (u'need', u'to', u'worry')
# (u'seems', u'to', u'think')
# (u'tries', u'to', u'baffle')
# (u'mean', u'to', u'reconsider')
# (u'refused', u'to', u'make')
# (u'seems', u'to', u'make')
# (u'seems', u'to', u'refer')
# (u'seems', u'to', u'say')
# (u'delighted', u'to', u'meet')
# (u'like', u'to', u'know')
# (u'regret', u'to', u'say')
# (u'seems', u'to', u'refer')
# (u'come', u'to', u'talk')
# (u'seem', u'to', u'remember')
# (u'want', u'to', u'hear')
# (u'trying', u'to', u'get')
# (u'forgot', u'to', u'say')
# (u'seemed', u'to', u'believe')
# (u'wanted', u'to', u'get')
# (u'wanted', u'to', u'see')
# (u'wanted', u'to', u'touch')
# (u'got', u'to', u'entertain')
# (u'tried', u'to', u'keep')
# (u'going', u'to', u'tell')
# (u'thought', u'to', u'mix')
# (u'going', u'to', u'jump')
# (u'beginning', u'to', u'catch')
# (u'try', u'to', u'see')
# (u'phoned', u'to', u'say')
# (u'bothering', u'to', u'look')
# (u'forced', u'to', u'wipe')
# (u'used', u'to', u'pretend')
# (u'refused', u'to', u'approach')
# (u'used', u'to', u'express')
# (u'proceeds', u'to', u'lash')
# (u'used', u'to', u'hang')
# (u'seeks', u'to', u'expunge')
# (u'trying', u'to', u'redeem')
# (u'seemed', u'to', u'take')
# (u'tried', u'to', u'conceal')
# (u'came', u'to', u'know')
# (u'refuses', u'to', u'continue')
# (u'continue', u'to', u'scrape')
# (u'given', u'to', u'understand')
# (u'propose', u'to', u'vent')
# (u'proceeded', u'to', u'mask')
# (u'withhold', u'to', u'keep')
# (u'begin', u'to', u'wither')
# (u'help', u'to', u'intensify')
# (u'seems', u'to', u'overtake')
# (u'want', u'to', u'buy')

# %%
brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
>>> data = nltk.ConditionalFreqDist((word.lower(), tag)
...                                 for (word, tag) in brown_news_tagged)
>>> for word in sorted(data.conditions()):
...     if len(data[word]) > 3:
...         tags = [tag for (tag, _) in data[word].most_common()]
...         print(word, ' '.join(tags))
# Out:
# (u'best', u'ADJ ADV NOUN VERB')
# (u'close', u'ADV ADJ VERB NOUN')
# (u'open', u'ADJ VERB NOUN ADV')
# (u'present', u'ADJ ADV NOUN VERB')
# (u'that', u'ADP DET PRON ADV')

# %%
nltk.app.concordance()

# %%
pos = {}
>>> pos
# Out:
# {}

# %%
pos['colorless'] = 'ADJ'
>>> pos
# Out:
# {'colorless': 'ADJ'}

# %%
pos['ideas'] = 'N'
>>> pos['sleep'] = 'V'
>>> pos['furiously'] = 'ADV'
>>> pos
# Out:
# {'colorless': 'ADJ', 'furiously': 'ADV', 'ideas': 'N', 'sleep': 'V'}

# %%
pos['ideas']
# Out:
# 'N'

# %%
pos['colorless']
# Out:
# 'ADJ'

# %%
pos['green']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-7a088695b94e> in <module>()
# ----> 1 pos['green']
#
# KeyError: 'green'

# %%
list(pos)
# Out:
# ['furiously', 'sleep', 'ideas', 'colorless']

# %%
sorted(pos)
# Out:
# ['colorless', 'furiously', 'ideas', 'sleep']

# %%
[w for w in pos if w.endswith('s')]
# Out:
# ['ideas', 'colorless']

# %%
for word in sorted(pos):
...     print(word + ":", pos[word])
# Out:
# ('colorless:', 'ADJ')
# ('furiously:', 'ADV')
# ('ideas:', 'N')
# ('sleep:', 'V')

# %%
list(pos.keys())
# Out:
# ['furiously', 'sleep', 'ideas', 'colorless']

# %%
list(pos.values())
# Out:
# ['ADV', 'V', 'N', 'ADJ']

# %%
list(pos.items())
# Out:
# [('furiously', 'ADV'), ('sleep', 'V'), ('ideas', 'N'), ('colorless', 'ADJ')]

# %%
for key, val in sorted(pos.items()):
...     print(key + ":", val)
# Out:
# ('colorless:', 'ADJ')
# ('furiously:', 'ADV')
# ('ideas:', 'N')
# ('sleep:', 'V')

# %%
pos['sleep'] = 'V'
>>> pos['sleep']
# Out:
# 'V'

# %%
pos['sleep'] = 'N'
>>> pos['sleep']
# Out:
# 'N'

# %%
pos = {'colorless': 'ADJ', 'ideas': 'N', 'sleep': 'V', 'furiously': 'ADV'}
>>> pos = dict(colorless='ADJ', ideas='N', sleep='V', furiously='ADV')

# %%
pos = {['ideas', 'blogs', 'adventures']: 'N'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-703da251f05e> in <module>()
# ----> 1 pos = {['ideas', 'blogs', 'adventures']: 'N'}
#
# TypeError: unhashable type: 'list'

# %%
from collections import defaultdict
>>> frequency = defaultdict(int)
>>> frequency['colorless'] = 4
>>> frequency['ideas']
# Out:
# 0

# %%
from collections import defaultdict
pos = defaultdict(list)
pos['sleep'] = ['NOUN', 'VERB']
pos['ideas']
# Out:
# []

# %%
pos = defaultdict(lambda: 'NOUN')
>>> pos['colorless'] = 'ADJ'
>>> pos['blog']
# Out:
# 'NOUN'

# %%
list(pos.items())
# Out:
# [('blog', 'NOUN'), ('colorless', 'ADJ')]

# %%
alice = nltk.corpus.gutenberg.words('carroll-alice.txt')
>>> vocab = nltk.FreqDist(alice)
>>> v1000 = [word for (word, _) in vocab.most_common(1000)]
>>> mapping = defaultdict(lambda: 'UNK')
>>> for v in v1000:
...     mapping[v] = v
...
>>> alice2 = [mapping[v] for v in alice]
>>> alice2[:100]
# Out:
# ['UNK',
#  u'Alice',
#  u"'",
#  u's',
#  u'Adventures',
#  u'in',
#  u'Wonderland',
#  u'by',
#  'UNK',
#  'UNK',
#  'UNK',
#  'UNK',
#  u'CHAPTER',
#  u'I',
#  u'.',
#  'UNK',
#  u'the',
#  u'Rabbit',
#  u'-',
#  'UNK',
#  u'Alice',
#  u'was',
#  u'beginning',
#  u'to',
#  u'get',
#  u'very',
#  u'tired',
#  u'of',
#  u'sitting',
#  u'by',
#  u'her',
#  u'sister',
#  u'on',
#  u'the',
#  u'bank',
#  u',',
#  u'and',
#  u'of',
#  u'having',
#  u'nothing',
#  u'to',
#  u'do',
#  u':',
#  u'once',
#  u'or',
#  u'twice',
#  u'she',
#  u'had',
#  'UNK',
#  u'into',
#  u'the',
#  u'book',
#  u'her',
#  u'sister',
#  u'was',
#  'UNK',
#  u',',
#  u'but',
#  u'it',
#  u'had',
#  u'no',
#  u'pictures',
#  u'or',
#  'UNK',
#  u'in',
#  u'it',
#  u',',
#  u"'",
#  u'and',
#  u'what',
#  u'is',
#  u'the',
#  u'use',
#  u'of',
#  u'a',
#  u'book',
#  u",'",
#  u'thought',
#  u'Alice',
#  u"'",
#  u'without',
#  u'pictures',
#  u'or',
#  u'conversation',
#  u"?'",
#  u'So',
#  u'she',
#  u'was',
#  'UNK',
#  u'in',
#  u'her',
#  u'own',
#  u'mind',
#  u'(',
#  u'as',
#  u'well',
#  u'as',
#  u'she',
#  u'could',
#  u',']

# %%
len(set(alice2))
# Out:
# 1001

# %%
from collections import defaultdict
>>> counts = defaultdict(int)
>>> from nltk.corpus import brown
>>> for (word, tag) in brown.tagged_words(categories='news', tagset='universal'):
...     counts[tag] += 1

# %%
counts['NOUN']
# Out:
# 30654

# %%
sorted(counts)
# Out:
# [u'.',
#  u'ADJ',
#  u'ADP',
#  u'ADV',
#  u'CONJ',
#  u'DET',
#  u'NOUN',
#  u'NUM',
#  u'PRON',
#  u'PRT',
#  u'VERB',
#  u'X']

# %%
from operator import itemgetter
>>> sorted(counts.items(), key=itemgetter(1), reverse=True)
# Out:
# [(u'NOUN', 30654),
#  (u'VERB', 14399),
#  (u'ADP', 12355),
#  (u'.', 11928),
#  (u'DET', 11389),
#  (u'ADJ', 6706),
#  (u'ADV', 3349),
#  (u'CONJ', 2717),
#  (u'PRON', 2535),
#  (u'PRT', 2264),
#  (u'NUM', 2166),
#  (u'X', 92)]

# %%
[t for t, c in sorted(counts.items(), key=itemgetter(1), reverse=True)]
# Out:
# [u'NOUN',
#  u'VERB',
#  u'ADP',
#  u'.',
#  u'DET',
#  u'ADJ',
#  u'ADV',
#  u'CONJ',
#  u'PRON',
#  u'PRT',
#  u'NUM',
#  u'X']

# %%
pair = ('NP', 8336)
>>> pair[1]
# Out:
# 8336

# %%
itemgetter(1)(pair)
# Out:
# 8336

# %%
last_letters = defaultdict(list)
>>> words = nltk.corpus.words.words('en')
>>> for word in words:
...     key = word[-2:]
...     last_letters[key].append(word)

# %%
last_letters['ly']
# Out:
# [u'abactinally',
#  u'abandonedly',
#  u'abasedly',
#  u'abashedly',
#  u'abashlessly',
#  u'abbreviately',
#  u'abdominally',
#  u'abhorrently',
#  u'abidingly',
#  u'abiogenetically',
#  u'abiologically',
#  u'abjectly',
#  u'ableptically',
#  u'ably',
#  u'abnormally',
#  u'abominably',
#  u'aborally',
#  u'aboriginally',
#  u'abortively',
#  u'aboundingly',
#  u'abridgedly',
#  u'abruptedly',
#  u'abruptly',
#  u'abscondedly',
#  u'absently',
#  u'absentmindedly',
#  u'absolutely',
#  u'absolutistically',
#  u'absorbedly',
#  u'absorbingly',
#  u'absorptively',
#  u'abstemiously',
#  u'abstinently',
#  u'abstractedly',
#  u'abstractively',
#  u'abstractly',
#  u'abstrusely',
#  u'absurdly',
#  u'abundantly',
#  u'abusedly',
#  u'abusefully',
#  u'abusively',
#  u'abysmally',
#  u'academically',
#  u'acceleratedly',
#  u'accentually',
#  u'acceptably',
#  u'acceptedly',
#  u'accessarily',
#  u'accessibly',
#  u'accessively',
#  u'accessorily',
#  u'accidentally',
#  u'accidently',
#  u'accommodately',
#  u'accommodatingly',
#  u'accordantly',
#  u'accordingly',
#  u'accountably',
#  u'accumulatively',
#  u'accurately',
#  u'accursedly',
#  u'accusably',
#  u'accusatively',
#  u'accusatorially',
#  u'accusingly',
#  u'accustomedly',
#  u'acervately',
#  u'acetometrically',
#  u'achingly',
#  u'achromatically',
#  u'acicularly',
#  u'acidimetrically',
#  u'acidly',
#  u'acknowledgedly',
#  u'acoustically',
#  u'acquiescently',
#  u'acquiescingly',
#  u'acquisitively',
#  u'acridly',
#  u'acrimoniously',
#  u'acrobatically',
#  u'acrocephaly',
#  u'acrogenously',
#  u'acrologically',
#  u'acromegaly',
#  u'acronically',
#  u'acropetally',
#  u'acrostically',
#  u'actinally',
#  u'actinically',
#  u'actinoelectrically',
#  u'actionably',
#  u'actively',
#  u'actually',
#  u'actuarially',
#  u'acutely',
#  u'Adamically',
#  u'adaptationally',
#  u'adaptively',
#  u'addedly',
#  u'additionally',
#  u'additively',
#  u'addleheadedly',
#  u'adequately',
#  u'adherently',
#  u'adhesively',
#  u'adiabatically',
#  u'adjacently',
#  u'adjectivally',
#  u'adjectively',
#  u'adjoinedly',
#  u'adjunctively',
#  u'adjunctly',
#  u'adjustably',
#  u'administratively',
#  u'admirably',
#  u'admiredly',
#  u'admiringly',
#  u'admissibly',
#  u'admittedly',
#  u'admonishingly',
#  u'admonitively',
#  u'admonitorily',
#  u'adnominally',
#  u'adolescently',
#  u'adoptedly',
#  u'adoptively',
#  u'adorably',
#  u'adorally',
#  u'adoringly',
#  u'adorningly',
#  u'adradially',
#  u'adroitly',
#  u'adscititiously',
#  u'adulterately',
#  u'adulterously',
#  u'adumbratively',
#  u'advancingly',
#  u'advantageously',
#  u'adventitiously',
#  u'adventuresomely',
#  u'adventurously',
#  u'adverbially',
#  u'adversatively',
#  u'adversely',
#  u'advertently',
#  u'advisably',
#  u'advisedly',
#  u'advisorily',
#  u'aerially',
#  u'aerobically',
#  u'aerobiologically',
#  u'aerobiotically',
#  u'aerogenically',
#  u'aeronautically',
#  u'aerophilately',
#  u'aeroscopically',
#  u'aesthetically',
#  u'aetiotropically',
#  u'affably',
#  u'affectedly',
#  u'affectingly',
#  u'affectionally',
#  u'affectionately',
#  u'affectively',
#  u'affinely',
#  u'affinitatively',
#  u'affirmably',
#  u'affirmatively',
#  u'affirmingly',
#  u'afflictingly',
#  u'afflictively',
#  u'affluently',
#  u'affrightedly',
#  u'affrightfully',
#  u'affrightingly',
#  u'affrontedly',
#  u'affrontingly',
#  u'agamically',
#  u'agamogenetically',
#  u'agedly',
#  u'aggravatingly',
#  u'aggregately',
#  u'aggressively',
#  u'aggrievedly',
#  u'agilely',
#  u'agitatedly',
#  u'agnatically',
#  u'agnostically',
#  u'agonistically',
#  u'agonizedly',
#  u'agonizingly',
#  u'agrarianly',
#  u'agreeably',
#  u'agreeingly',
#  u'agriculturally',
#  u'agrobiologically',
#  u'agrogeologically',
#  u'agrologically',
#  u'aguishly',
#  u'aimfully',
#  u'aimlessly',
#  u'airily',
#  u'airtightly',
#  u'alarmedly',
#  u'alarmingly',
#  u'alchemically',
#  u'alcoholically',
#  u'aldermanly',
#  u'alertly',
#  u'algebraically',
#  u'algometrically',
#  u'alimentally',
#  u'alimentatively',
#  u'alkalimetrically',
#  u'allegedly',
#  u'allegorically',
#  u'allenarly',
#  u'alleviatingly',
#  u'alliably',
#  u'allicholly',
#  u'alliteratively',
#  u'allochirally',
#  u'allogenically',
#  u'allopathetically',
#  u'allopathically',
#  u'allopatrically',
#  u'allothigenetically',
#  u'allotropically',
#  u'allowably',
#  u'allowedly',
#  u'alluringly',
#  u'allusively',
#  u'Ally',
#  u'ally',
#  u'almightily',
#  u'alodially',
#  u'alogically',
#  u'aloofly',
#  u'alphabetically',
#  u'alpinely',
#  u'alterably',
#  u'alternately',
#  u'alternatingly',
#  u'alternatively',
#  u'altimetrically',
#  u'altruistically',
#  u'aly',
#  u'amateurishly',
#  u'amatively',
#  u'amatorially',
#  u'amazedly',
#  u'amazingly',
#  u'ambagiously',
#  u'ambassadorially',
#  u'ambidextrously',
#  u'ambiguously',
#  u'ambilateralaterally',
#  u'ambitionlessly',
#  u'ambitiously',
#  u'amblingly',
#  u'ambrosially',
#  u'amenably',
#  u'Americanly',
#  u'ametaboly',
#  u'amethodically',
#  u'amiably',
#  u'amicably',
#  u'amitotically',
#  u'amorously',
#  u'amorphously',
#  u'amphibiously',
#  u'amphibologically',
#  u'amphiboly',
#  u'amphigenously',
#  u'amphimictically',
#  u'amphistyly',
#  u'amphitheatrically',
#  u'amply',
#  u'amusedly',
#  u'amusingly',
#  u'amusively',
#  u'Anabaptistically',
#  u'anacamptically',
#  u'anachronically',
#  u'anachronistically',
#  u'anachronously',
#  u'anacoluthically',
#  u'Anacreontically',
#  u'anacrustically',
#  u'anaerobically',
#  u'anaerobiotically',
#  u'anaesthetically',
#  u'anagogically',
#  u'anagrammatically',
#  u'anally',
#  u'analogically',
#  u'analogously',
#  u'analytically',
#  u'anamnestically',
#  u'anapaestically',
#  u'anarchically',
#  u'anarthrously',
#  u'anathematically',
#  u'Anatoly',
#  u'anatomically',
#  u'ancestorially',
#  u'ancestrally',
#  u'anciently',
#  u'anecdotically',
#  u'anemographically',
#  u'anemometrically',
#  u'anemometrographically',
#  u'anemophily',
#  u'anencephaly',
#  u'anerly',
#  u'anesthetically',
#  u'aneurismally',
#  u'aneurysmally',
#  u'angelically',
#  u'angerly',
#  u'angiomegaly',
#  u'Anglicanly',
#  u'angrily',
#  u'anguishously',
#  u'angularly',
#  u'angulately',
#  u'animally',
#  u'animatedly',
#  u'animately',
#  u'animatingly',
#  u'anisocotyly',
#  u'anisophylly',
#  u'anisotropically',
#  u'anniversarily',
#  u'annoyingly',
#  u'annually',
#  u'annularly',
#  u'anodically',
#  u'anomalistically',
#  u'anomalously',
#  u'anomaly',
#  u'anonymously',
#  u'anorthographically',
#  u'answerably',
#  u'answeringly',
#  u'answerlessly',
#  u'antagonistically',
#  u'antarctically',
#  u'antecedaneously',
#  u'antecedently',
#  u'antediluvially',
#  u'anteriorly',
#  u'anterolaterally',
#  u'anteroposteriorly',
#  u'anteroventrally',
#  u'anthologically',
#  u'anthropologically',
#  u'anthropometrically',
#  u'anthropomorphically',
#  u'anthropomorphologically',
#  u'anthropomorphously',
#  u'anthropopathically',
#  u'anthropophagously',
#  u'antichristianly',
#  u'antichronically',
#  u'anticipatively',
#  u'anticipatorily',
#  u'anticly',
#  u'anticonstitutionally',
#  u'anticyclonically',
#  u'antidotally',
#  u'antidotically',
#  u'antidromically',
#  u'antimonarchically',
#  u'antimonopoly',
#  u'antipathetically',
#  u'antiperistatically',
#  u'antiphonally',
#  u'antiphonically',
#  u'antiphrastically',
#  u'antiquarianly',
#  u'antiquely',
#  u'antirachitically',
#  u'antiseptically',
#  u'antisocialistically',
#  u'antistrophically',
#  u'antitheistically',
#  u'antithetically',
#  u'antitypically',
#  u'antonomastically',
#  u'antrorsely',
#  u'anxiously',
#  u'aoristically',
#  u'apagogically',
#  u'apathetically',
#  u'aperiodically',
#  u'apertly',
#  u'apetaly',
#  u'apheliotropically',
#  u'aphetically',
#  u'aphoristically',
#  u'aphylly',
#  u'apically',
#  u'apishly',
#  u'aplanatically',
#  u'apocalyptically',
#  u'apocryphally',
#  u'apodictically',
#  u'apogamically',
#  u'apogamously',
#  u'apogeotropically',
#  u'apologetically',
#  u'apometaboly',
#  u'apoplectically',
#  u'aposematically',
#  u'apostatically',
#  u'apostolically',
#  u'apothegmatically',
#  u'appallingly',
#  u'apparently',
#  u'appealingly',
#  u'appeasably',
#  u'appeasingly',
#  u'appellatively',
#  u'apperceptively',
#  u'appetently',
#  u'appetizingly',
#  u'applaudably',
#  u'applaudingly',
#  u'applausively',
#  u'appliably',
#  u'applicably',
#  u'applicatively',
#  u'applicatorily',
#  u'appliedly',
#  u'apply',
#  u'applyingly',
#  u'appositely',
#  u'appositionally',
#  u'appositively',
#  u'appraisingly',
#  u'appreciably',
#  u'appreciatingly',
#  u'appreciatively',
#  u'appreciatorily',
#  u'apprehendingly',
#  u'apprehensibly',
#  u'apprehensively',
#  u'appropriately',
#  u'approvedly',
#  u'approvingly',
#  u'approximately',
#  u'approximatively',
#  u'appulsively',
#  u'apsidally',
#  u'aptitudinally',
#  u'aptly',
#  u'aquatically',
#  u'aqueously',
#  u'arabesquely',
#  u'arbitrarily',
#  u'arboreally',
#  u'arborescently',
#  u'Arcadianly',
#  u'archaeologically',
#  u'archaically',
#  u'archetypally',
#  u'archetypically',
#  u'archiepiscopally',
#  u'architectonically',
#  u'architecturally',
#  u'archly',
#  u'arctically',
#  u'arcuately',
#  u'ardently',
#  u'arduously',
#  u'areographically',
#  u'areologically',
#  u'argentometrically',
#  u'argumentatively',
#  u'argutely',
#  u'aridly',
#  u'arightly',
#  u'aristocratically',
#  u'arithmetically',
#  u'aromatically',
#  u'arrantly',
#  u'arrestingly',
#  u'arrhythmically',
#  u'arrogantly',
#  u'arrogatingly',
#  u'arterially',
#  u'artfully',
#  u'articularly',
#  u'articulately',
#  u'artificially',
#  u'artistically',
#  u'artlessly',
#  u'ascendingly',
#  u'ascertainably',
#  u'ascetically',
#  u'aseptically',
#  u'asexually',
#  u'ashamedly',
#  u'ashily',
#  u'Asiatically',
#  u'asininely',
#  u'askingly',
#  u'asperously',
#  u'aspersively',
#  u'aspiringly',
#  u'assembly',
#  u'assentatorily',
#  u'assentingly',
#  u'assertively',
#  u'assertorially',
#  u'assertorically',
#  u'assertorily',
#  u'assessably',
#  u'asseveratingly',
#  u'asseveratively',
#  u'assidually',
#  u'assiduously',
#  u'assignably',
#  u'assishly',
#  u'associatively',
#  u'assumably',
#  u'assumedly',
#  u'assumingly',
#  u'assumptively',
#  u'assuredly',
#  u'assuringly',
#  u'astatically',
#  u'astely',
#  u'asthmatically',
#  u'astigmatically',
#  u'astonishedly',
#  u'astonishingly',
#  u'astoundingly',
#  u'astrally',
#  u'astrictively',
#  u'astringently',
#  u'astrologically',
#  u'astronomically',
#  u'astuciously',
#  u'astutely',
#  u'asymmetrically',
#  u'asymptotically',
#  u'asyndetically',
#  u'atavistically',
#  u'atheistically',
#  u'Athenianly',
#  u'atheologically',
#  u'athletically',
#  u'atmospherically',
#  u'atomically',
#  u'atomistically',
#  u'atonally',
#  u'atoningly',
#  u'atrociously',
#  u'attachedly',
#  u'attemperately',
#  u'attendantly',
#  u'attendingly',
#  u'attentively',
#  u'attently',
#  u'attractingly',
#  u'attractionally',
#  u'attractively',
#  u'attributively',
#  u'attunely',
#  u'atypically',
#  u'audaciously',
#  u'audibly',
#  u'auditorially',
#  u'auditorily',
#  u'augmentatively',
#  u'augmentedly',
#  u'augustly',
#  u'auntly',
#  u'aurally',
#  u'aureately',
#  u'aureously',
#  u'auricularly',
#  u'auriculately',
#  u'aurorally',
#  u'auspiciously',
#  u'austerely',
#  u'auteciously',
#  u'autecologically',
#  u'authentically',
#  u'authenticly',
#  u'authorially',
#  u'authoritatively',
#  u'authorly',
#  u'autobiographically',
#  u'autocatalytically',
#  u'autocephaly',
#  u'autochthonously',
#  u'autocratically',
#  u'autoeciously',
#  u'autoerotically',
#  u'autogenetically',
#  u'autogenously',
#  u'autographically',
#  u'automatically',
#  u'automorphically',
#  u'autonomically',
#  u'autonomously',
#  u'autophytically',
#  u'autoptically',
#  u'autoschediastically',
#  u'autostyly',
#  u'autosymbolically',
#  u'autotropically',
#  u'autumnally',
#  u'auxetically',
#  u'auxiliarly',
#  u'auxinically',
#  u'availably',
#  u'availingly',
#  u'avariciously',
#  u'avengingly',
#  u'averagely',
#  u'aversely',
#  u'avertedly',
#  u'avidiously',
#  u'avidly',
#  u'avoidably',
#  u'avowably',
#  u'avowedly',
#  u'awakeningly',
#  u'awesomely',
#  u'awfully',
#  u'awkwardly',
#  u'axially',
#  u'axiologically',
#  u'axiomatically',
#  u'azimuthally',
#  u'babblingly',
#  u'babblishly',
#  u'babbly',
#  u'babishly',
#  u'babyishly',
#  u'bacchanalianly',
#  u'bachelorly',
#  u'backbitingly',
#  u'backhandedly',
#  u'backwardly',
#  u'bacterially',
#  u'bacteriologically',
#  u'bacterioscopically',
#  u'baddishly',
#  u'badgeringly',
#  u'badgerly',
#  u'badly',
#  u'bafflingly',
#  u'baggily',
#  u'bairnly',
#  u'bakerly',
#  u'bakingly',
#  u'baldly',
#  u'balefully',
#  u'balkingly',
#  u'ballistically',
#  u'bally',
#  u'balmily',
#  u'balsamically',
#  u'banally',
#  u'bandlessly',
#  u'banefully',
#  u'bankruptly',
#  u'banteringly',
#  u'baptismally',
#  u'barbarically',
#  u'barbarously',
#  u'bardily',
#  u'barefacedly',
#  u'barely',
#  u'barfly',
#  u'barkingly',
#  u'barometrically',
#  u'barratrously',
#  u'barrenly',
#  u'barruly',
#  u'basally',
#  u'baselessly',
#  u'basely',
#  u'bashfully',
#  u'basically',
#  u'bastardly',
#  u'bathymetrically',
#  u'bawdily',
#  u'bayardly',
#  u'beadily',
#  u'beamily',
#  u'beamingly',
#  u'bearably',
#  u'bearishly',
#  u'beastily',
#  u'beastlily',
#  u'beastly',
#  u'beatifically',
#  u'beauteously',
#  u'beautifully',
#  u'beckoningly',
#  u'becomingly',
#  u'bedazzlingly',
#  u'beefily',
#  u'beerily',
#  u'beerishly',
#  u'befittingly',
#  u'beggarly',
#  u'beggingly',
#  u'begrudgingly',
#  u'beguilingly',
#  u'behavioristically',
#  u'behoovefully',
#  u'behoovingly',
#  u'beknottedly',
#  u'belatedly',
#  u'believingly',
#  u'bellicosely',
#  u'belligerently',
#  u'belly',
#  u'bely',
#  u'belyingly',
#  u'bemoaningly',
#  u'bemusedly',
#  u'bendingly',
#  u'benedictively',
#  u'beneficently',
#  u'beneficially',
#  u'benevolently',
#  u'benignantly',
#  u'benignly',
#  u'benumbingly',
#  u'beseechingly',
#  u'beseemingly',
#  u'beseemly',
#  u'besiegingly',
#  u'besottedly',
#  u'besottingly',
#  u'bestially',
#  u'besully',
#  u'betterly',
#  u'Beverly',
#  u'bewailingly',
#  u'bewilderedly',
#  u'bewilderingly',
#  u'bewitchingly',
#  u'bewrayingly',
#  u'biannually',
#  u'biaxially',
#  u'Biblically',
#  u'bibliographically',
#  u'bibliophily',
#  u'bibliopolically',
#  u'bibliopoly',
#  u'bibulously',
#  u'biconically',
#  u'biddably',
#  u'bienly',
#  u'biennially',
#  u'bifariously',
#  u'bifidly',
#  u'bifilarly',
#  u'bifurcately',
#  u'bigamously',
#  u'bigotedly',
#  u'bihourly',
#  u'bilaterally',
#  u'bilingually',
#  u'biliously',
#  u'billiardly',
#  u'Billy',
#  u'billy',
#  u'bimanually',
#  u'bimonthly',
#  u'binately',
#  u'bindingly',
#  u'binocularly',
#  u'binomially',
#  u'biochemically',
#  u'bioecologically',
#  u'biogenetically',
#  u'biogeographically',
#  u'biographically',
#  u'biologically',
#  u'biometrically',
#  u'bionomically',
#  u'bipartitely',
#  u'bipinnately',
#  u'biquarterly',
#  u'bisectionally',
#  u'biserially',
#  u'biseriately',
#  u'bisexually',
#  u'bisymmetrically',
#  u'biternately',
#  u'bitingly',
#  u'bitterly',
#  u'biweekly',
#  u'biyearly',
#  u'bizarrely',
#  u'blackbelly',
#  u'blackguardly',
#  u'blackishly',
#  u'blackly',
#  u'blamably',
#  u'blamefully',
#  u'blamelessly',
#  u'blamingly',
#  u'blanchingly',
#  u'blandishingly',
#  u'blandly',
#  u'blankly',
#  u'blasphemously',
#  u'blatantly',
#  u'blately',
#  u'blazingly',
#  u'bleakly',
#  u'bleatingly',
#  u'blenchingly',
#  u'blessedly',
#  u'blessingly',
#  u'blightingly',
#  u'blindedly',
#  u'blindfoldly',
#  u'blindingly',
#  u'blindly',
#  u'blinkingly',
#  u'blissfully',
#  u'blisteringly',
#  u'blithefully',
#  u'blithely',
#  u'blithesomely',
#  u'blizzardly',
#  u'blockheadedly',
#  u'blockishly',
#  u'blolly',
#  u'bloodily',
#  u'bloodlessly',
#  u'bloodthirstily',
#  u'bloomingly',
#  u'blottesquely',
#  u'blottingly',
#  u'blowfly',
#  u'blubberingly',
#  u'bluely',
#  u'bluffly',
#  u'blunderingly',
#  u'bluntly',
#  u'blushfully',
#  u'blushingly',
#  u'blusteringly',
#  u'blusterously',
#  u'boardly',
#  u'boarishly',
#  u'boastfully',
#  u'boatly',
#  u'bobbishly',
#  u'bobfly',
#  u'bodaciously',
#  u'bodily',
#  u'bodingly',
#  u'boilingly',
#  u'boily',
#  u'boisterously',
#  u'boldly',
#  u'bolly',
#  u'bolographically',
#  u'Bolshevistically',
#  u'bombastically',
#  u'bonairly',
#  u'bonally',
#  u'bonelessly',
#  u'bonnily',
#  u'boobily',
#  u'bookishly',
#  u'booly',
#  u'boomingly',
#  u'boorishly',
#  u'bootlessly',
#  u'boozily',
#  u'boringly',
#  u'botanically',
#  u'botchedly',
#  u'botcherly',
#  u'botchily',
#  u'botfly',
#  u'botryoidally',
#  u'bottomlessly',
#  u'bounceably',
#  u'bouncingly',
#  u'boundedly',
#  u'boundingly',
#  u'boundlessly',
#  u'boundly',
#  u'bounteously',
#  u'bountifully',
#  u'bovinely',
#  u'bowingly',
#  u'bowly',
#  u'boyishly',
#  u'brabblingly',
#  u'brachistocephaly',
#  u'brachycephaly',
#  u'brachydactyly',
#  u'bracingly',
#  u'braggartly',
#  u'braggingly',
#  u'braggishly',
#  u'brainlessly',
#  u'brainsickly',
#  u'brambly',
#  u'brassily',
#  u'bravely',
#  u'brawlingly',
#  u'brawly',
#  u'brawnily',
#  u'brazenfacedly',
#  u'brazenly',
#  u'breakably',
#  u'breathingly',
#  u'breathlessly',
#  u'breezily',
#  u'bremely',
#  u'brickly',
#  u'bridally',
#  u'bridely',
#  u'brieflessly',
#  u'briefly',
#  u'brigandishly',
#  u'brightly',
#  u'brilliantly',
#  u'brimfully',
#  u'brimmingly',
#  u'briskly',
#  u'bristly',
#  u'Britannically',
#  u'Britishly',
#  u'brittlely',
#  u'broadly',
#  u'broilingly',
#  u'brokenheartedly',
#  u'brokenly',
#  u'brolly',
#  u'bromidically',
#  u'bromometrically',
#  u'bronchially',
#  u'broodingly',
#  u'brotherly',
#  u'brownly',
#  u'brusquely',
#  u'brutally',
#  u'brutely',
#  u'brutishly',
#  u'bubblingly',
#  u'bubbly',
#  u'buccally',
#  u'buckishly',
#  u'bucolically',
#  u'buirdly',
#  u'bulkily',
#  u'bullheadedly',
#  u'bullishly',
#  u'bully',
#  u'bumpily',
#  u'bumpingly',
#  u'bumpkinly',
#  u'bumptiously',
#  u'bunchily',
#  u'bungerly',
#  u'bunglingly',
#  u'buoyantly',
#  u'burbly',
#  u'burdensomely',
#  u'bureaucratically',
#  u'burglariously',
#  u'burlesquely',
#  u'burlily',
#  u'burly',
#  u'burningly',
#  u'bushily',
#  u'busily',
#  u'bustlingly',
#  u'butcherly',
#  u'butterfly',
#  u'butyrically',
#  u'buxomly',
#  u'buzzardly',
#  u'buzzingly',
#  u'byously',
#  u'Byronically',
#  u'cabalistically',
#  u'cacophonically',
#  u'cacophonously',
#  ...]

# %%
last_letters['zy']
# Out:
# [u'blazy',
#  u'bleezy',
#  u'blowzy',
#  u'boozy',
#  u'breezy',
#  u'bronzy',
#  u'buzzy',
#  u'Chazy',
#  u'cozy',
#  u'crazy',
#  u'dazy',
#  u'dizzy',
#  u'dozy',
#  u'enfrenzy',
#  u'fezzy',
#  u'fizzy',
#  u'floozy',
#  u'fozy',
#  u'franzy',
#  u'frenzy',
#  u'friezy',
#  u'frizzy',
#  u'frowzy',
#  u'furzy',
#  u'fuzzy',
#  u'gauzy',
#  u'gazy',
#  u'glazy',
#  u'groszy',
#  u'hazy',
#  u'heezy',
#  u'Izzy',
#  u'jazzy',
#  u'Jozy',
#  u'lawzy',
#  u'lazy',
#  u'mazy',
#  u'mizzy',
#  u'muzzy',
#  u'nizy',
#  u'oozy',
#  u'quartzy',
#  u'quizzy',
#  u'refrenzy',
#  u'ritzy',
#  u'Shortzy',
#  u'sizy',
#  u'sleazy',
#  u'sneezy',
#  u'snoozy',
#  u'squeezy',
#  u'Suzy',
#  u'tanzy',
#  u'tizzy',
#  u'topazy',
#  u'trotcozy',
#  u'twazzy',
#  u'unbreezy',
#  u'unfrizzy',
#  u'wheezy',
#  u'woozy',
#  u'wuzzy',
#  u'yezzy']

# %%
anagrams = defaultdict(list)
>>> for word in words:
...     key = ''.join(sorted(word))
...     anagrams[key].append(word)

# %%
anagrams['aeilnrt']
# Out:
# [u'entrail', u'latrine', u'ratline', u'reliant', u'retinal', u'trenail']

# %%
anagrams = nltk.Index((''.join(sorted(w)), w) for w in words)
>>> anagrams['aeilnrt']
# Out:
# [u'entrail', u'latrine', u'ratline', u'reliant', u'retinal', u'trenail']

# %%
pos = defaultdict(lambda: defaultdict(int))
>>> brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
>>> for ((w1, t1), (w2, t2)) in nltk.bigrams(brown_news_tagged):
...     pos[(t1, w2)][t2] += 1

# %%
pos[('DET', 'right')]
# Out:
# defaultdict(int, {u'ADJ': 11, u'NOUN': 5})

# %%
counts = defaultdict(int)
>>> for word in nltk.corpus.gutenberg.words('milton-paradise.txt'):
...     counts[word] += 1

# %%
[key for (key, value) in counts.items() if value == 32]
# Out:
# [u'brought',
#  u'Him',
#  u'virtue',
#  u'Against',
#  u'There',
#  u'thine',
#  u'King',
#  u'mortal',
#  u'every',
#  u'been']

# %%
pos = {'colorless': 'ADJ', 'ideas': 'N', 'sleep': 'V', 'furiously': 'ADV'}
>>> pos2 = dict((value, key) for (key, value) in pos.items())
>>> pos2['N']
# Out:
# 'ideas'

# %%
pos.update({'cats': 'N', 'scratch': 'V', 'peacefully': 'ADV', 'old': 'ADJ'})
>>> pos2 = defaultdict(list)
>>> for key, value in pos.items():
...     pos2[value].append(key)

# %%
pos2['ADV']
# Out:
# ['peacefully', 'furiously']

# %%
pos2 = nltk.Index((value, key) for (key, value) in pos.items())
>>> pos2['ADV']
# Out:
# ['peacefully', 'furiously']

# %%
from nltk.corpus import brown
>>> brown_tagged_sents = brown.tagged_sents(categories='news')
>>> brown_sents = brown.sents(categories='news')

# %%
tags = [tag for (word, tag) in brown.tagged_words(categories='news')]
>>> nltk.FreqDist(tags).max()
# Out:
# u'NN'

# %%
raw = 'I do not like green eggs and ham, I do not like them Sam I am!'
>>> tokens = word_tokenize(raw)
>>> default_tagger = nltk.DefaultTagger('NN')
>>> default_tagger.tag(tokens)
# Out:
# [('I', 'NN'),
#  ('do', 'NN'),
#  ('not', 'NN'),
#  ('like', 'NN'),
#  ('green', 'NN'),
#  ('eggs', 'NN'),
#  ('and', 'NN'),
#  ('ham', 'NN'),
#  (',', 'NN'),
#  ('I', 'NN'),
#  ('do', 'NN'),
#  ('not', 'NN'),
#  ('like', 'NN'),
#  ('them', 'NN'),
#  ('Sam', 'NN'),
#  ('I', 'NN'),
#  ('am', 'NN'),
#  ('!', 'NN')]

# %%
default_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.13089484257215028

# %%
patterns = [
...     (r'.*ing$', 'VBG'),               # gerunds
...     (r'.*ed$', 'VBD'),                # simple past
...     (r'.*es$', 'VBZ'),                # 3rd singular present
...     (r'.*ould$', 'MD'),               # modals
...     (r'.*\'s$', 'NN$'),               # possessive nouns
...     (r'.*s$', 'NNS'),                 # plural nouns
...     (r'^-?[0-9]+(.[0-9]+)?$', 'CD'),  # cardinal numbers
...     (r'.*', 'NN')                     # nouns (default)
... ]

# %%
regexp_tagger = nltk.RegexpTagger(patterns)
>>> regexp_tagger.tag(brown_sents[3])
# Out:
# [(u'``', 'NN'),
#  (u'Only', 'NN'),
#  (u'a', 'NN'),
#  (u'relative', 'NN'),
#  (u'handful', 'NN'),
#  (u'of', 'NN'),
#  (u'such', 'NN'),
#  (u'reports', 'NNS'),
#  (u'was', 'NNS'),
#  (u'received', 'VBD'),
#  (u"''", 'NN'),
#  (u',', 'NN'),
#  (u'the', 'NN'),
#  (u'jury', 'NN'),
#  (u'said', 'NN'),
#  (u',', 'NN'),
#  (u'``', 'NN'),
#  (u'considering', 'VBG'),
#  (u'the', 'NN'),
#  (u'widespread', 'NN'),
#  (u'interest', 'NN'),
#  (u'in', 'NN'),
#  (u'the', 'NN'),
#  (u'election', 'NN'),
#  (u',', 'NN'),
#  (u'the', 'NN'),
#  (u'number', 'NN'),
#  (u'of', 'NN'),
#  (u'voters', 'NNS'),
#  (u'and', 'NN'),
#  (u'the', 'NN'),
#  (u'size', 'NN'),
#  (u'of', 'NN'),
#  (u'this', 'NNS'),
#  (u'city', 'NN'),
#  (u"''", 'NN'),
#  (u'.', 'NN')]

# %%
regexp_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.20326391789486245

# %%
fd = nltk.FreqDist(brown.words(categories='news'))
>>> cfd = nltk.ConditionalFreqDist(brown.tagged_words(categories='news'))
>>> most_freq_words = fd.most_common(100)
>>> likely_tags = dict((word, cfd[word].max()) for (word, _) in most_freq_words)
>>> baseline_tagger = nltk.UnigramTagger(model=likely_tags)
>>> baseline_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.45578495136941344

# %%
sent = brown.sents(categories='news')[3]
>>> baseline_tagger.tag(sent)
# Out:
# [(u'``', u'``'),
#  (u'Only', None),
#  (u'a', u'AT'),
#  (u'relative', None),
#  (u'handful', None),
#  (u'of', u'IN'),
#  (u'such', None),
#  (u'reports', None),
#  (u'was', u'BEDZ'),
#  (u'received', None),
#  (u"''", u"''"),
#  (u',', u','),
#  (u'the', u'AT'),
#  (u'jury', None),
#  (u'said', u'VBD'),
#  (u',', u','),
#  (u'``', u'``'),
#  (u'considering', None),
#  (u'the', u'AT'),
#  (u'widespread', None),
#  (u'interest', None),
#  (u'in', u'IN'),
#  (u'the', u'AT'),
#  (u'election', None),
#  (u',', u','),
#  (u'the', u'AT'),
#  (u'number', None),
#  (u'of', u'IN'),
#  (u'voters', None),
#  (u'and', u'CC'),
#  (u'the', u'AT'),
#  (u'size', None),
#  (u'of', u'IN'),
#  (u'this', u'DT'),
#  (u'city', None),
#  (u"''", u"''"),
#  (u'.', u'.')]

# %%
baseline_tagger = nltk.UnigramTagger(model=likely_tags,
...                                      backoff=nltk.DefaultTagger('NN'))

# %%
def performance(cfd, wordlist):
    lt = dict((word, cfd[word].max()) for word in wordlist)
    baseline_tagger = nltk.UnigramTagger(model=lt, backoff=nltk.DefaultTagger('NN'))
    return baseline_tagger.evaluate(brown.tagged_sents(categories='news'))

def display():
    import pylab
    word_freqs = nltk.FreqDist(brown.words(categories='news')).most_common()
    words_by_freq = [w for (w, _) in word_freqs]
    cfd = nltk.ConditionalFreqDist(brown.tagged_words(categories='news'))
    sizes = 2 ** pylab.arange(15)
    perfs = [performance(cfd, words_by_freq[:size]) for size in sizes]
    pylab.plot(sizes, perfs, '-bo')
    pylab.title('Lookup Tagger Performance with Varying Model Size')
    pylab.xlabel('Model Size')
    pylab.ylabel('Performance')
    pylab.show()

# %%
display()

# %%
from nltk.corpus import brown
>>> brown_tagged_sents = brown.tagged_sents(categories='news')
>>> brown_sents = brown.sents(categories='news')
>>> unigram_tagger = nltk.UnigramTagger(brown_tagged_sents)
>>> unigram_tagger.tag(brown_sents[2007])
# Out:
# [(u'Various', u'JJ'),
#  (u'of', u'IN'),
#  (u'the', u'AT'),
#  (u'apartments', u'NNS'),
#  (u'are', u'BER'),
#  (u'of', u'IN'),
#  (u'the', u'AT'),
#  (u'terrace', u'NN'),
#  (u'type', u'NN'),
#  (u',', u','),
#  (u'being', u'BEG'),
#  (u'on', u'IN'),
#  (u'the', u'AT'),
#  (u'ground', u'NN'),
#  (u'floor', u'NN'),
#  (u'so', u'QL'),
#  (u'that', u'CS'),
#  (u'entrance', u'NN'),
#  (u'is', u'BEZ'),
#  (u'direct', u'JJ'),
#  (u'.', u'.')]

# %%
unigram_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.9349006503968017

# %%
size = int(len(brown_tagged_sents) * 0.9)
>>> size
# Out:
# 4160

# %%
train_sents = brown_tagged_sents[:size]
>>> test_sents = brown_tagged_sents[size:]
>>> unigram_tagger = nltk.UnigramTagger(train_sents)
>>> unigram_tagger.evaluate(test_sents)
# Out:
# 0.8120203329014253

# %%
bigram_tagger = nltk.BigramTagger(train_sents)
>>> bigram_tagger.tag(brown_sents[2007])
# Out:
# [(u'Various', u'JJ'),
#  (u'of', u'IN'),
#  (u'the', u'AT'),
#  (u'apartments', u'NNS'),
#  (u'are', u'BER'),
#  (u'of', u'IN'),
#  (u'the', u'AT'),
#  (u'terrace', u'NN'),
#  (u'type', u'NN'),
#  (u',', u','),
#  (u'being', u'BEG'),
#  (u'on', u'IN'),
#  (u'the', u'AT'),
#  (u'ground', u'NN'),
#  (u'floor', u'NN'),
#  (u'so', u'CS'),
#  (u'that', u'CS'),
#  (u'entrance', u'NN'),
#  (u'is', u'BEZ'),
#  (u'direct', u'JJ'),
#  (u'.', u'.')]

# %%
unseen_sent = brown_sents[4203]
>>> bigram_tagger.tag(unseen_sent)
# Out:
# [(u'The', u'AT'),
#  (u'population', u'NN'),
#  (u'of', u'IN'),
#  (u'the', u'AT'),
#  (u'Congo', u'NP'),
#  (u'is', u'BEZ'),
#  (u'13.5', None),
#  (u'million', None),
#  (u',', None),
#  (u'divided', None),
#  (u'into', None),
#  (u'at', None),
#  (u'least', None),
#  (u'seven', None),
#  (u'major', None),
#  (u'``', None),
#  (u'culture', None),
#  (u'clusters', None),
#  (u"''", None),
#  (u'and', None),
#  (u'innumerable', None),
#  (u'tribes', None),
#  (u'speaking', None),
#  (u'400', None),
#  (u'separate', None),
#  (u'dialects', None),
#  (u'.', None)]

# %%
bigram_tagger.evaluate(test_sents)
# Out:
# 0.10276088906608193

# %%
t0 = nltk.DefaultTagger('NN')
>>> t1 = nltk.UnigramTagger(train_sents, backoff=t0)
>>> t2 = nltk.BigramTagger(train_sents, backoff=t1)
>>> t2.evaluate(test_sents)
# Out:
# 0.844911791089405

# %%
t0 = nltk.DefaultTagger('NN')
>>> t1 = nltk.UnigramTagger(train_sents, backoff=t0)
>>> t2 = nltk.BigramTagger(train_sents, backoff=t1)
>>> t3 = nltk.TrigramTagger(train_sents, backoff=t2)
>>> t3.evaluate(test_sents)
# Out:
# 0.8424200139539519

# %%
from pickle import dump
>>> output = open('t2.pkl', 'wb')
>>> dump(t2, output, -1)
>>> output.close()

# %%
from pickle import load
>>> input = open('t2.pkl', 'rb')
>>> tagger = load(input)
>>> input.close()

# %%
text = """The board's action shows what free enterprise
...     is up against in our complex maze of regulatory laws ."""
>>> tokens = text.split()
>>> tagger.tag(tokens)
# Out:
# [('The', u'AT'),
#  ("board's", u'NN$'),
#  ('action', 'NN'),
#  ('shows', u'NNS'),
#  ('what', u'WDT'),
#  ('free', u'JJ'),
#  ('enterprise', 'NN'),
#  ('is', u'BEZ'),
#  ('up', u'RP'),
#  ('against', u'IN'),
#  ('in', u'IN'),
#  ('our', u'PP$'),
#  ('complex', u'JJ'),
#  ('maze', 'NN'),
#  ('of', u'IN'),
#  ('regulatory', 'NN'),
#  ('laws', u'NNS'),
#  ('.', u'.')]

# %%
cfd = nltk.ConditionalFreqDist(
...            ((x[1], y[1], z[0]), z[1])
...            for sent in brown_tagged_sents
...            for x, y, z in nltk.trigrams(sent))
>>> ambiguous_contexts = [c for c in cfd.conditions() if len(cfd[c]) > 1]
>>> sum(cfd[c].N() for c in ambiguous_contexts) / cfd.N()
# Out:
# 0

# %%
test_tags = [tag for sent in brown.sents(categories='editorial')
...                  for (word, tag) in t2.tag(sent)]
>>> gold_tags = [tag for (word, tag) in brown.tagged_words(categories='editorial')]
>>> print(nltk.ConfusionMatrix(gold_tags, test_tags))
# Out:
#            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  W                                         |
#            |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       N                                                                                                                                                                                                                                                                                                                                                                            V                             D                                         |
#            |                                                                                                                                                                                                                                                                                                                                                   F              F         F         F                                                                                                        J                                                                                         N                             N                                                                                                                                                                                        P    P         P                                                                                                                                                                    B                             T                                         |
#            |                                                                                                                                                               B                                                                                                                                                                                   W              W         W         W                                                                                                        J                                                                                         N              N              S                                            N                                                                                                                       P    P              P    P    P    P    P    P    P                                                                                                                                                     N                        W    +                                         |
#            |                                                                                         A                                                                     E                             B              B    B                                                                                    D         D                        E         -              -         -         -    F         F    F         F    F                                                                     -         J    J         J         J                                  N    N              -              N    N    N    -              N    N    N                   P    N    N              N                                                 P    P         P              P    P         P    P    P         S    S    P    S    P    P    P                                                                                              V                   V         V    V         V    V    -         V    V         D    B    W              W              W      |
#            |                                                 -                                       B                   A    A         A    A         B              B    D                             E              E    E         C    C         C    C         C              D    D                        O         T                        X    F    A    F    F    I    F    J    F    N    W    F    W    W    F    W    W                                       I    I    I         J    J    T         J    J         J         J              M    M              N    N    N    N    T              S    N    N    T              P    P    P    N    N         S    P    P              R    N              O              P              P    P         P              P    P         S    S    P         S    S    S    S    S    S    S         Q                   R    R    R                        R         T         U         B    V    V         B         B    B         B    B    T         B    B         T    E    D              P              R      |
#            |                             *         ,         -         .         :    :              N                   P    P         T    T         E         B    E    Z                        B    R         B    Z    Z         C    C         D    D         S              O    O         D         D    Z         +                        +    W    T    W    W    N    W    J    W    N    -    W    -    -    W    -    -                             H         N    N    N         J    J    L         R    R         S         T              D    D              $    $    N    N    L         N    $    S    S    L              $    $    +    P    P         $    S    S              $    R              D              N         P    $    $         L    P         O    O         +    +    S    P    +    +    S    +    S    S    S         L                   B    B    B                        P         O         H         +    B    B         D         G    G         N    N    L         Z    Z         +    Z    T              O              B      |
#            |                             -         -         -         -         -    -    A    A    -    A         A    -    -         -    -         -    B    E    D    -    B    B    B    B    E    -    B    E    -    -         -    -         -    -         -         D    -    -    D    O    D    O    -         B    D    D    D         B    -    -    -    -    -    -    -    -    -    N    -    P    P    -    V    W         H    H    H    H    V         -    -    -         -    -    -    J    -    -    J    -    J    -         M    -    -         N    -    -    -    -    -    N    N    -    -    -    -         N    -    -    B    -    -    N    -    -    -         N    -    -    N         -         P    -    P    P    -    -    P    -    P    P    -    -    P    B    H    +    P    B    B    +    H    +    -    -         -    Q         R    -    -    -    R    R              -         -         -         P    -    -    V    -    V    -    -    V    -    -    -    V    -    -    W    B    -    -    W    W    -    W    W    -      |
#            |         '                   H         H    -    H         H         H    T    B    B    T    B    A    P    H    T    A    H    T    B    H    E    D    Z    H    E    E    E    E    R    H    E    Z    H    T    C    H    T    C    H    T    C    H    D    O    H    T    O    D    O    Z    H    D    E    T    T    T    E    E    A    T    C    I    T    J    T    N    T    N    N    P    P    V    B    D    H    V    V    V    V    Z    I    H    N    T    J    H    T    H    J    H    T    J    T    J    H    M    D    H    T    N    N    H    T    H    T    H    N    S    T    H    T    H    N    P    H    T    E    H    T    P    H    H    T    N    R    T    T    R    O    T    P    N    H    P    $    H    T    P    H    L    P    H    T    P    E    V    M    S    E    E    H    V    M    H    T    Q    H    L    R    B    H    N    T    B    B    R    R    H    T    H    U    H    V    P    H    T    B    H    B    H    T    B    H    T    H    B    H    T    D    E    H    H    P    P    T    P    R    H    ` |
#            |    '    '    (    )    *    L    ,    L    -    L    .    L    :    L    L    L    N    L    X    P    $    L    L    T    L    L    E    L    D    Z    *    L    G    M    N    R    *    L    Z    *    L    L    C    L    L    D    L    L    S    L    O    *    L    L    D    *    Z    *    L    T    Z    I    S    X    X    Z    T    L    C    N    L    J    L    N    L    S    P    L    O    B    Z    T    V    D    G    N    Z    *    N    L    C    L    J    L    L    L    R    L    L    S    L    T    L    D    *    L    L    N    $    L    L    L    L    L    S    $    L    L    L    L    P    $    L    L    Z    L    L    S    L    L    L    R    $    L    L    S    D    L    N    $    L    $    $    L    L    L    L    S    O    L    L    S    Z    Z    D    S    M    R    V    D    D    L    L    L    L    P    B    $    L    C    L    R    T    N    P    L    O    L    H    L    B    O    L    L    D    L    G    L    L    N    L    L    L    Z    L    L    T    Z    L    L    $    O    L    S    B    L    ` |
# -----------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#          ' |  <19>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#         '' |    . <382>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          ( |    .    .  <95>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          ) |    .    .    .  <95>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          * |    .    .    .    . <304>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       *-HL |    .    .    .    .    3   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          , |    .    .    .    .    .    .<2736>   5    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       ,-HL |    .    .    .    .    .    .   22   <3>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#         -- |    .    .    .    .    .    .    .    . <191>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      ---HL |    .    .    .    .    .    .    .    .    1   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          . |    .    .    .    .    .    .    .    .    .    .<2976>   4    8    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       .-HL |    .    .    .    .    .    .    .    .    .    .   20   <1>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#          : |    .    .    .    .    .    .    .    .    .    .    .    . <108>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       :-HL |    .    .    .    .    .    .    .    .    .    .    .    .   36   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       :-TL |    .    .    .    .    .    .    .    .    .    .    .    .    1    .   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        ABL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <2>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   12    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        ABN |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <150>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    2    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#     ABN-TL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    2   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        ABX |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .  <30>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#         AP |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <547>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    2    .    .    .    1    .    .    .    1    .    .    .    .    .    .    .    .    .    .   18    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   26    .    1    3    .    .    .    .    4    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        AP$ |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <1>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      AP-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    5    .   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      AP-TL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#         AT |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .<5303>   3    4    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      AT-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   93   <.>   2    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      AT-TL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   30    .  <13>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#         BE |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <420>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      BE-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        BED |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <109>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#       BEDZ |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <307>   .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    2    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#      BEDZ* |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <2>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#    BEDZ-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <.>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        BEG |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .  <45>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
#        BEM |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .  <19>   .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . |
# ...
#        VBZ |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .  166    .    .    .    .    .    .   60    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <308>   9    .    .    .    .    .    .    .    .    .    .    .    . |
#     VBZ-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    6    .    .    .    .    .    .    2    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    6   <2>   .    .    .    .    .    .    .    .    .    .    .    . |
#     VBZ-TL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    3    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <.>   .    .    .    .    .    .    .    .    .    .    . |
#        WDT |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <307>   .    .    .    .    .    .    .    .    .    . |
#    WDT+BEZ |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    2    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <.>   .    .    .    .    .    .    .    .    . |
# WDT+BEZ-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <.>   .    .    .    .    .    .    .    . |
#     WDT-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    3    .    .   <.>   .    .    .    .    .    .    . |
#        WP$ |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .  <11>   .    .    .    .    .    . |
#        WPO |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    5    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <8>   .    .    .    .    . |
#     WPO-TL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   <.>   .    .    .    . |
#        WPS |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .   53    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    5    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <209>   .    .    . |
#        WRB |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    3    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    1    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <256>   .    . |
#     WRB-HL |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    3   <.>   . |
#         `` |    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    .    . <396>|
# -----------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# (row = reference; col = test)

# %%
from nltk.tag import brill
brill.nltkdemo18()

from nltk.tag import brill 
brill
# Out:
# <module 'nltk.tag.brill' from 'c:\python27\lib\site-packages\nltk\tag\brill.pyc'>

# %%
print(open("errors.out").read())
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-174-5d5d5639aae9> in <module>()
# ----> 1 print(open("errors.out").read())
#
# IOError: [Errno 2] No such file or directory: 'errors.out'

# %%
print("Duvida no de cima porque penso que a funçao demo() ta deprecated")
# Out:
# Duvida no de cima porque penso que a funçao demo() ta deprecated
